# %%
import numpy as np
import pandas as pd
from scratch import *
import random
# Out:
# Linear Regression
# Training loss after  0  iterations is  1.5811388300841898
# Training loss after  500  iterations is  0.11515089871796896
# Training loss after  1000  iterations is  0.11515089872154656
# Training loss after  1500  iterations is  0.11515089872154524
# Training loss after  2000  iterations is  0.11515089872154423
# Training loss after  2500  iterations is  0.11515089872154423
# Training loss after  3000  iterations is  0.11515089872154423
# Training loss after  3500  iterations is  0.11515089872154423
# Training loss after  4000  iterations is  0.11515089872154423
# Training loss after  4500  iterations is  0.11515089872154423
# Predicted Values: [[2.76462962]
#  [2.76462962]]
# True Values: [3]

# %%
preprocess = MyPreProcessor()
X,Y=preprocess.pre_process(2)
print(X)
print(Y)
# Out:
# [[-0.29911252 -0.01940752 -0.24347183 -0.30950245]
#  [ 0.98585385  1.50520806 -0.6255817  -0.23496538]
#  [ 0.80692407 -1.19354086  0.97401692  0.11777277]
#  ...
#  [-0.61580852 -0.10285432  0.14393737 -0.23987331]
#  [-0.4566623   0.62410398 -0.57111759 -0.92544269]
#  [-0.71354029 -0.25551277  0.249426   -0.25398274]]
# [[1.]
#  [0.]
#  [0.]
#  ...
#  [1.]
#  [1.]
#  [1.]]

# %%
ratio = X.shape[0]//10
X_train = X[0:7*ratio, :]
y_train = Y[0:7*ratio, :]
X_val = X[7*ratio : 8*ratio, :]
y_val = Y[7*ratio : 8*ratio, :]
X_test = X[8*ratio:, :]
y_test = Y[8*ratio:,:]
print(X_train.shape,y_train.shape )
print(X_test.shape,y_test.shape )
print(X_val.shape, y_val.shape)
# Out:
# (959, 4) (959, 1)
# (276, 4) (276, 1)
# (137, 4) (137, 1)

# %%
pp = MyPreProcessor()
W = pp.get_analytical_sol()
print(W)
X,y = pp.pre_process(0)
bias = np.zeros((X.shape[0],1))
bias.fill(1)
X = np.append(X,bias, axis = 1)
y_pred = np.dot(X,W)
error = (np.sum((y-y_pred)**2)/y_pred.shape[0])**0.5
mae = np.sum(abs(y-y_pred))/y_pred.shape[0]
print(error)
print(mae)
# Out:
# [[ 2.13626242  0.00849443 -0.19450817 ... -0.55916099 -0.53284584
#    1.        ]
#  [ 3.63998538 -0.09676618 -0.28473155 ... -0.70051095 -0.53510142
#    1.        ]
#  [ 3.63998538 -0.11180341 -0.28473155 ... -0.65765484 -0.61254316
#    1.        ]
#  ...
#  [ 0.63253946  0.0460875  -0.1569151  ... -0.52833467 -0.4711932
#    1.        ]
#  [ 2.13626242 -0.14939648 -0.31480601 ... -0.6448732  -0.63133969
#    1.        ]
#  [ 0.63253946  0.06864335 -0.1569151  ... -0.51705675 -0.40427753
#    1.        ]]
# [[ -0.25628631]
#  [ -0.51655077]
#  [  7.900679  ]
#  [  7.50021818]
#  [  6.02815842]
#  [-13.36837538]
#  [ -6.73825106]
#  [  5.79235855]
#  [  9.66007587]]
# 2.1959658591369107
# 1.583133232202937

# %%
"""Running SGD on Banknote dataset and with LR = 0.0001, 0.01, 10"""
L = [0.0001, 0.0001,0.01,10]
Epochs = [10000,400000, 10000, 10000]

# %%
for i in range(4):
    print("\n For learning rate ", L[i], "------------------------------------------------------------ ")
    log_regressor_sgd = MyLogisticRegression()
    log_regressor_sgd.fit(X_train, y_train, X_val, y_val, epochs = Epochs[i] ,learning_rate = L[i], grad_type = "sgd")
    print(log_regressor_sgd.W)
    print(log_regressor_sgd.b)
    loss_history_sgd = log_regressor_sgd.loss_history
    val_loss_history_sgd = log_regressor_sgd.val_loss_history
    train_acc_history_sgd = log_regressor_sgd.train_acc_history
    val_acc_history_sgd = log_regressor_sgd.val_acc_history
    plt.plot([x for x in range(len(loss_history_sgd))], loss_history_sgd, label = "Training  loss " )
    plt.plot([x for x in range(len(val_loss_history_sgd))], val_loss_history_sgd, label = "Validation  loss")
    plt.xlabel('iterations')
    plt.ylabel('loss')
    plt.legend()
    plt.show()
    plt.plot([x for x in range(len(train_acc_history_sgd))], train_acc_history_sgd, label = "Training  accuracy " )
    plt.plot([x for x in range(len(val_acc_history_sgd))], val_acc_history_sgd, label = "Validation  accuracy")
    plt.xlabel('iterations')
    plt.ylabel('accuracy')
    plt.legend()
    plt.show()
    
    print("\n -------------------------------------------------------------------------------------------")
# Out:
#  For learning rate  0.0001 ------------------------------------------------------------
#
# Training loss after  0  sgd steps is :  0.6931469805599655  | validation loss is :  0.6931469805599654
# Training accuracy after  0  sgd steps is :  45.04692387904067 %  | validation accuracy is :  38.68613138686131 %
#
# Training loss after  500  sgd steps is :  0.6844737942851975  | validation loss is :  0.6837371223991312
# Training accuracy after  500  sgd steps is :  68.50886339937435 %  | validation accuracy is :  72.26277372262774 %
#
# Training loss after  1000  sgd steps is :  0.6761021016521149  | validation loss is :  0.6746208555545485
# Training accuracy after  1000  sgd steps is :  67.88321167883211 %  | validation accuracy is :  72.26277372262774 %
#
# Training loss after  1500  sgd steps is :  0.6681414108692175  | validation loss is :  0.6659900758160101
# Training accuracy after  1500  sgd steps is :  68.09176225234619 %  | validation accuracy is :  72.26277372262774 %
#
# Training loss after  2000  sgd steps is :  0.6606775862769559  | validation loss is :  0.6579106875397492
# Training accuracy after  2000  sgd steps is :  67.98748696558916 %  | validation accuracy is :  72.26277372262774 %
#
# Training loss after  2500  sgd steps is :  0.6542350005228731  | validation loss is :  0.6509783121819667
# Training accuracy after  2500  sgd steps is :  69.34306569343065 %  | validation accuracy is :  72.26277372262774 %
#
# Training loss after  3000  sgd steps is :  0.64738551075838  | validation loss is :  0.6434592560384198
# Training accuracy after  3000  sgd steps is :  68.71741397288842 %  | validation accuracy is :  72.99270072992701 %
#
# Training loss after  3500  sgd steps is :  0.6414260358265352  | validation loss is :  0.6369888752830064
# Training accuracy after  3500  sgd steps is :  69.86444212721585 %  | validation accuracy is :  72.99270072992701 %
#
# Training loss after  4000  sgd steps is :  0.6351199703169125  | validation loss is :  0.6302046935638003
# Training accuracy after  4000  sgd steps is :  69.96871741397288 %  | validation accuracy is :  72.99270072992701 %
#
# Training loss after  4500  sgd steps is :  0.6296222092157338  | validation loss is :  0.6243167260699829
# Training accuracy after  4500  sgd steps is :  70.281543274244 %  | validation accuracy is :  72.99270072992701 %
#
# Training loss after  5000  sgd steps is :  0.6237454922284986  | validation loss is :  0.6180793710642113
# Training accuracy after  5000  sgd steps is :  70.17726798748696 %  | validation accuracy is :  72.99270072992701 %
#
# Training loss after  5500  sgd steps is :  0.6183764916787383  | validation loss is :  0.6123476565711895
# Training accuracy after  5500  sgd steps is :  70.38581856100103 %  | validation accuracy is :  72.99270072992701 %
#
# Training loss after  6000  sgd steps is :  0.6137963516975835  | validation loss is :  0.6074901075861685
# Training accuracy after  6000  sgd steps is :  70.90719499478624 %  | validation accuracy is :  72.99270072992701 %
#
# Training loss after  6500  sgd steps is :  0.6088469915018028  | validation loss is :  0.6021064043961237
# Training accuracy after  6500  sgd steps is :  70.90719499478624 %  | validation accuracy is :  74.45255474452554 %
#
# Training loss after  7000  sgd steps is :  0.6043277724849706  | validation loss is :  0.5973822895462312
# Training accuracy after  7000  sgd steps is :  71.01147028154328 %  | validation accuracy is :  73.72262773722628 %
#
# Training loss after  7500  sgd steps is :  0.6003609280016683  | validation loss is :  0.5931720229428462
# Training accuracy after  7500  sgd steps is :  71.11574556830031 %  | validation accuracy is :  75.18248175182481 %
#
# Training loss after  8000  sgd steps is :  0.5961237525327042  | validation loss is :  0.5887527667240936
# Training accuracy after  8000  sgd steps is :  71.22002085505736 %  | validation accuracy is :  75.91240875912408 %
#
# Training loss after  8500  sgd steps is :  0.5918211443990427  | validation loss is :  0.5842529651704635
# Training accuracy after  8500  sgd steps is :  71.11574556830031 %  | validation accuracy is :  76.64233576642336 %
#
# Training loss after  9000  sgd steps is :  0.5877105409824196  | validation loss is :  0.5798907726045293
# Training accuracy after  9000  sgd steps is :  71.42857142857143 %  | validation accuracy is :  77.37226277372262 %
#
# Training loss after  9500  sgd steps is :  0.5839873321641538  | validation loss is :  0.576050189557307
# Training accuracy after  9500  sgd steps is :  71.53284671532847 %  | validation accuracy is :  77.37226277372262 %
# [[-0.21930875]
#  [-0.24313807]
#  [ 0.02493224]
#  [ 0.00326356]]
# [[-0.03954924]]
#  -------------------------------------------------------------------------------------------
#
#  For learning rate  0.0001 ------------------------------------------------------------
#
# Training loss after  0  sgd steps is :  0.6931469805599655  | validation loss is :  0.6931469805599654
# Training accuracy after  0  sgd steps is :  45.04692387904067 %  | validation accuracy is :  38.68613138686131 %
#
# Training loss after  20000  sgd steps is :  0.521115990058853  | validation loss is :  0.5101953525785942
# Training accuracy after  20000  sgd steps is :  75.3910323253389 %  | validation accuracy is :  82.48175182481752 %
#
# Training loss after  40000  sgd steps is :  0.4445622044757058  | validation loss is :  0.4316056789353902
# Training accuracy after  40000  sgd steps is :  86.44421272158498 %  | validation accuracy is :  86.86131386861314 %
#
# Training loss after  60000  sgd steps is :  0.39109273567472413  | validation loss is :  0.37704057408959046
# Training accuracy after  60000  sgd steps is :  90.61522419186653 %  | validation accuracy is :  87.59124087591242 %
#
# Training loss after  80000  sgd steps is :  0.3501033231248022  | validation loss is :  0.3356787837886305
# Training accuracy after  80000  sgd steps is :  92.07507820646507 %  | validation accuracy is :  91.24087591240875 %
#
# Training loss after  100000  sgd steps is :  0.3174456948706455  | validation loss is :  0.30239549555850065
# Training accuracy after  100000  sgd steps is :  94.05630865484879 %  | validation accuracy is :  94.16058394160584 %
#
# Training loss after  120000  sgd steps is :  0.29102021163777486  | validation loss is :  0.27592427901796485
# Training accuracy after  120000  sgd steps is :  95.20333680917624 %  | validation accuracy is :  95.62043795620438 %
#
# Training loss after  140000  sgd steps is :  0.2691705616514202  | validation loss is :  0.25368181710163157
# Training accuracy after  140000  sgd steps is :  96.03753910323253 %  | validation accuracy is :  96.35036496350365 %
#
# Training loss after  160000  sgd steps is :  0.2508621236026918  | validation loss is :  0.23521347073179372
# Training accuracy after  160000  sgd steps is :  96.55891553701773 %  | validation accuracy is :  96.35036496350365 %
#
# Training loss after  180000  sgd steps is :  0.23527649006466705  | validation loss is :  0.21963417568129895
# Training accuracy after  180000  sgd steps is :  96.76746611053181 %  | validation accuracy is :  97.08029197080292 %
#
# Training loss after  200000  sgd steps is :  0.22180627712199374  | validation loss is :  0.20611376744882917
# Training accuracy after  200000  sgd steps is :  96.87174139728884 %  | validation accuracy is :  97.08029197080292 %
#
# Training loss after  220000  sgd steps is :  0.21008097075763169  | validation loss is :  0.19457298608256654
# Training accuracy after  220000  sgd steps is :  96.87174139728884 %  | validation accuracy is :  98.54014598540147 %
#
# Training loss after  240000  sgd steps is :  0.19984928061286916  | validation loss is :  0.18446856866162772
# Training accuracy after  240000  sgd steps is :  97.18456725755996 %  | validation accuracy is :  98.54014598540147 %
#
# Training loss after  260000  sgd steps is :  0.1906937456245962  | validation loss is :  0.17566046006785793
# Training accuracy after  260000  sgd steps is :  97.288842544317 %  | validation accuracy is :  98.54014598540147 %
#
# Training loss after  280000  sgd steps is :  0.18252366373148785  | validation loss is :  0.1676032864524462
# Training accuracy after  280000  sgd steps is :  97.288842544317 %  | validation accuracy is :  98.54014598540147 %
#
# Training loss after  300000  sgd steps is :  0.1752261726617279  | validation loss is :  0.16043196141605853
# Training accuracy after  300000  sgd steps is :  97.39311783107404 %  | validation accuracy is :  98.54014598540147 %
#
# Training loss after  320000  sgd steps is :  0.16875497996618505  | validation loss is :  0.1540845521106438
# Training accuracy after  320000  sgd steps is :  97.49739311783108 %  | validation accuracy is :  98.54014598540147 %
#
# Training loss after  340000  sgd steps is :  0.1628605648393294  | validation loss is :  0.14829963237768412
# Training accuracy after  340000  sgd steps is :  97.60166840458811 %  | validation accuracy is :  98.54014598540147 %
#
# Training loss after  360000  sgd steps is :  0.15744196777620778  | validation loss is :  0.14308237888907233
# Training accuracy after  360000  sgd steps is :  97.60166840458811 %  | validation accuracy is :  98.54014598540147 %
#
# Training loss after  380000  sgd steps is :  0.15252590486611953  | validation loss is :  0.1382513573524718
# Training accuracy after  380000  sgd steps is :  97.60166840458811 %  | validation accuracy is :  98.54014598540147 %
# [[-3.02816093]
#  [-1.70629097]
#  [-1.70608646]
#  [-0.30040596]]
# [[-0.01019772]]
# C:\Users\Asus\Anaconda3\lib\site-packages\IPython\core\pylabtools.py:128: UserWarning: Creating legend with loc="best" can be slow with large amounts of data.
#   fig.canvas.print_figure(bytes_io, **kw)
#  -------------------------------------------------------------------------------------------
#
#  For learning rate  0.01 ------------------------------------------------------------
#
# Training loss after  0  sgd steps is :  0.6931469805599655  | validation loss is :  0.6931469805599654
# Training accuracy after  0  sgd steps is :  45.04692387904067 %  | validation accuracy is :  38.68613138686131 %
#
# Training loss after  500  sgd steps is :  0.4135025740089796  | validation loss is :  0.39655973006145484
# Training accuracy after  500  sgd steps is :  91.97080291970804 %  | validation accuracy is :  89.78102189781022 %
#
# Training loss after  1000  sgd steps is :  0.3130793338844657  | validation loss is :  0.2992398370248983
# Training accuracy after  1000  sgd steps is :  94.16058394160584 %  | validation accuracy is :  94.16058394160584 %
#
# Training loss after  1500  sgd steps is :  0.25847261031621266  | validation loss is :  0.24316747482601464
# Training accuracy after  1500  sgd steps is :  96.03753910323253 %  | validation accuracy is :  96.35036496350365 %
#
# Training loss after  2000  sgd steps is :  0.22309766405920944  | validation loss is :  0.20620897377765834
# Training accuracy after  2000  sgd steps is :  96.35036496350365 %  | validation accuracy is :  97.08029197080292 %
#
# Training loss after  2500  sgd steps is :  0.19485500514154297  | validation loss is :  0.1786622785098632
# Training accuracy after  2500  sgd steps is :  97.288842544317 %  | validation accuracy is :  98.54014598540147 %
#
# Training loss after  3000  sgd steps is :  0.1754536415440645  | validation loss is :  0.15912113312929801
# Training accuracy after  3000  sgd steps is :  97.39311783107404 %  | validation accuracy is :  98.54014598540147 %
#
# Training loss after  3500  sgd steps is :  0.16032509927776156  | validation loss is :  0.14521738441402657
# Training accuracy after  3500  sgd steps is :  97.39311783107404 %  | validation accuracy is :  98.54014598540147 %
#
# Training loss after  4000  sgd steps is :  0.14850468965156455  | validation loss is :  0.13507175618550504
# Training accuracy after  4000  sgd steps is :  97.60166840458811 %  | validation accuracy is :  98.54014598540147 %
#
# Training loss after  4500  sgd steps is :  0.13914223479692392  | validation loss is :  0.12466432915813698
# Training accuracy after  4500  sgd steps is :  98.01876955161627 %  | validation accuracy is :  98.54014598540147 %
#
# Training loss after  5000  sgd steps is :  0.13110410502776693  | validation loss is :  0.11770692286953231
# Training accuracy after  5000  sgd steps is :  98.01876955161627 %  | validation accuracy is :  98.54014598540147 %
#
# Training loss after  5500  sgd steps is :  0.12420876312086783  | validation loss is :  0.1098068862520361
# Training accuracy after  5500  sgd steps is :  97.91449426485923 %  | validation accuracy is :  98.54014598540147 %
#
# Training loss after  6000  sgd steps is :  0.11770019716592323  | validation loss is :  0.10418755289603726
# Training accuracy after  6000  sgd steps is :  98.01876955161627 %  | validation accuracy is :  98.54014598540147 %
#
# Training loss after  6500  sgd steps is :  0.11267180278567311  | validation loss is :  0.09906457654209438
# Training accuracy after  6500  sgd steps is :  98.22732012513035 %  | validation accuracy is :  98.54014598540147 %
#
# Training loss after  7000  sgd steps is :  0.1088706443231285  | validation loss is :  0.0947615127723911
# Training accuracy after  7000  sgd steps is :  97.91449426485923 %  | validation accuracy is :  98.54014598540147 %
#
# Training loss after  7500  sgd steps is :  0.10432496119769484  | validation loss is :  0.09129481623828485
# Training accuracy after  7500  sgd steps is :  98.01876955161627 %  | validation accuracy is :  98.54014598540147 %
#
# Training loss after  8000  sgd steps is :  0.10037271778835333  | validation loss is :  0.0867139541762768
# Training accuracy after  8000  sgd steps is :  98.33159541188738 %  | validation accuracy is :  98.54014598540147 %
#
# Training loss after  8500  sgd steps is :  0.09720505065963671  | validation loss is :  0.08447326292516753
# Training accuracy after  8500  sgd steps is :  98.22732012513035 %  | validation accuracy is :  98.54014598540147 %
#
# Training loss after  9000  sgd steps is :  0.09406039579531555  | validation loss is :  0.08103212859692291
# Training accuracy after  9000  sgd steps is :  98.43587069864442 %  | validation accuracy is :  98.54014598540147 %
#
# Training loss after  9500  sgd steps is :  0.09137139168173238  | validation loss is :  0.07844118696398661
# Training accuracy after  9500  sgd steps is :  98.43587069864442 %  | validation accuracy is :  98.54014598540147 %
# [[-4.32006635]
#  [-2.50500355]
#  [-2.71346275]
#  [-0.18046969]]
# [[0.06249786]]
#  -------------------------------------------------------------------------------------------
#
#  For learning rate  10 ------------------------------------------------------------
#
# Training loss after  0  sgd steps is :  0.6931469805599655  | validation loss is :  0.6931469805599654
# Training accuracy after  0  sgd steps is :  45.04692387904067 %  | validation accuracy is :  38.68613138686131 %
#
# Training loss after  500  sgd steps is :  0.09095872026025917  | validation loss is :  0.05924576747121743
# Training accuracy after  500  sgd steps is :  98.54014598540147 %  | validation accuracy is :  99.27007299270073 %
#
# Training loss after  1000  sgd steps is :  0.22719573460892212  | validation loss is :  0.17283480284100394
# Training accuracy after  1000  sgd steps is :  98.22732012513035 %  | validation accuracy is :  97.08029197080292 %
#
# Training loss after  1500  sgd steps is :  0.34487241156087994  | validation loss is :  0.2926661611168111
# Training accuracy after  1500  sgd steps is :  97.08029197080292 %  | validation accuracy is :  96.35036496350365 %
#
# Training loss after  2000  sgd steps is :  0.06238757515502463  | validation loss is :  0.07932558565891246
# Training accuracy after  2000  sgd steps is :  98.54014598540147 %  | validation accuracy is :  99.27007299270073 %
#
# Training loss after  2500  sgd steps is :  0.25769949320311386  | validation loss is :  0.18709771159918429
# Training accuracy after  2500  sgd steps is :  97.8102189781022 %  | validation accuracy is :  97.8102189781022 %
#
# Training loss after  3000  sgd steps is :  0.20164958949542822  | validation loss is :  0.11760969614588432
# Training accuracy after  3000  sgd steps is :  98.33159541188738 %  | validation accuracy is :  99.27007299270073 %
#
# Training loss after  3500  sgd steps is :  0.15060902039292914  | validation loss is :  0.0618687446826674
# Training accuracy after  3500  sgd steps is :  98.43587069864442 %  | validation accuracy is :  98.54014598540147 %
#
# Training loss after  4000  sgd steps is :  0.25411630483854114  | validation loss is :  0.11769669612007316
# Training accuracy after  4000  sgd steps is :  97.8102189781022 %  | validation accuracy is :  99.27007299270073 %
#
# Training loss after  4500  sgd steps is :  0.05785750944737639  | validation loss is :  0.10894984278593832
# Training accuracy after  4500  sgd steps is :  98.6444212721585 %  | validation accuracy is :  99.27007299270073 %
#
# Training loss after  5000  sgd steps is :  0.2637148445083147  | validation loss is :  0.2150344575948722
# Training accuracy after  5000  sgd steps is :  98.01876955161627 %  | validation accuracy is :  97.08029197080292 %
#
# Training loss after  5500  sgd steps is :  0.2794515455402687  | validation loss is :  0.11765025641616099
# Training accuracy after  5500  sgd steps is :  97.70594369134515 %  | validation accuracy is :  99.27007299270073 %
#
# Training loss after  6000  sgd steps is :  0.3348967930013529  | validation loss is :  0.31089816382275265
# Training accuracy after  6000  sgd steps is :  97.39311783107404 %  | validation accuracy is :  96.35036496350365 %
#
# Training loss after  6500  sgd steps is :  0.3246916658386852  | validation loss is :  0.1176502344033065
# Training accuracy after  6500  sgd steps is :  97.60166840458811 %  | validation accuracy is :  99.27007299270073 %
#
# Training loss after  7000  sgd steps is :  0.3785525081297033  | validation loss is :  0.11768790951450223
# Training accuracy after  7000  sgd steps is :  97.39311783107404 %  | validation accuracy is :  99.27007299270073 %
#
# Training loss after  7500  sgd steps is :  0.23977450409186038  | validation loss is :  0.1176502547141521
# Training accuracy after  7500  sgd steps is :  98.1230448383733 %  | validation accuracy is :  99.27007299270073 %
#
# Training loss after  8000  sgd steps is :  0.19904509344784774  | validation loss is :  0.08562716967657175
# Training accuracy after  8000  sgd steps is :  98.1230448383733 %  | validation accuracy is :  98.54014598540147 %
#
# Training loss after  8500  sgd steps is :  0.48662026591503754  | validation loss is :  0.26348477625058164
# Training accuracy after  8500  sgd steps is :  95.9332638164755 %  | validation accuracy is :  97.8102189781022 %
#
# Training loss after  9000  sgd steps is :  0.29323086738643844  | validation loss is :  0.2921859458981061
# Training accuracy after  9000  sgd steps is :  97.8102189781022 %  | validation accuracy is :  97.8102189781022 %
#
# Training loss after  9500  sgd steps is :  0.4609607774942761  | validation loss is :  0.19726055072739054
# Training accuracy after  9500  sgd steps is :  96.66319082377477 %  | validation accuracy is :  97.08029197080292 %
# [[-180.77856205]
#  [-124.83593429]
#  [-123.14929285]
#  [ -11.48744616]]
# [[-25.42595552]]
#  -------------------------------------------------------------------------------------------

# %%
"""Running BGD on Banknote dataset and with LR = 0.0001, 0.01, 10"""
L = [0.0001, 0.0001,0.01,10]
Epochs = [10000,400000, 10000, 10000]

# %%
for i in range(4):
    print("\n For learning rate ", L[i], "------------------------------------------------------------ ")
    log_regressor_bgd = MyLogisticRegression()
    log_regressor_bgd.fit(X_train, y_train, X_val, y_val, epochs = Epochs[i] ,learning_rate = L[i], grad_type = "bgd")
    print(log_regressor_bgd.W)
    print(log_regressor_bgd.b)
    loss_history_bgd = log_regressor_bgd.loss_history
    val_loss_history_bgd = log_regressor_bgd.val_loss_history
    train_acc_history_bgd = log_regressor_bgd.train_acc_history
    val_acc_history_bgd = log_regressor_bgd.val_acc_history
    plt.plot([x for x in range(len(loss_history_bgd))], loss_history_bgd, label = "Training  Loss " )
    plt.plot([x for x in range(len(val_loss_history_bgd))], val_loss_history_bgd, label = "Validation  Loss")
    plt.xlabel('epochs')
    plt.ylabel('loss')
    plt.legend()
    plt.show()
    plt.plot([x for x in range(len(train_acc_history_bgd))], train_acc_history_bgd, label = "Training  accuracy " )
    plt.plot([x for x in range(len(val_acc_history_bgd))], val_acc_history_bgd, label = "Validation  accuracy")
    plt.xlabel('epochs')
    plt.ylabel('Accuracy')
    plt.legend()
    plt.show()
    print("\n -------------------------------------------------------------------------------------------")
# Out:
#  For learning rate  0.0001 ------------------------------------------------------------
#
# Training loss after  0  bgd steps is :  0.6931469805599655  | validation loss is :  0.6931469805599654
# Training accuracy after  0  bgd steps is :  45.04692387904067 %  | validation accuracy is :  38.68613138686131 %
#
# Training loss after  500  bgd steps is :  0.6846722097947422  | validation loss is :  0.6840016968229867
# Training accuracy after  500  bgd steps is :  68.82168925964547 %  | validation accuracy is :  71.53284671532847 %
#
# Training loss after  1000  bgd steps is :  0.676630168067112  | validation loss is :  0.6753319540196963
# Training accuracy after  1000  bgd steps is :  69.03023983315954 %  | validation accuracy is :  71.53284671532847 %
#
# Training loss after  1500  bgd steps is :  0.6689910871728904  | validation loss is :  0.6671050401891278
# Training accuracy after  1500  bgd steps is :  69.23879040667362 %  | validation accuracy is :  71.53284671532847 %
#
# Training loss after  2000  bgd steps is :  0.6617270242963703  | validation loss is :  0.6592902334517617
# Training accuracy after  2000  bgd steps is :  69.34306569343065 %  | validation accuracy is :  71.53284671532847 %
#
# Training loss after  2500  bgd steps is :  0.6548118306452143  | validation loss is :  0.6518587727601561
# Training accuracy after  2500  bgd steps is :  69.4473409801877 %  | validation accuracy is :  71.53284671532847 %
#
# Training loss after  3000  bgd steps is :  0.6482211009719822  | validation loss is :  0.6447838064102761
# Training accuracy after  3000  bgd steps is :  69.4473409801877 %  | validation accuracy is :  71.53284671532847 %
#
# Training loss after  3500  bgd steps is :  0.6419321087571653  | validation loss is :  0.6380403237845524
# Training accuracy after  3500  bgd steps is :  69.65589155370178 %  | validation accuracy is :  72.26277372262774 %
#
# Training loss after  4000  bgd steps is :  0.635923731178443  | validation loss is :  0.6316050750584046
# Training accuracy after  4000  bgd steps is :  69.76016684045881 %  | validation accuracy is :  72.26277372262774 %
#
# Training loss after  4500  bgd steps is :  0.6301763673434901  | validation loss is :  0.6254564828634306
# Training accuracy after  4500  bgd steps is :  69.86444212721585 %  | validation accuracy is :  72.26277372262774 %
#
# Training loss after  5000  bgd steps is :  0.6246718526509536  | validation loss is :  0.6195745492001374
# Training accuracy after  5000  bgd steps is :  70.17726798748696 %  | validation accuracy is :  72.99270072992701 %
#
# Training loss after  5500  bgd steps is :  0.619393371585895  | validation loss is :  0.613940760254251
# Training accuracy after  5500  bgd steps is :  70.281543274244 %  | validation accuracy is :  72.99270072992701 %
#
# Training loss after  6000  bgd steps is :  0.6143253707623784  | validation loss is :  0.6085379912054484
# Training accuracy after  6000  bgd steps is :  70.49009384775809 %  | validation accuracy is :  73.72262773722628 %
#
# Training loss after  6500  bgd steps is :  0.60945347360025  | validation loss is :  0.6033504126298412
# Training accuracy after  6500  bgd steps is :  70.59436913451512 %  | validation accuracy is :  73.72262773722628 %
#
# Training loss after  7000  bgd steps is :  0.6047643976640386  | validation loss is :  0.598363399686111
# Training accuracy after  7000  bgd steps is :  70.69864442127216 %  | validation accuracy is :  74.45255474452554 %
#
# Training loss after  7500  bgd steps is :  0.6002458753947428  | validation loss is :  0.5935634449347194
# Training accuracy after  7500  bgd steps is :  70.8029197080292 %  | validation accuracy is :  74.45255474452554 %
#
# Training loss after  8000  bgd steps is :  0.5958865787238571  | validation loss is :  0.5889380753629688
# Training accuracy after  8000  bgd steps is :  71.01147028154328 %  | validation accuracy is :  75.18248175182481 %
#
# Training loss after  8500  bgd steps is :  0.591676047866319  | validation loss is :  0.5844757739678722
# Training accuracy after  8500  bgd steps is :  71.11574556830031 %  | validation accuracy is :  75.91240875912408 %
#
# Training loss after  9000  bgd steps is :  0.5876046244381208  | validation loss is :  0.5801659060757538
# Training accuracy after  9000  bgd steps is :  71.22002085505736 %  | validation accuracy is :  76.64233576642336 %
#
# Training loss after  9500  bgd steps is :  0.5836633889284062  | validation loss is :  0.5759986504445361
# Training accuracy after  9500  bgd steps is :  71.6371220020855 %  | validation accuracy is :  77.37226277372262 %
# [[-0.21925326]
#  [-0.24602219]
#  [ 0.02838119]
#  [ 0.00192891]]
# -0.03681746356243362
#  -------------------------------------------------------------------------------------------
#
#  For learning rate  0.0001 ------------------------------------------------------------
#
# Training loss after  0  bgd steps is :  0.6931469805599655  | validation loss is :  0.6931469805599654
# Training accuracy after  0  bgd steps is :  45.04692387904067 %  | validation accuracy is :  38.68613138686131 %
#
# Training loss after  20000  bgd steps is :  0.5205768760838353  | validation loss is :  0.5099819434575673
# Training accuracy after  20000  bgd steps is :  75.3910323253389 %  | validation accuracy is :  83.21167883211679 %
#
# Training loss after  40000  bgd steps is :  0.4446731044305447  | validation loss is :  0.4319751156022192
# Training accuracy after  40000  bgd steps is :  86.02711157455683 %  | validation accuracy is :  86.86131386861314 %
#
# Training loss after  60000  bgd steps is :  0.3911970318007886  | validation loss is :  0.3774003772474368
# Training accuracy after  60000  bgd steps is :  90.51094890510949 %  | validation accuracy is :  88.32116788321169 %
#
# Training loss after  80000  bgd steps is :  0.35018293691182617  | validation loss is :  0.3356157547082535
# Training accuracy after  80000  bgd steps is :  92.17935349322211 %  | validation accuracy is :  91.24087591240875 %
#
# Training loss after  100000  bgd steps is :  0.3176503611032191  | validation loss is :  0.3025547554690128
# Training accuracy after  100000  bgd steps is :  94.05630865484879 %  | validation accuracy is :  94.16058394160584 %
#
# Training loss after  120000  bgd steps is :  0.2912373443948372  | validation loss is :  0.27581621615128593
# Training accuracy after  120000  bgd steps is :  94.8905109489051 %  | validation accuracy is :  95.62043795620438 %
#
# Training loss after  140000  bgd steps is :  0.26938624308979675  | validation loss is :  0.2537990794252671
# Training accuracy after  140000  bgd steps is :  95.9332638164755 %  | validation accuracy is :  96.35036496350365 %
#
# Training loss after  160000  bgd steps is :  0.25102277914904064  | validation loss is :  0.23538713377119655
# Training accuracy after  160000  bgd steps is :  96.55891553701773 %  | validation accuracy is :  96.35036496350365 %
#
# Training loss after  180000  bgd steps is :  0.2353825827024143  | validation loss is :  0.2197809171798488
# Training accuracy after  180000  bgd steps is :  96.76746611053181 %  | validation accuracy is :  97.08029197080292 %
#
# Training loss after  200000  bgd steps is :  0.2219075715437008  | validation loss is :  0.20639527627123988
# Training accuracy after  200000  bgd steps is :  96.87174139728884 %  | validation accuracy is :  97.08029197080292 %
#
# Training loss after  220000  bgd steps is :  0.21018112418794602  | validation loss is :  0.19479365242758512
# Training accuracy after  220000  bgd steps is :  96.87174139728884 %  | validation accuracy is :  97.8102189781022 %
#
# Training loss after  240000  bgd steps is :  0.19988615157163467  | validation loss is :  0.1846446861487873
# Training accuracy after  240000  bgd steps is :  97.18456725755996 %  | validation accuracy is :  98.54014598540147 %
#
# Training loss after  260000  bgd steps is :  0.1907771966309311  | validation loss is :  0.17569290782750574
# Training accuracy after  260000  bgd steps is :  97.288842544317 %  | validation accuracy is :  98.54014598540147 %
#
# Training loss after  280000  bgd steps is :  0.1826613936613696  | validation loss is :  0.16773854466439084
# Training accuracy after  280000  bgd steps is :  97.288842544317 %  | validation accuracy is :  98.54014598540147 %
#
# Training loss after  300000  bgd steps is :  0.17538517773281576  | validation loss is :  0.16062335149305723
# Training accuracy after  300000  bgd steps is :  97.39311783107404 %  | validation accuracy is :  98.54014598540147 %
#
# Training loss after  320000  bgd steps is :  0.16882481886910283  | validation loss is :  0.1542204984698349
# Training accuracy after  320000  bgd steps is :  97.60166840458811 %  | validation accuracy is :  98.54014598540147 %
#
# Training loss after  340000  bgd steps is :  0.1628795575458577  | validation loss is :  0.1484272397070228
# Training accuracy after  340000  bgd steps is :  97.60166840458811 %  | validation accuracy is :  98.54014598540147 %
#
# Training loss after  360000  bgd steps is :  0.15746654529082343  | validation loss is :  0.14315952008488525
# Training accuracy after  360000  bgd steps is :  97.60166840458811 %  | validation accuracy is :  98.54014598540147 %
#
# Training loss after  380000  bgd steps is :  0.15251706080970467  | validation loss is :  0.13834795398380548
# Training accuracy after  380000  bgd steps is :  97.70594369134515 %  | validation accuracy is :  98.54014598540147 %
# [[-3.02915075]
#  [-1.70655147]
#  [-1.70433247]
#  [-0.30291981]]
# -0.008189693030550947
#  -------------------------------------------------------------------------------------------
#
#  For learning rate  0.01 ------------------------------------------------------------
#
# Training loss after  0  bgd steps is :  0.6931469805599655  | validation loss is :  0.6931469805599654
# Training accuracy after  0  bgd steps is :  45.04692387904067 %  | validation accuracy is :  38.68613138686131 %
#
# Training loss after  500  bgd steps is :  0.4159555881543855  | validation loss is :  0.40265325386554435
# Training accuracy after  500  bgd steps is :  88.52971845672576 %  | validation accuracy is :  86.86131386861314 %
#
# Training loss after  1000  bgd steps is :  0.31760232347513523  | validation loss is :  0.3025048157314157
# Training accuracy after  1000  bgd steps is :  94.05630865484879 %  | validation accuracy is :  94.16058394160584 %
#
# Training loss after  1500  bgd steps is :  0.2597828458984282  | validation loss is :  0.24415730024842894
# Training accuracy after  1500  bgd steps is :  96.14181438998958 %  | validation accuracy is :  96.35036496350365 %
#
# Training loss after  2000  bgd steps is :  0.22187550205616582  | validation loss is :  0.20636197153850022
# Training accuracy after  2000  bgd steps is :  96.87174139728884 %  | validation accuracy is :  97.08029197080292 %
#
# Training loss after  2500  bgd steps is :  0.1951700111955153  | validation loss is :  0.18000551027309636
# Training accuracy after  2500  bgd steps is :  97.288842544317 %  | validation accuracy is :  98.54014598540147 %
#
# Training loss after  3000  bgd steps is :  0.17536291216312183  | validation loss is :  0.1606007173858709
# Training accuracy after  3000  bgd steps is :  97.39311783107404 %  | validation accuracy is :  98.54014598540147 %
#
# Training loss after  3500  bgd steps is :  0.16009214483978573  | validation loss is :  0.1457132177014468
# Training accuracy after  3500  bgd steps is :  97.60166840458811 %  | validation accuracy is :  98.54014598540147 %
#
# Training loss after  4000  bgd steps is :  0.14795728108184528  | validation loss is :  0.13391841618734793
# Training accuracy after  4000  bgd steps is :  97.91449426485923 %  | validation accuracy is :  98.54014598540147 %
#
# Training loss after  4500  bgd steps is :  0.13807748492467448  | validation loss is :  0.12433096993350785
# Training accuracy after  4500  bgd steps is :  97.91449426485923 %  | validation accuracy is :  98.54014598540147 %
#
# Training loss after  5000  bgd steps is :  0.12987211863406503  | validation loss is :  0.11637325571772021
# Training accuracy after  5000  bgd steps is :  98.22732012513035 %  | validation accuracy is :  98.54014598540147 %
#
# Training loss after  5500  bgd steps is :  0.12294349480733037  | validation loss is :  0.10965303304862645
# Training accuracy after  5500  bgd steps is :  98.01876955161627 %  | validation accuracy is :  98.54014598540147 %
#
# Training loss after  6000  bgd steps is :  0.11701040107221973  | validation loss is :  0.10389488571579392
# Training accuracy after  6000  bgd steps is :  98.01876955161627 %  | validation accuracy is :  98.54014598540147 %
#
# Training loss after  6500  bgd steps is :  0.11186853758461736  | validation loss is :  0.0988998620051829
# Training accuracy after  6500  bgd steps is :  98.1230448383733 %  | validation accuracy is :  98.54014598540147 %
#
# Training loss after  7000  bgd steps is :  0.10736599464455311  | validation loss is :  0.0945207029995693
# Training accuracy after  7000  bgd steps is :  98.1230448383733 %  | validation accuracy is :  98.54014598540147 %
#
# Training loss after  7500  bgd steps is :  0.10338751693557463  | validation loss is :  0.09064608474750929
# Training accuracy after  7500  bgd steps is :  98.1230448383733 %  | validation accuracy is :  98.54014598540147 %
#
# Training loss after  8000  bgd steps is :  0.0998440992862106  | validation loss is :  0.08719027884600902
# Training accuracy after  8000  bgd steps is :  98.22732012513035 %  | validation accuracy is :  98.54014598540147 %
#
# Training loss after  8500  bgd steps is :  0.09666592533639085  | validation loss is :  0.08408618187954664
# Training accuracy after  8500  bgd steps is :  98.22732012513035 %  | validation accuracy is :  98.54014598540147 %
#
# Training loss after  9000  bgd steps is :  0.09379746326544146  | validation loss is :  0.08128050234439134
# Training accuracy after  9000  bgd steps is :  98.22732012513035 %  | validation accuracy is :  98.54014598540147 %
#
# Training loss after  9500  bgd steps is :  0.09119398914279395  | validation loss is :  0.07873036592325892
# Training accuracy after  9500  bgd steps is :  98.22732012513035 %  | validation accuracy is :  98.54014598540147 %
# [[-4.32738335]
#  [-2.46430225]
#  [-2.75009478]
#  [-0.21773359]]
# 0.09472497102526312
#  -------------------------------------------------------------------------------------------
#
#  For learning rate  10 ------------------------------------------------------------
#
# Training loss after  0  bgd steps is :  0.6931469805599655  | validation loss is :  0.6931469805599654
# Training accuracy after  0  bgd steps is :  45.04692387904067 %  | validation accuracy is :  38.68613138686131 %
#
# Training loss after  500  bgd steps is :  0.02756118869988163  | validation loss is :  0.01886025964663917
# Training accuracy after  500  bgd steps is :  98.85297184567257 %  | validation accuracy is :  99.27007299270073 %
#
# Training loss after  1000  bgd steps is :  0.024961453861280736  | validation loss is :  0.018056054205253823
# Training accuracy after  1000  bgd steps is :  98.74869655891554 %  | validation accuracy is :  99.27007299270073 %
#
# Training loss after  1500  bgd steps is :  0.023769470923946236  | validation loss is :  0.018043002755231533
# Training accuracy after  1500  bgd steps is :  98.74869655891554 %  | validation accuracy is :  99.27007299270073 %
#
# Training loss after  2000  bgd steps is :  0.023056904435479846  | validation loss is :  0.01819776095557825
# Training accuracy after  2000  bgd steps is :  98.74869655891554 %  | validation accuracy is :  99.27007299270073 %
#
# Training loss after  2500  bgd steps is :  0.02257680631761796  | validation loss is :  0.01839823583948335
# Training accuracy after  2500  bgd steps is :  98.6444212721585 %  | validation accuracy is :  99.27007299270073 %
#
# Training loss after  3000  bgd steps is :  0.022230198149549747  | validation loss is :  0.01860813134092609
# Training accuracy after  3000  bgd steps is :  98.54014598540147 %  | validation accuracy is :  99.27007299270073 %
#
# Training loss after  3500  bgd steps is :  0.02196839194596263  | validation loss is :  0.018814487002032386
# Training accuracy after  3500  bgd steps is :  98.54014598540147 %  | validation accuracy is :  99.27007299270073 %
#
# Training loss after  4000  bgd steps is :  0.02176421854320825  | validation loss is :  0.019012373739718445
# Training accuracy after  4000  bgd steps is :  98.54014598540147 %  | validation accuracy is :  99.27007299270073 %
#
# Training loss after  4500  bgd steps is :  0.021601152377495332  | validation loss is :  0.01920003863946886
# Training accuracy after  4500  bgd steps is :  98.54014598540147 %  | validation accuracy is :  99.27007299270073 %
#
# Training loss after  5000  bgd steps is :  0.021468490460173097  | validation loss is :  0.0193770918992655
# Training accuracy after  5000  bgd steps is :  98.54014598540147 %  | validation accuracy is :  99.27007299270073 %
#
# Training loss after  5500  bgd steps is :  0.021358961303008198  | validation loss is :  0.01954375050499622
# Training accuracy after  5500  bgd steps is :  98.54014598540147 %  | validation accuracy is :  99.27007299270073 %
#
# Training loss after  6000  bgd steps is :  0.021267435249057748  | validation loss is :  0.01970049760761046
# Training accuracy after  6000  bgd steps is :  98.54014598540147 %  | validation accuracy is :  99.27007299270073 %
#
# Training loss after  6500  bgd steps is :  0.021190181941360037  | validation loss is :  0.01984792113037147
# Training accuracy after  6500  bgd steps is :  98.54014598540147 %  | validation accuracy is :  99.27007299270073 %
#
# Training loss after  7000  bgd steps is :  0.021124419836983606  | validation loss is :  0.01998663515570503
# Training accuracy after  7000  bgd steps is :  98.54014598540147 %  | validation accuracy is :  99.27007299270073 %
#
# Training loss after  7500  bgd steps is :  0.021068030912323246  | validation loss is :  0.0201172415591449
# Training accuracy after  7500  bgd steps is :  98.54014598540147 %  | validation accuracy is :  99.27007299270073 %
#
# Training loss after  8000  bgd steps is :  0.021019373386096222  | validation loss is :  0.020240311942768527
# Training accuracy after  8000  bgd steps is :  99.06152241918666 %  | validation accuracy is :  99.27007299270073 %
#
# Training loss after  8500  bgd steps is :  0.02097715498703789  | validation loss is :  0.0203563800449012
# Training accuracy after  8500  bgd steps is :  99.06152241918666 %  | validation accuracy is :  99.27007299270073 %
#
# Training loss after  9000  bgd steps is :  0.02094034492255275  | validation loss is :  0.02046593960018023
# Training accuracy after  9000  bgd steps is :  99.06152241918666 %  | validation accuracy is :  99.27007299270073 %
#
# Training loss after  9500  bgd steps is :  0.02090811132721569  | validation loss is :  0.020569445003227653
# Training accuracy after  9500  bgd steps is :  99.06152241918666 %  | validation accuracy is :  99.27007299270073 %
# [[-28.35673936]
#  [-14.99561312]
#  [-18.8477103 ]
#  [ -1.7048779 ]]
# -3.351112968791918
#  -------------------------------------------------------------------------------------------

# %%
"Custom learning rate chosen by hit and trial"
# Out:
# 'Custom learning rate chosen by hit and trial'

# %%
""" SGD on 0.005 learning rate"""
log_regressor_sgd = MyLogisticRegression()
log_regressor_sgd.fit(X_train, y_train, X_val, y_val, epochs = 10000 ,learning_rate = 0.05, grad_type = "sgd")
print(log_regressor_sgd.W)
print(log_regressor_sgd.b)
loss_history_sgd = log_regressor_sgd.loss_history
val_loss_history_sgd = log_regressor_sgd.val_loss_history
train_acc_history_sgd = log_regressor_sgd.train_acc_history
val_acc_history_sgd = log_regressor_sgd.val_acc_history
plt.plot([x for x in range(len(loss_history_sgd))], loss_history_sgd, label = "Training  loss " )
plt.plot([x for x in range(len(val_loss_history_sgd))], val_loss_history_sgd, label = "Validation  loss")
plt.xlabel('epochs')
plt.ylabel('loss')
plt.legend()
plt.show()
plt.plot([x for x in range(len(train_acc_history_sgd))], train_acc_history_sgd, label = "Training  accuracy " )
plt.plot([x for x in range(len(val_acc_history_sgd))], val_acc_history_sgd, label = "Validation  accuracy")
plt.xlabel('epochs')
plt.ylabel('accuracy')
plt.legend()
plt.show()
# Out:
# Training loss after  0  sgd steps is :  0.6931469805599655  | validation loss is :  0.6931469805599654
# Training accuracy after  0  sgd steps is :  45.04692387904067 %  | validation accuracy is :  38.68613138686131 %
#
# Training loss after  500  sgd steps is :  0.19375168807849588  | validation loss is :  0.18219299225306262
# Training accuracy after  500  sgd steps is :  97.39311783107404 %  | validation accuracy is :  97.08029197080292 %
#
# Training loss after  1000  sgd steps is :  0.12793888455005725  | validation loss is :  0.11622024747380555
# Training accuracy after  1000  sgd steps is :  98.1230448383733 %  | validation accuracy is :  98.54014598540147 %
#
# Training loss after  1500  sgd steps is :  0.10182090571705042  | validation loss is :  0.08995949829807948
# Training accuracy after  1500  sgd steps is :  97.91449426485923 %  | validation accuracy is :  98.54014598540147 %
#
# Training loss after  2000  sgd steps is :  0.08749332694491682  | validation loss is :  0.07451976876894509
# Training accuracy after  2000  sgd steps is :  98.1230448383733 %  | validation accuracy is :  98.54014598540147 %
#
# Training loss after  2500  sgd steps is :  0.07868572676530806  | validation loss is :  0.06729496541560133
# Training accuracy after  2500  sgd steps is :  98.22732012513035 %  | validation accuracy is :  99.27007299270073 %
#
# Training loss after  3000  sgd steps is :  0.07293558147245727  | validation loss is :  0.059763303082317226
# Training accuracy after  3000  sgd steps is :  98.6444212721585 %  | validation accuracy is :  98.54014598540147 %
#
# Training loss after  3500  sgd steps is :  0.06752007048157793  | validation loss is :  0.05537252610951345
# Training accuracy after  3500  sgd steps is :  98.33159541188738 %  | validation accuracy is :  98.54014598540147 %
#
# Training loss after  4000  sgd steps is :  0.06413406189341309  | validation loss is :  0.05265561483282442
# Training accuracy after  4000  sgd steps is :  98.33159541188738 %  | validation accuracy is :  98.54014598540147 %
#
# Training loss after  4500  sgd steps is :  0.06081679746328976  | validation loss is :  0.04873402442296127
# Training accuracy after  4500  sgd steps is :  98.33159541188738 %  | validation accuracy is :  98.54014598540147 %
#
# Training loss after  5000  sgd steps is :  0.058972494232717124  | validation loss is :  0.046974359745351246
# Training accuracy after  5000  sgd steps is :  98.22732012513035 %  | validation accuracy is :  99.27007299270073 %
#
# Training loss after  5500  sgd steps is :  0.05644863379606066  | validation loss is :  0.04368286147194046
# Training accuracy after  5500  sgd steps is :  98.6444212721585 %  | validation accuracy is :  98.54014598540147 %
#
# Training loss after  6000  sgd steps is :  0.054865503049703085  | validation loss is :  0.041598708591755094
# Training accuracy after  6000  sgd steps is :  98.6444212721585 %  | validation accuracy is :  98.54014598540147 %
#
# Training loss after  6500  sgd steps is :  0.052618380315429536  | validation loss is :  0.04104452929340668
# Training accuracy after  6500  sgd steps is :  98.33159541188738 %  | validation accuracy is :  98.54014598540147 %
#
# Training loss after  7000  sgd steps is :  0.05119566360180118  | validation loss is :  0.03888589379758818
# Training accuracy after  7000  sgd steps is :  98.33159541188738 %  | validation accuracy is :  98.54014598540147 %
#
# Training loss after  7500  sgd steps is :  0.05066583717284461  | validation loss is :  0.03809267962206061
# Training accuracy after  7500  sgd steps is :  98.33159541188738 %  | validation accuracy is :  98.54014598540147 %
#
# Training loss after  8000  sgd steps is :  0.04997607216469722  | validation loss is :  0.03883775052510009
# Training accuracy after  8000  sgd steps is :  98.33159541188738 %  | validation accuracy is :  99.27007299270073 %
#
# Training loss after  8500  sgd steps is :  0.048128530261987164  | validation loss is :  0.03582720022167951
# Training accuracy after  8500  sgd steps is :  98.33159541188738 %  | validation accuracy is :  98.54014598540147 %
#
# Training loss after  9000  sgd steps is :  0.04706649393341504  | validation loss is :  0.035302541083002646
# Training accuracy after  9000  sgd steps is :  98.33159541188738 %  | validation accuracy is :  98.54014598540147 %
#
# Training loss after  9500  sgd steps is :  0.04675504984288126  | validation loss is :  0.03420104561993742
# Training accuracy after  9500  sgd steps is :  98.54014598540147 %  | validation accuracy is :  98.54014598540147 %
# [[-7.1523119 ]
#  [-3.85696262]
#  [-5.04764985]
#  [ 0.22841834]]
# [[0.10648478]]

# %%
log_regressor_bgd = MyLogisticRegression()
log_regressor_bgd.fit(X_train, y_train, X_val, y_val, epochs = 10000 ,learning_rate = 0.05, grad_type = "bgd")
print(log_regressor_bgd.W)
print(log_regressor_bgd.b)
loss_history_bgd = log_regressor_bgd.loss_history
val_loss_history_bgd = log_regressor_bgd.val_loss_history
train_acc_history_bgd = log_regressor_bgd.train_acc_history
val_acc_history_bgd = log_regressor_bgd.val_acc_history
plt.plot([x for x in range(10000)], loss_history_bgd, label = "Training  Loss " )
plt.plot([x for x in range(10000)], val_loss_history_bgd, label = "Validation  Loss")
plt.xlabel('epochs')
plt.ylabel('loss')
plt.legend()
plt.show()
plt.plot([x for x in range(10000)], train_acc_history_bgd, label = "Training  accuracy " )
plt.plot([x for x in range(10000)], val_acc_history_bgd, label = "Validation  accuracy")
plt.xlabel('epochs')
plt.ylabel('accuracy')
plt.legend()
plt.show()
# Out:
# Training loss after  0  bgd steps is :  0.6931469805599655  | validation loss is :  0.6931469805599654
# Training accuracy after  0  bgd steps is :  45.04692387904067 %  | validation accuracy is :  38.68613138686131 %
#
# Training loss after  500  bgd steps is :  0.1950628127381792  | validation loss is :  0.17989539481477435
# Training accuracy after  500  bgd steps is :  97.288842544317 %  | validation accuracy is :  98.54014598540147 %
#
# Training loss after  1000  bgd steps is :  0.12982126872038408  | validation loss is :  0.11632284801643351
# Training accuracy after  1000  bgd steps is :  98.22732012513035 %  | validation accuracy is :  98.54014598540147 %
#
# Training loss after  1500  bgd steps is :  0.10335722178096493  | validation loss is :  0.09061628659187185
# Training accuracy after  1500  bgd steps is :  98.1230448383733 %  | validation accuracy is :  98.54014598540147 %
#
# Training loss after  2000  bgd steps is :  0.08879855697086227  | validation loss is :  0.07638066016697075
# Training accuracy after  2000  bgd steps is :  98.22732012513035 %  | validation accuracy is :  98.54014598540147 %
#
# Training loss after  2500  bgd steps is :  0.07946664015455784  | validation loss is :  0.06719453589227721
# Training accuracy after  2500  bgd steps is :  98.22732012513035 %  | validation accuracy is :  98.54014598540147 %
#
# Training loss after  3000  bgd steps is :  0.0729124202489999  | validation loss is :  0.06071032991678886
# Training accuracy after  3000  bgd steps is :  98.33159541188738 %  | validation accuracy is :  98.54014598540147 %
#
# Training loss after  3500  bgd steps is :  0.06802155640128923  | validation loss is :  0.05585597342353119
# Training accuracy after  3500  bgd steps is :  98.33159541188738 %  | validation accuracy is :  98.54014598540147 %
#
# Training loss after  4000  bgd steps is :  0.06421140951275006  | validation loss is :  0.05206757661005881
# Training accuracy after  4000  bgd steps is :  98.33159541188738 %  | validation accuracy is :  98.54014598540147 %
#
# Training loss after  4500  bgd steps is :  0.06114623173564139  | validation loss is :  0.04901809973506528
# Training accuracy after  4500  bgd steps is :  98.33159541188738 %  | validation accuracy is :  98.54014598540147 %
#
# Training loss after  5000  bgd steps is :  0.05861813670331487  | validation loss is :  0.04650380548602217
# Training accuracy after  5000  bgd steps is :  98.33159541188738 %  | validation accuracy is :  98.54014598540147 %
#
# Training loss after  5500  bgd steps is :  0.056491101374693285  | validation loss is :  0.04439064736201324
# Training accuracy after  5500  bgd steps is :  98.33159541188738 %  | validation accuracy is :  98.54014598540147 %
#
# Training loss after  6000  bgd steps is :  0.05467214658105862  | validation loss is :  0.04258655044572006
# Training accuracy after  6000  bgd steps is :  98.33159541188738 %  | validation accuracy is :  98.54014598540147 %
#
# Training loss after  6500  bgd steps is :  0.05309542123949558  | validation loss is :  0.041026027172931565
# Training accuracy after  6500  bgd steps is :  98.33159541188738 %  | validation accuracy is :  98.54014598540147 %
#
# Training loss after  7000  bgd steps is :  0.051712898177116766  | validation loss is :  0.039661139741760915
# Training accuracy after  7000  bgd steps is :  98.6444212721585 %  | validation accuracy is :  98.54014598540147 %
#
# Training loss after  7500  bgd steps is :  0.05048867407332171  | validation loss is :  0.03845593759220143
# Training accuracy after  7500  bgd steps is :  98.6444212721585 %  | validation accuracy is :  98.54014598540147 %
#
# Training loss after  8000  bgd steps is :  0.04939533756610984  | validation loss is :  0.0373828978372684
# Training accuracy after  8000  bgd steps is :  98.6444212721585 %  | validation accuracy is :  98.54014598540147 %
#
# Training loss after  8500  bgd steps is :  0.048411576592595325  | validation loss is :  0.036420570962717946
# Training accuracy after  8500  bgd steps is :  98.6444212721585 %  | validation accuracy is :  98.54014598540147 %
#
# Training loss after  9000  bgd steps is :  0.04752055621050648  | validation loss is :  0.035551978890150646
# Training accuracy after  9000  bgd steps is :  98.6444212721585 %  | validation accuracy is :  98.54014598540147 %
#
# Training loss after  9500  bgd steps is :  0.04670879098957566  | validation loss is :  0.034763497777172414
# Training accuracy after  9500  bgd steps is :  98.6444212721585 %  | validation accuracy is :  98.54014598540147 %
# [[-7.10514169]
#  [-4.02930148]
#  [-4.82473046]
#  [ 0.18175084]]
# 0.13570700892604548

# %%
"""Exploratory Data Analysis for the BankNote dataset """
# Out:
# 'Exploratory Data Analysis for the BankNote dataset '

# %%
df = pd.read_csv("LoR_dataset/data_banknote_authentication.txt",sep="," , names = ["col1", "col2", "col3", "col4" , "val"])

# %%
df.head()
# Out:
#       col1    col2    col3     col4  val
# 0  3.62160  8.6661 -2.8073 -0.44699    0
# 1  4.54590  8.1674 -2.4586 -1.46210    0
# 2  3.86600 -2.6383  1.9242  0.10645    0
# 3  3.45660  9.5228 -4.0112 -3.59440    0
# 4  0.32924 -4.4552  4.5718 -0.98880    0

# %%
import seaborn as sns
print(df.corr())
sns.heatmap(df.corr(), annot = True)
# Out:
#           col1      col2      col3      col4       val
# col1  1.000000  0.264026 -0.380850  0.276817 -0.724843
# col2  0.264026  1.000000 -0.786895 -0.526321 -0.444688
# col3 -0.380850 -0.786895  1.000000  0.318841  0.155883
# col4  0.276817 -0.526321  0.318841  1.000000 -0.023424
# val  -0.724843 -0.444688  0.155883 -0.023424  1.000000

# %%
df.hist(figsize=(16, 20), bins=50, xlabelsize=8, ylabelsize=8); # ; avoid having the matplotlib verbose informations

# %%
sns.pairplot(df,hue='val',diag_kind="hist")

# %%
print(df)
# Out:
#          col1      col2     col3     col4  val
# 0     3.62160   8.66610  -2.8073 -0.44699    0
# 1     4.54590   8.16740  -2.4586 -1.46210    0
# 2     3.86600  -2.63830   1.9242  0.10645    0
# 3     3.45660   9.52280  -4.0112 -3.59440    0
# 4     0.32924  -4.45520   4.5718 -0.98880    0
# ...       ...       ...      ...      ...  ...
# 1367  0.40614   1.34920  -1.4501 -0.55949    1
# 1368 -1.38870  -4.87730   6.4774  0.34179    1
# 1369 -3.75030 -13.45860  17.5932 -2.77710    1
# 1370 -3.56370  -8.38270  12.3930 -1.28230    1
# 1371 -2.54190  -0.65804   2.6842  1.19520    1
#
# [1372 rows x 5 columns]

# %%
from sklearn.linear_model import LogisticRegression
from sklearn import metrics

# %%
logistic_regression = LogisticRegression(max_iter=10000)
logistic_regression.fit(X_train,y_train)
y_pred = logistic_regression.predict(X_test)
accuracy = metrics.accuracy_score(y_test, y_pred)
print("Accuracy on the test set :",accuracy*100, " %")
y_pred_train = logistic_regression.predict(X_train)
accuracy = metrics.accuracy_score(y_pred_train, y_train)
print("Accuracy Train:",accuracy*100, " %")
# Out:
# Accuracy on the test set : 97.82608695652173  %
# Accuracy Train: 98.33159541188738  %
# C:\Users\Asus\Anaconda3\lib\site-packages\sklearn\linear_model\logistic.py:432: FutureWarning: Default solver will be changed to 'lbfgs' in 0.22. Specify a solver to silence this warning.
#   FutureWarning)
# C:\Users\Asus\Anaconda3\lib\site-packages\sklearn\utils\validation.py:724: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)

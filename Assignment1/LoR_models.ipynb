# %%
import numpy as np
import pandas as pd
from scratch import *
# Out:
# Linear Regression
# Training loss after  0  iterations is  1.5811388300841898
# Training loss after  500  iterations is  0.11522308082978301
# Training loss after  1000  iterations is  0.11531590760055782
# Training loss after  1500  iterations is  0.11540873459346981
# Training loss after  2000  iterations is  0.11550156192142631
# Training loss after  2500  iterations is  0.11559438970508162
# Training loss after  3000  iterations is  0.11568721806509605
# Training loss after  3500  iterations is  0.11578004712213608
# Training loss after  4000  iterations is  0.11587287699688441
# Training loss after  4500  iterations is  0.11596570781002223
# Predicted Values: [[2.76277438]
#  [2.76277438]]
# True Values: [3]

# %%
preprocess = MyPreProcessor()
X,Y=preprocess.pre_process(2)
print(X)
print(Y)
# Out:
# [[ 0.96566702  0.3403972  -0.2160334   0.14170757]
#  [ 0.98585385  1.50520806 -0.6255817  -0.23496538]
#  [ 0.26603092  0.88425551  0.3553179   0.02698897]
#  ...
#  [ 0.33247428  0.14305968  0.84841262  0.06257093]
#  [-0.34911229 -0.14261431 -0.13920248 -0.20674651]
#  [ 0.19927917  1.65982351 -0.81319348 -0.39724044]]
# [[0]
#  [0]
#  [0]
#  ...
#  [0]
#  [1]
#  [0]]

# %%
ratio = X.shape[0]//10
X_train = X[0:7*ratio, :]
y_train = Y[0:7*ratio, :]
X_val = X[7*ratio : 8*ratio, :]
y_val = Y[7*ratio : 8*ratio, :]
X_test = X[8*ratio:, :]
y_test = Y[8*ratio:,:]
print(X_train.shape,y_train.shape )
print(X_test.shape,y_test.shape )
print(X_val.shape, y_val.shape)
# Out:
# (959, 4) (959, 1)
# (276, 4) (276, 1)
# (137, 4) (137, 1)

# %%
pp = MyPreProcessor()
W = pp.get_analytical_sol()
print(W)
X,y = pp.pre_process(0)
bias = np.zeros((X.shape[0],1))
bias.fill(1)
X = np.append(X,bias, axis = 1)
y_pred = np.dot(X,W)
error = (np.sum((y-y_pred)**2)/y_pred.shape[0])**0.5
mae = np.sum(abs(y-y_pred))/y_pred.shape[0]
print(error)
print(mae)
# Out:
# [[ 0.63253946  0.05360612 -0.1569151  ... -0.48247112 -0.40502939
#    1.        ]
#  [ 0.63253946  0.15886672 -0.05165449 ... -0.24563475 -0.17796722
#    1.        ]
#  [ 2.13626242  0.03856889 -0.14187787 ... -0.5629203  -0.37495493
#    1.        ]
#  ...
#  [ 3.63998538 -0.07421034 -0.23210125 ... -0.56968705 -0.54788307
#    1.        ]
#  [ 3.63998538 -0.0065428  -0.19450817 ... -0.58848359 -0.51780861
#    1.        ]
#  [ 2.13626242 -0.2095454  -0.3599177  ... -0.74035961 -0.67569952
#    1.        ]]
# [[ -0.25628631]
#  [ -0.51655077]
#  [  7.900679  ]
#  [  7.50021818]
#  [  6.02815842]
#  [-13.36837538]
#  [ -6.73825106]
#  [  5.79235855]
#  [  9.66007587]]
# 2.1959658591369107
# 1.5831332322027456

# %%
"""Running SGD on Banknote dataset and with LR = 0.0001, 0.01, 10"""
L = [0.0001,0.01,10]

# %%
for i in range(3):
    print("\n For learning rate ", L[i], "------------------------------------------------------------ ")
    log_regressor_sgd = MyLogisticRegression()
    log_regressor_sgd.fit(X_train, y_train, X_val, y_val, epochs = 2000 ,learning_rate = L[i], grad_type = "sgd")
    print(log_regressor_sgd.W)
    print(log_regressor_sgd.b)
    loss_history_sgd = log_regressor_sgd.loss_history
    val_loss_history_sgd = log_regressor_sgd.val_loss_history
    train_acc_history_sgd = log_regressor_sgd.train_acc_history
    val_acc_history_sgd = log_regressor_sgd.val_acc_history
    plt.plot([x for x in range(len(loss_history_sgd))], loss_history_sgd, label = "Training  loss " )
    plt.plot([x for x in range(len(val_loss_history_sgd))], val_loss_history_sgd, label = "Validation  loss")
    plt.xlabel('iterations')
    plt.ylabel('loss')
    plt.legend()
    plt.show()
    plt.plot([x for x in range(len(train_acc_history_sgd))], train_acc_history_sgd, label = "Training  accuracy " )
    plt.plot([x for x in range(len(val_acc_history_sgd))], val_acc_history_sgd, label = "Validation  accuracy")
    plt.xlabel('iterations')
    plt.ylabel('accuracy')
    plt.legend()
    plt.show()
    
    print("\n -------------------------------------------------------------------------------------------")
# Out:
#  For learning rate  0.0001 ------------------------------------------------------------
# (959, 4) 959 4
#
# Training loss after  0  sgd steps is :  0.6931469805599655  | validation loss is :  0.6931469805599654
# Training accuracy after  0  sgd steps is :  45.35974973931178 %  | validation accuracy is :  38.68613138686131 %
#
# Training loss after  500  sgd steps is :  0.6843483342628359  | validation loss is :  0.6846710353965657
# Training accuracy after  500  sgd steps is :  69.65589155370178 %  | validation accuracy is :  67.88321167883211 %
#
# Training loss after  1000  sgd steps is :  0.6765691428641776  | validation loss is :  0.6772934463854116
# Training accuracy after  1000  sgd steps is :  69.86444212721585 %  | validation accuracy is :  70.07299270072993 %
#
# Training loss after  1500  sgd steps is :  0.6688479151328022  | validation loss is :  0.6697270244527656
# Training accuracy after  1500  sgd steps is :  70.07299270072993 %  | validation accuracy is :  70.07299270072993 %
# [[-0.04754951]
#  [-0.06242702]
#  [ 0.01413317]
#  [ 0.00407912]]
# [[-0.00964552]]
#  -------------------------------------------------------------------------------------------
#
#  For learning rate  0.01 ------------------------------------------------------------
# (959, 4) 959 4
#
# Training loss after  0  sgd steps is :  0.6931469805599655  | validation loss is :  0.6931469805599654
# Training accuracy after  0  sgd steps is :  45.35974973931178 %  | validation accuracy is :  38.68613138686131 %
#
# Training loss after  500  sgd steps is :  0.41524102258560225  | validation loss is :  0.42671493063776295
# Training accuracy after  500  sgd steps is :  84.8800834202294 %  | validation accuracy is :  80.2919708029197 %
#
# Training loss after  1000  sgd steps is :  0.3141380018057759  | validation loss is :  0.32659989747733564
# Training accuracy after  1000  sgd steps is :  92.80500521376433 %  | validation accuracy is :  91.97080291970804 %
#
# Training loss after  1500  sgd steps is :  0.2573262570498133  | validation loss is :  0.26812488335476253
# Training accuracy after  1500  sgd steps is :  95.30761209593325 %  | validation accuracy is :  94.16058394160584 %
# [[-2.19919449]
#  [-1.20619326]
#  [-0.87100794]
#  [-0.19334622]]
# [[-0.11523059]]
#  -------------------------------------------------------------------------------------------
#
#  For learning rate  10 ------------------------------------------------------------
# (959, 4) 959 4
#
# Training loss after  0  sgd steps is :  0.6931469805599655  | validation loss is :  0.6931469805599654
# Training accuracy after  0  sgd steps is :  45.35974973931178 %  | validation accuracy is :  38.68613138686131 %
#
# Training loss after  500  sgd steps is :  0.28939369039544866  | validation loss is :  0.05746372626812576
# Training accuracy after  500  sgd steps is :  97.08029197080292 %  | validation accuracy is :  99.27007299270073 %
#
# Training loss after  1000  sgd steps is :  0.3010733828046494  | validation loss is :  0.34420013561287505
# Training accuracy after  1000  sgd steps is :  96.4546402502607 %  | validation accuracy is :  94.16058394160584 %
#
# Training loss after  1500  sgd steps is :  0.5607101398054529  | validation loss is :  0.3505179073248239
# Training accuracy after  1500  sgd steps is :  95.20333680917624 %  | validation accuracy is :  96.35036496350365 %
# [[-112.29679809]
#  [ -73.09079278]
#  [ -63.86026823]
#  [   1.88570539]]
# [[-17.16818459]]
#  -------------------------------------------------------------------------------------------

# %%
"""Running BGD on Banknote dataset and with LR = 0.0001, 0.01, 10"""
L = [0.0001,0.01,10]

# %%
for i in range(3):
    print("\n For learning rate ", L[i], "------------------------------------------------------------ ")
    log_regressor_bgd = MyLogisticRegression()
    log_regressor_bgd.fit(X_train, y_train, X_val, y_val, epochs = 10000 ,learning_rate = L[i], grad_type = "bgd")
    print(log_regressor_bgd.W)
    print(log_regressor_bgd.b)
    loss_history_bgd = log_regressor_bgd.loss_history
    val_loss_history_bgd = log_regressor_bgd.val_loss_history
    train_acc_history_bgd = log_regressor_bgd.train_acc_history
    val_acc_history_bgd = log_regressor_bgd.val_acc_history
    plt.plot([x for x in range(10000)], loss_history_bgd, label = "Training  accuracy " )
    plt.plot([x for x in range(10000)], val_loss_history_bgd, label = "Validation  accuracy")
    plt.xlabel('epochs')
    plt.ylabel('loss')
    plt.legend()
    plt.show()
    plt.plot([x for x in range(10000)], train_acc_history_bgd, label = "Training  accuracy " )
    plt.plot([x for x in range(10000)], val_acc_history_bgd, label = "Validation  accuracy")
    plt.xlabel('epochs')
    plt.ylabel('loss')
    plt.legend()
    plt.show()
    print("\n -------------------------------------------------------------------------------------------")
# Out:
#  For learning rate  0.0001 ------------------------------------------------------------
#
# Training loss after  0  iterations is :  0.6931469805599655  | validation loss is :  0.6931469805599654
# Training accuracy after  0  iterations is :  45.35974973931178 %  | validation accuracy is :  38.68613138686131 %
#
# Training loss after  500  iterations is :  0.6842569524007732  | validation loss is :  0.6845713448069108
# Training accuracy after  500  iterations is :  69.76016684045881 %  | validation accuracy is :  67.88321167883211 %
#
# Training loss after  1000  iterations is :  0.6758252021277675  | validation loss is :  0.6764527643232366
# Training accuracy after  1000  iterations is :  69.76016684045881 %  | validation accuracy is :  68.61313868613139 %
#
# Training loss after  1500  iterations is :  0.6678203656283328  | validation loss is :  0.6687592822730976
# Training accuracy after  1500  iterations is :  69.76016684045881 %  | validation accuracy is :  68.61313868613139 %
#
# Training loss after  2000  iterations is :  0.6602129654587098  | validation loss is :  0.6614608696154838
# Training accuracy after  2000  iterations is :  69.86444212721585 %  | validation accuracy is :  69.34306569343065 %
#
# Training loss after  2500  iterations is :  0.6529753875330612  | validation loss is :  0.6545294078344776
# Training accuracy after  2500  iterations is :  69.86444212721585 %  | validation accuracy is :  70.07299270072993 %
#
# Training loss after  3000  iterations is :  0.6460818358421578  | validation loss is :  0.647938647063107
# Training accuracy after  3000  iterations is :  69.96871741397288 %  | validation accuracy is :  70.07299270072993 %
#
# Training loss after  3500  iterations is :  0.6395082704707546  | validation loss is :  0.6416641453550102
# Training accuracy after  3500  iterations is :  70.07299270072993 %  | validation accuracy is :  70.07299270072993 %
#
# Training loss after  4000  iterations is :  0.6332323334950789  | validation loss is :  0.6356831941488398
# Training accuracy after  4000  iterations is :  70.281543274244 %  | validation accuracy is :  70.07299270072993 %
#
# Training loss after  4500  iterations is :  0.6272332666459116  | validation loss is :  0.6299747342305845
# Training accuracy after  4500  iterations is :  70.281543274244 %  | validation accuracy is :  70.07299270072993 %
#
# Training loss after  5000  iterations is :  0.6214918239566137  | validation loss is :  0.6245192657773616
# Training accuracy after  5000  iterations is :  70.38581856100103 %  | validation accuracy is :  70.07299270072993 %
#
# Training loss after  5500  iterations is :  0.6159901820033881  | validation loss is :  0.6192987553948124
# Training accuracy after  5500  iterations is :  70.38581856100103 %  | validation accuracy is :  70.07299270072993 %
#
# Training loss after  6000  iterations is :  0.6107118498003788  | validation loss is :  0.6142965424575945
# Training accuracy after  6000  iterations is :  70.59436913451512 %  | validation accuracy is :  70.8029197080292 %
#
# Training loss after  6500  iterations is :  0.6056415799400132  | validation loss is :  0.6094972465370624
# Training accuracy after  6500  iterations is :  70.69864442127216 %  | validation accuracy is :  70.8029197080292 %
#
# Training loss after  7000  iterations is :  0.6007652821687334  | validation loss is :  0.6048866772532271
# Training accuracy after  7000  iterations is :  71.01147028154328 %  | validation accuracy is :  70.8029197080292 %
#
# Training loss after  7500  iterations is :  0.5960699402556868  | validation loss is :  0.6004517475158879
# Training accuracy after  7500  iterations is :  71.01147028154328 %  | validation accuracy is :  70.8029197080292 %
#
# Training loss after  8000  iterations is :  0.5915435327406494  | validation loss is :  0.5961803908159613
# Training accuracy after  8000  iterations is :  71.32429614181439 %  | validation accuracy is :  70.8029197080292 %
#
# Training loss after  8500  iterations is :  0.5871749579300963  | validation loss is :  0.5920614829845873
# Training accuracy after  8500  iterations is :  71.42857142857143 %  | validation accuracy is :  70.8029197080292 %
#
# Training loss after  9000  iterations is :  0.5829539633392724  | validation loss is :  0.588084768646225
# Training accuracy after  9000  iterations is :  71.74139728884255 %  | validation accuracy is :  70.8029197080292 %
#
# Training loss after  9500  iterations is :  0.5788710796461093  | validation loss is :  0.5842407924445038
# Training accuracy after  9500  iterations is :  71.94994786235662 %  | validation accuracy is :  70.8029197080292 %
# [[-0.22458196]
#  [-0.25026371]
#  [ 0.0358815 ]
#  [ 0.00476095]]
# -0.03429206730666136
#  -------------------------------------------------------------------------------------------
#
#  For learning rate  0.01 ------------------------------------------------------------
#
# Training loss after  0  iterations is :  0.6931469805599655  | validation loss is :  0.6931469805599654
# Training accuracy after  0  iterations is :  45.35974973931178 %  | validation accuracy is :  38.68613138686131 %
#
# Training loss after  500  iterations is :  0.40825591480677387  | validation loss is :  0.42124606768757195
# Training accuracy after  500  iterations is :  89.57247132429615 %  | validation accuracy is :  80.2919708029197 %
#
# Training loss after  1000  iterations is :  0.3100043382121975  | validation loss is :  0.3208109665309262
# Training accuracy after  1000  iterations is :  93.63920750782064 %  | validation accuracy is :  91.97080291970804 %
#
# Training loss after  1500  iterations is :  0.2525084723380924  | validation loss is :  0.25974191114129364
# Training accuracy after  1500  iterations is :  96.24608967674662 %  | validation accuracy is :  96.35036496350365 %
#
# Training loss after  2000  iterations is :  0.21488321989739426  | validation loss is :  0.219154922452315
# Training accuracy after  2000  iterations is :  97.288842544317 %  | validation accuracy is :  97.08029197080292 %
#
# Training loss after  2500  iterations is :  0.18839546541124322  | validation loss is :  0.19040147692431492
# Training accuracy after  2500  iterations is :  97.70594369134515 %  | validation accuracy is :  97.08029197080292 %
#
# Training loss after  3000  iterations is :  0.1687531387177522  | validation loss is :  0.16903465246069568
# Training accuracy after  3000  iterations is :  97.8102189781022 %  | validation accuracy is :  98.54014598540147 %
#
# Training loss after  3500  iterations is :  0.15360813664836523  | validation loss is :  0.15256307099130403
# Training accuracy after  3500  iterations is :  98.01876955161627 %  | validation accuracy is :  98.54014598540147 %
#
# Training loss after  4000  iterations is :  0.141570990249546  | validation loss is :  0.13949171806116265
# Training accuracy after  4000  iterations is :  98.01876955161627 %  | validation accuracy is :  98.54014598540147 %
#
# Training loss after  4500  iterations is :  0.1317686669880567  | validation loss is :  0.12887280109731042
# Training accuracy after  4500  iterations is :  98.1230448383733 %  | validation accuracy is :  98.54014598540147 %
#
# Training loss after  5000  iterations is :  0.12362595001908677  | validation loss is :  0.12007806195413527
# Training accuracy after  5000  iterations is :  98.01876955161627 %  | validation accuracy is :  98.54014598540147 %
#
# Training loss after  5500  iterations is :  0.11674891927371872  | validation loss is :  0.11267544738851683
# Training accuracy after  5500  iterations is :  98.1230448383733 %  | validation accuracy is :  98.54014598540147 %
#
# Training loss after  6000  iterations is :  0.11085900833825724  | validation loss is :  0.10635852546801206
# Training accuracy after  6000  iterations is :  98.1230448383733 %  | validation accuracy is :  98.54014598540147 %
#
# Training loss after  6500  iterations is :  0.10575380350284574  | validation loss is :  0.10090418201765142
# Training accuracy after  6500  iterations is :  98.22732012513035 %  | validation accuracy is :  98.54014598540147 %
#
# Training loss after  7000  iterations is :  0.1012827619370254  | validation loss is :  0.09614625468328292
# Training accuracy after  7000  iterations is :  98.22732012513035 %  | validation accuracy is :  98.54014598540147 %
#
# Training loss after  7500  iterations is :  0.09733163580066012  | validation loss is :  0.09195853892740322
# Training accuracy after  7500  iterations is :  98.22732012513035 %  | validation accuracy is :  98.54014598540147 %
#
# Training loss after  8000  iterations is :  0.09381217505168124  | validation loss is :  0.08824351071012679
# Training accuracy after  8000  iterations is :  98.22732012513035 %  | validation accuracy is :  98.54014598540147 %
#
# Training loss after  8500  iterations is :  0.09065513861195655  | validation loss is :  0.08492464922182046
# Training accuracy after  8500  iterations is :  98.22732012513035 %  | validation accuracy is :  98.54014598540147 %
#
# Training loss after  9000  iterations is :  0.08780543984622564  | validation loss is :  0.08194109114540668
# Training accuracy after  9000  iterations is :  98.22732012513035 %  | validation accuracy is :  98.54014598540147 %
#
# Training loss after  9500  iterations is :  0.08521870452456791  | validation loss is :  0.07924383284904331
# Training accuracy after  9500  iterations is :  98.22732012513035 %  | validation accuracy is :  98.54014598540147 %
# [[-4.41142347]
#  [-2.41897909]
#  [-2.64520642]
#  [-0.16355189]]
# 0.06622693454012492
#  -------------------------------------------------------------------------------------------
#
#  For learning rate  10 ------------------------------------------------------------
#
# Training loss after  0  iterations is :  0.6931469805599655  | validation loss is :  0.6931469805599654
# Training accuracy after  0  iterations is :  45.35974973931178 %  | validation accuracy is :  38.68613138686131 %
#
# Training loss after  500  iterations is :  0.020436009539311642  | validation loss is :  0.022225023702869728
# Training accuracy after  500  iterations is :  99.27007299270073 %  | validation accuracy is :  99.27007299270073 %
#
# Training loss after  1000  iterations is :  0.017589894537179723  | validation loss is :  0.021450622685468972
# Training accuracy after  1000  iterations is :  99.27007299270073 %  | validation accuracy is :  99.27007299270073 %
#
# Training loss after  1500  iterations is :  0.016297607530837265  | validation loss is :  0.02123542203434807
# Training accuracy after  1500  iterations is :  99.06152241918666 %  | validation accuracy is :  99.27007299270073 %
#
# Training loss after  2000  iterations is :  0.015525870311703651  | validation loss is :  0.02113411253434454
# Training accuracy after  2000  iterations is :  99.06152241918666 %  | validation accuracy is :  99.27007299270073 %
#
# Training loss after  2500  iterations is :  0.015003038840890283  | validation loss is :  0.021075240319580437
# Training accuracy after  2500  iterations is :  99.06152241918666 %  | validation accuracy is :  99.27007299270073 %
#
# Training loss after  3000  iterations is :  0.014621875151934749  | validation loss is :  0.021038678591248996
# Training accuracy after  3000  iterations is :  99.06152241918666 %  | validation accuracy is :  99.27007299270073 %
#
# Training loss after  3500  iterations is :  0.014330320614539448  | validation loss is :  0.021016132515774014
# Training accuracy after  3500  iterations is :  99.06152241918666 %  | validation accuracy is :  99.27007299270073 %
#
# Training loss after  4000  iterations is :  0.014099623392686713  | validation loss is :  0.021003190781968096
# Training accuracy after  4000  iterations is :  99.06152241918666 %  | validation accuracy is :  99.27007299270073 %
#
# Training loss after  4500  iterations is :  0.013912425740006618  | validation loss is :  0.020997124201633237
# Training accuracy after  4500  iterations is :  99.06152241918666 %  | validation accuracy is :  99.27007299270073 %
#
# Training loss after  5000  iterations is :  0.013757541598585813  | validation loss is :  0.02099609522039501
# Training accuracy after  5000  iterations is :  99.47862356621481 %  | validation accuracy is :  99.27007299270073 %
#
# Training loss after  5500  iterations is :  0.013627392928984135  | validation loss is :  0.02099880520585498
# Training accuracy after  5500  iterations is :  99.47862356621481 %  | validation accuracy is :  99.27007299270073 %
#
# Training loss after  6000  iterations is :  0.013516639459016827  | validation loss is :  0.021004308535026342
# Training accuracy after  6000  iterations is :  99.47862356621481 %  | validation accuracy is :  99.27007299270073 %
#
# Training loss after  6500  iterations is :  0.013421395902505032  | validation loss is :  0.021011902595057044
# Training accuracy after  6500  iterations is :  99.47862356621481 %  | validation accuracy is :  99.27007299270073 %
#
# Training loss after  7000  iterations is :  0.013338760170011524  | validation loss is :  0.021021057580301507
# Training accuracy after  7000  iterations is :  99.47862356621481 %  | validation accuracy is :  99.27007299270073 %
#
# Training loss after  7500  iterations is :  0.01326651620045146  | validation loss is :  0.02103136941329493
# Training accuracy after  7500  iterations is :  99.47862356621481 %  | validation accuracy is :  99.27007299270073 %
#
# Training loss after  8000  iterations is :  0.013202939742367125  | validation loss is :  0.021042527090890002
# Training accuracy after  8000  iterations is :  99.47862356621481 %  | validation accuracy is :  99.27007299270073 %
#
# Training loss after  8500  iterations is :  0.013146667375197698  | validation loss is :  0.021054289477271157
# Training accuracy after  8500  iterations is :  99.47862356621481 %  | validation accuracy is :  99.27007299270073 %
#
# Training loss after  9000  iterations is :  0.013096605764322576  | validation loss is :  0.021066468498835707
# Training accuracy after  9000  iterations is :  99.47862356621481 %  | validation accuracy is :  99.27007299270073 %
#
# Training loss after  9500  iterations is :  0.01305186730056007  | validation loss is :  0.021078916788299627
# Training accuracy after  9500  iterations is :  99.47862356621481 %  | validation accuracy is :  99.27007299270073 %
# [[-29.69974609]
#  [-15.80212063]
#  [-19.61769194]
#  [ -1.21819386]]
# -3.6268255033310446
#  -------------------------------------------------------------------------------------------

# %%
"Custom learning rate chosen by hit and trial"
# Out:
# 'Custom learning rate chosen by hit and trial'

# %%
""" SGD on 0.005 learning rate"""
log_regressor_sgd = MyLogisticRegression()
log_regressor_sgd.fit(X_train, y_train, X_val, y_val, epochs = 10000 ,learning_rate = 0.005, grad_type = "sgd")
print(log_regressor_sgd.W)
print(log_regressor_sgd.b)
loss_history_sgd = log_regressor_sgd.loss_history
val_loss_history_sgd = log_regressor_sgd.val_loss_history
train_acc_history_sgd = log_regressor_sgd.train_acc_history
val_acc_history_sgd = log_regressor_sgd.val_acc_history
plt.plot([x for x in range(len(loss_history_sgd))], loss_history_sgd, label = "Training  loss " )
plt.plot([x for x in range(len(val_loss_history_sgd))], val_loss_history_sgd, label = "Validation  loss")
plt.xlabel('epochs')
plt.ylabel('loss')
plt.legend()
plt.show()
plt.plot([x for x in range(len(train_acc_history_sgd))], train_acc_history_sgd, label = "Training  accuracy " )
plt.plot([x for x in range(len(val_acc_history_sgd))], val_acc_history_sgd, label = "Validation  accuracy")
plt.xlabel('epochs')
plt.ylabel('accuracy')
plt.legend()
plt.show()
# Out:
# (959, 4) 959 4
#
# Training loss after  0  sgd steps is :  0.6931469805599655  | validation loss is :  0.6931469805599654
# Training accuracy after  0  sgd steps is :  45.35974973931178 %  | validation accuracy is :  38.68613138686131 %
#
# Training loss after  500  sgd steps is :  0.4942519894473935  | validation loss is :  0.5043850864678605
# Training accuracy after  500  sgd steps is :  75.49530761209593 %  | validation accuracy is :  75.91240875912408 %
#
# Training loss after  1000  sgd steps is :  0.4096121375328973  | validation loss is :  0.41959010386527007
# Training accuracy after  1000  sgd steps is :  90.30239833159541 %  | validation accuracy is :  84.67153284671532 %
#
# Training loss after  1500  sgd steps is :  0.3531567682031769  | validation loss is :  0.36629684158221937
# Training accuracy after  1500  sgd steps is :  91.86652763295099 %  | validation accuracy is :  89.05109489051095 %
#
# Training loss after  2000  sgd steps is :  0.3143026274632131  | validation loss is :  0.32824769617499605
# Training accuracy after  2000  sgd steps is :  92.90928050052138 %  | validation accuracy is :  91.24087591240875 %
#
# Training loss after  2500  sgd steps is :  0.2815173847629309  | validation loss is :  0.2936991100210086
# Training accuracy after  2500  sgd steps is :  93.95203336809176 %  | validation accuracy is :  91.97080291970804 %
#
# Training loss after  3000  sgd steps is :  0.25552218783513436  | validation loss is :  0.26417472398565733
# Training accuracy after  3000  sgd steps is :  95.9332638164755 %  | validation accuracy is :  94.8905109489051 %
#
# Training loss after  3500  sgd steps is :  0.2355434248197582  | validation loss is :  0.24466170211001037
# Training accuracy after  3500  sgd steps is :  95.9332638164755 %  | validation accuracy is :  94.8905109489051 %
#
# Training loss after  4000  sgd steps is :  0.21724630169140868  | validation loss is :  0.222801338822823
# Training accuracy after  4000  sgd steps is :  97.18456725755996 %  | validation accuracy is :  97.08029197080292 %
#
# Training loss after  4500  sgd steps is :  0.2029340503793002  | validation loss is :  0.20781345628080788
# Training accuracy after  4500  sgd steps is :  97.39311783107404 %  | validation accuracy is :  97.08029197080292 %
#
# Training loss after  5000  sgd steps is :  0.19008864305912904  | validation loss is :  0.19297914966052596
# Training accuracy after  5000  sgd steps is :  97.60166840458811 %  | validation accuracy is :  97.08029197080292 %
#
# Training loss after  5500  sgd steps is :  0.17942975683135698  | validation loss is :  0.18084540596673973
# Training accuracy after  5500  sgd steps is :  97.70594369134515 %  | validation accuracy is :  97.08029197080292 %
#
# Training loss after  6000  sgd steps is :  0.17060806501974476  | validation loss is :  0.17238283148567274
# Training accuracy after  6000  sgd steps is :  97.70594369134515 %  | validation accuracy is :  97.8102189781022 %
#
# Training loss after  6500  sgd steps is :  0.1622524088739136  | validation loss is :  0.16291729693295465
# Training accuracy after  6500  sgd steps is :  97.8102189781022 %  | validation accuracy is :  98.54014598540147 %
#
# Training loss after  7000  sgd steps is :  0.15491215769994457  | validation loss is :  0.1549669239339665
# Training accuracy after  7000  sgd steps is :  97.91449426485923 %  | validation accuracy is :  98.54014598540147 %
#
# Training loss after  7500  sgd steps is :  0.1481991691583179  | validation loss is :  0.14689803793985148
# Training accuracy after  7500  sgd steps is :  98.01876955161627 %  | validation accuracy is :  98.54014598540147 %
#
# Training loss after  8000  sgd steps is :  0.14253267481853557  | validation loss is :  0.14008796703412316
# Training accuracy after  8000  sgd steps is :  97.8102189781022 %  | validation accuracy is :  98.54014598540147 %
#
# Training loss after  8500  sgd steps is :  0.13683397319989543  | validation loss is :  0.13386742272219337
# Training accuracy after  8500  sgd steps is :  97.91449426485923 %  | validation accuracy is :  98.54014598540147 %
#
# Training loss after  9000  sgd steps is :  0.13223067432442714  | validation loss is :  0.12907808831984022
# Training accuracy after  9000  sgd steps is :  97.91449426485923 %  | validation accuracy is :  98.54014598540147 %
#
# Training loss after  9500  sgd steps is :  0.12792324224590088  | validation loss is :  0.12444460809235139
# Training accuracy after  9500  sgd steps is :  97.91449426485923 %  | validation accuracy is :  98.54014598540147 %
# [[-3.38685258]
#  [-1.86129267]
#  [-1.84504188]
#  [-0.21970229]]
# [[0.05282331]]

# %%
log_regressor_bgd = MyLogisticRegression()
log_regressor_bgd.fit(X_train, y_train, X_val, y_val, epochs = 10000 ,learning_rate = 0.005, grad_type = "bgd")
print(log_regressor_bgd.W)
print(log_regressor_bgd.b)
loss_history_bgd = log_regressor_bgd.loss_history
val_loss_history_bgd = log_regressor_bgd.val_loss_history
train_acc_history_bgd = log_regressor_bgd.train_acc_history
val_acc_history_bgd = log_regressor_bgd.val_acc_history
plt.plot([x for x in range(10000)], loss_history_bgd, label = "Training  accuracy " )
plt.plot([x for x in range(10000)], val_loss_history_bgd, label = "Validation  accuracy")
plt.xlabel('epochs')
plt.ylabel('loss')
plt.legend()
plt.show()
plt.plot([x for x in range(10000)], train_acc_history_bgd, label = "Training  accuracy " )
plt.plot([x for x in range(10000)], val_acc_history_bgd, label = "Validation  accuracy")
plt.xlabel('epochs')
plt.ylabel('accuracy')
plt.legend()
plt.show()
# Out:
# Training loss after  0  iterations is :  0.6931469805599655  | validation loss is :  0.6931469805599654
# Training accuracy after  0  iterations is :  45.35974973931178 %  | validation accuracy is :  38.68613138686131 %
#
# Training loss after  500  iterations is :  0.49117663667461775  | validation loss is :  0.5016666519226046
# Training accuracy after  500  iterations is :  79.04066736183525 %  | validation accuracy is :  77.37226277372262 %
#
# Training loss after  1000  iterations is :  0.4082855283363414  | validation loss is :  0.4212691126482235
# Training accuracy after  1000  iterations is :  89.57247132429615 %  | validation accuracy is :  80.2919708029197 %
#
# Training loss after  1500  iterations is :  0.3517748747475844  | validation loss is :  0.3641850747260185
# Training accuracy after  1500  iterations is :  91.86652763295099 %  | validation accuracy is :  89.05109489051095 %
#
# Training loss after  2000  iterations is :  0.3100289446245862  | validation loss is :  0.32083405747400967
# Training accuracy after  2000  iterations is :  93.63920750782064 %  | validation accuracy is :  91.97080291970804 %
#
# Training loss after  2500  iterations is :  0.27793790446955763  | validation loss is :  0.28691810194221057
# Training accuracy after  2500  iterations is :  95.41188738269031 %  | validation accuracy is :  94.16058394160584 %
#
# Training loss after  3000  iterations is :  0.2525284631370879  | validation loss is :  0.25976211619608164
# Training accuracy after  3000  iterations is :  96.24608967674662 %  | validation accuracy is :  96.35036496350365 %
#
# Training loss after  3500  iterations is :  0.2319280643386207  | validation loss is :  0.23758716379972442
# Training accuracy after  3500  iterations is :  96.97601668404589 %  | validation accuracy is :  97.08029197080292 %
#
# Training loss after  4000  iterations is :  0.21489947078787613  | validation loss is :  0.21917187394082158
# Training accuracy after  4000  iterations is :  97.288842544317 %  | validation accuracy is :  97.08029197080292 %
#
# Training loss after  4500  iterations is :  0.20059356808313988  | validation loss is :  0.20365526060977301
# Training accuracy after  4500  iterations is :  97.39311783107404 %  | validation accuracy is :  97.08029197080292 %
#
# Training loss after  5000  iterations is :  0.18840886943460722  | validation loss is :  0.19041568830709857
# Training accuracy after  5000  iterations is :  97.70594369134515 %  | validation accuracy is :  97.08029197080292 %
#
# Training loss after  5500  iterations is :  0.17790773731115686  | validation loss is :  0.17899450824880203
# Training accuracy after  5500  iterations is :  97.70594369134515 %  | validation accuracy is :  97.08029197080292 %
#
# Training loss after  6000  iterations is :  0.16876437500366878  | validation loss is :  0.16904668197794845
# Training accuracy after  6000  iterations is :  97.8102189781022 %  | validation accuracy is :  98.54014598540147 %
#
# Training loss after  6500  iterations is :  0.1607313994244445  | validation loss is :  0.16030808694909351
# Training accuracy after  6500  iterations is :  98.01876955161627 %  | validation accuracy is :  98.54014598540147 %
#
# Training loss after  7000  iterations is :  0.15361769798620173  | validation loss is :  0.15257337226399828
# Training accuracy after  7000  iterations is :  98.01876955161627 %  | validation accuracy is :  98.54014598540147 %
#
# Training loss after  7500  iterations is :  0.14727336830258408  | validation loss is :  0.14568063981540405
# Training accuracy after  7500  iterations is :  98.01876955161627 %  | validation accuracy is :  98.54014598540147 %
#
# Training loss after  8000  iterations is :  0.14157923495997202  | validation loss is :  0.13950063873480864
# Training accuracy after  8000  iterations is :  98.01876955161627 %  | validation accuracy is :  98.54014598540147 %
#
# Training loss after  8500  iterations is :  0.136439401189868  | validation loss is :  0.13392900637318894
# Training accuracy after  8500  iterations is :  98.1230448383733 %  | validation accuracy is :  98.54014598540147 %
#
# Training loss after  9000  iterations is :  0.13177585939405945  | validation loss is :  0.12888060548319252
# Training accuracy after  9000  iterations is :  98.1230448383733 %  | validation accuracy is :  98.54014598540147 %
#
# Training loss after  9500  iterations is :  0.12752452715981694  | validation loss is :  0.12428532943696943
# Training accuracy after  9500  iterations is :  97.8102189781022 %  | validation accuracy is :  98.54014598540147 %
# [[-3.40201319]
#  [-1.84350174]
#  [-1.85971229]
#  [-0.24921905]]
# 0.0007434665679809533

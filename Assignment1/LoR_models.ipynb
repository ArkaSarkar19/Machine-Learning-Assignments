# %%
import numpy as np
import pandas as pd
from scratch import *
import random
# Out:
# Linear Regression
# Training loss after  0  iterations is  1.5811388300841898
# Training loss after  500  iterations is  0.11515089871796896
# Training loss after  1000  iterations is  0.11515089872154656
# Training loss after  1500  iterations is  0.11515089872154524
# Training loss after  2000  iterations is  0.11515089872154423
# Training loss after  2500  iterations is  0.11515089872154423
# Training loss after  3000  iterations is  0.11515089872154423
# Training loss after  3500  iterations is  0.11515089872154423
# Training loss after  4000  iterations is  0.11515089872154423
# Training loss after  4500  iterations is  0.11515089872154423
# Predicted Values: [[2.76462962]
#  [2.76462962]]
# True Values: [3]

# %%
preprocess = MyPreProcessor()
X,Y=preprocess.pre_process(2)
print(X)
print(Y)
# Out:
# [[-0.37095945 -0.23243133 -0.41395243  0.25112591]
#  [ 1.53525151  0.86306915 -0.78782856  0.40073686]
#  [ 1.26981427 -1.07609556  0.77730177  1.10875348]
#  ...
#  [-0.84076893 -0.29239137 -0.03489116  0.39088564]
#  [-0.60468005  0.22995878 -0.73453804 -0.98519039]
#  [-0.98575122 -0.40208289  0.0683244   0.36256517]]
# [[1.]
#  [0.]
#  [0.]
#  ...
#  [1.]
#  [1.]
#  [1.]]

# %%
ratio = X.shape[0]//10
X_train = X[0:7*ratio, :]
y_train = Y[0:7*ratio, :]
X_val = X[7*ratio : 8*ratio, :]
y_val = Y[7*ratio : 8*ratio, :]
X_test = X[8*ratio:, :]
y_test = Y[8*ratio:,:]
print(X_train.shape,y_train.shape )
print(X_test.shape,y_test.shape )
print(X_val.shape, y_val.shape)
# Out:
# (959, 4) (959, 1)
# (276, 4) (276, 1)
# (137, 4) (137, 1)

# %%
pp = MyPreProcessor()
W = pp.get_analytical_sol()
print(W)
X,y = pp.pre_process(0)
bias = np.zeros((X.shape[0],1))
bias.fill(1)
X = np.append(X,bias, axis = 1)
y_pred = np.dot(X,W)
error = (np.sum((y-y_pred)**2)/y_pred.shape[0])**0.5
mae = np.sum(abs(y-y_pred))/y_pred.shape[0]
print(error)
print(mae)
# Out:
# [[ 0.05352386  0.50788834  0.42431958 ...  0.24530597 -0.09951538
#    1.        ]
#  [ 1.26171644 -0.07501672 -0.18028967 ... -0.61230092 -0.11029156
#    1.        ]
#  [ 1.26171644 -0.15828888 -0.18028967 ... -0.35228181 -0.48027378
#    1.        ]
#  ...
#  [-1.15466873  0.71606872  0.67624011 ...  0.43233726  0.19503356
#    1.        ]
#  [ 0.05352386 -0.36646926 -0.38182609 ... -0.27473225 -0.57007528
#    1.        ]
#  [-1.15466873  0.84097695  0.67624011 ...  0.50076334  0.51472693
#    1.        ]]
# [[-0.31897531]
#  [-0.09327839]
#  [ 1.17898616]
#  [ 0.47167202]
#  [ 4.44500034]
#  [-4.46177583]
#  [-1.11059218]
#  [ 1.2124104 ]
#  [ 9.93247126]]
# 2.1959658591369107
# 1.5831332322025662

# %%
"""Running SGD on Banknote dataset and with LR = 0.0001, 0.01, 10"""
L = [0.0001, 0.0001,0.01,10]
Epochs = [10000,400000, 10000, 10000]

# %%
for i in range(4):
    print("\n For learning rate ", L[i], "------------------------------------------------------------ ")
    log_regressor_sgd = MyLogisticRegression()
    log_regressor_sgd.fit(X_train, y_train, X_val, y_val, epochs = Epochs[i] ,learning_rate = L[i], grad_type = "sgd")
    print(log_regressor_sgd.W)
    print(log_regressor_sgd.b)
    loss_history_sgd = log_regressor_sgd.loss_history
    val_loss_history_sgd = log_regressor_sgd.val_loss_history
    train_acc_history_sgd = log_regressor_sgd.train_acc_history
    val_acc_history_sgd = log_regressor_sgd.val_acc_history
    plt.plot([x for x in range(len(loss_history_sgd))], loss_history_sgd, label = "Training  loss " )
    plt.plot([x for x in range(len(val_loss_history_sgd))], val_loss_history_sgd, label = "Validation  loss")
    plt.xlabel('iterations')
    plt.ylabel('loss')
    plt.legend()
    plt.show()
    plt.plot([x for x in range(len(train_acc_history_sgd))], train_acc_history_sgd, label = "Training  accuracy " )
    plt.plot([x for x in range(len(val_acc_history_sgd))], val_acc_history_sgd, label = "Validation  accuracy")
    plt.xlabel('iterations')
    plt.ylabel('accuracy')
    plt.legend()
    plt.show()
    
    print("\n -------------------------------------------------------------------------------------------")
# Out:
#  For learning rate  0.0001 ------------------------------------------------------------
#
# Training loss after  0  sgd steps is :  0.6931469805599655  | validation loss is :  0.6931469805599654
# Training accuracy after  0  sgd steps is :  45.04692387904067 %  | validation accuracy is :  38.68613138686131 %
#
# Training loss after  500  sgd steps is :  0.6844811836783257  | validation loss is :  0.6836831479523103
# Training accuracy after  500  sgd steps is :  85.81856100104275 %  | validation accuracy is :  85.40145985401459 %
#
# Training loss after  1000  sgd steps is :  0.6760574320937718  | validation loss is :  0.6742033547365274
# Training accuracy after  1000  sgd steps is :  85.71428571428572 %  | validation accuracy is :  86.86131386861314 %
#
# Training loss after  1500  sgd steps is :  0.6679375067237409  | validation loss is :  0.6652286611936581
# Training accuracy after  1500  sgd steps is :  85.08863399374349 %  | validation accuracy is :  86.86131386861314 %
#
# Training loss after  2000  sgd steps is :  0.6595812240532354  | validation loss is :  0.6560649194306954
# Training accuracy after  2000  sgd steps is :  85.50573514077165 %  | validation accuracy is :  87.59124087591242 %
#
# Training loss after  2500  sgd steps is :  0.6513095798451135  | validation loss is :  0.6469063637197932
# Training accuracy after  2500  sgd steps is :  84.8800834202294 %  | validation accuracy is :  86.13138686131387 %
#
# Training loss after  3000  sgd steps is :  0.6432975977120563  | validation loss is :  0.6380526809371897
# Training accuracy after  3000  sgd steps is :  84.98435870698644 %  | validation accuracy is :  86.13138686131387 %
#
# Training loss after  3500  sgd steps is :  0.6365459988069262  | validation loss is :  0.6305961561055864
# Training accuracy after  3500  sgd steps is :  85.40145985401459 %  | validation accuracy is :  86.13138686131387 %
#
# Training loss after  4000  sgd steps is :  0.6290676249912797  | validation loss is :  0.6224006713136423
# Training accuracy after  4000  sgd steps is :  85.29718456725757 %  | validation accuracy is :  86.13138686131387 %
#
# Training loss after  4500  sgd steps is :  0.6216561356529565  | validation loss is :  0.6143660336816082
# Training accuracy after  4500  sgd steps is :  85.19290928050052 %  | validation accuracy is :  86.86131386861314 %
#
# Training loss after  5000  sgd steps is :  0.6145446899978437  | validation loss is :  0.6066731819743911
# Training accuracy after  5000  sgd steps is :  85.61001042752866 %  | validation accuracy is :  86.86131386861314 %
#
# Training loss after  5500  sgd steps is :  0.607877210551323  | validation loss is :  0.5993606682270514
# Training accuracy after  5500  sgd steps is :  85.61001042752866 %  | validation accuracy is :  86.86131386861314 %
#
# Training loss after  6000  sgd steps is :  0.6016940317382057  | validation loss is :  0.5926725345413161
# Training accuracy after  6000  sgd steps is :  85.61001042752866 %  | validation accuracy is :  86.13138686131387 %
#
# Training loss after  6500  sgd steps is :  0.5957361302857008  | validation loss is :  0.5861269280222948
# Training accuracy after  6500  sgd steps is :  85.81856100104275 %  | validation accuracy is :  86.86131386861314 %
#
# Training loss after  7000  sgd steps is :  0.5899260796362529  | validation loss is :  0.5797532563443916
# Training accuracy after  7000  sgd steps is :  86.02711157455683 %  | validation accuracy is :  86.86131386861314 %
#
# Training loss after  7500  sgd steps is :  0.5841239774862028  | validation loss is :  0.5733712853302997
# Training accuracy after  7500  sgd steps is :  86.02711157455683 %  | validation accuracy is :  86.86131386861314 %
#
# Training loss after  8000  sgd steps is :  0.5786166144103301  | validation loss is :  0.5672611966315975
# Training accuracy after  8000  sgd steps is :  86.02711157455683 %  | validation accuracy is :  86.86131386861314 %
#
# Training loss after  8500  sgd steps is :  0.5729142561578205  | validation loss is :  0.5610083131294926
# Training accuracy after  8500  sgd steps is :  85.9228362877998 %  | validation accuracy is :  86.86131386861314 %
#
# Training loss after  9000  sgd steps is :  0.5674778764343487  | validation loss is :  0.5551623641387787
# Training accuracy after  9000  sgd steps is :  86.02711157455683 %  | validation accuracy is :  86.86131386861314 %
#
# Training loss after  9500  sgd steps is :  0.562229660464482  | validation loss is :  0.5494383982239276
# Training accuracy after  9500  sgd steps is :  86.02711157455683 %  | validation accuracy is :  86.86131386861314 %
# [[-0.31198827]
#  [-0.18227991]
#  [ 0.0413582 ]
#  [-0.01544513]]
# [[-0.03868181]]
#  -------------------------------------------------------------------------------------------
#
#  For learning rate  0.0001 ------------------------------------------------------------
#
# Training loss after  0  sgd steps is :  0.6931469805599655  | validation loss is :  0.6931469805599654
# Training accuracy after  0  sgd steps is :  45.04692387904067 %  | validation accuracy is :  38.68613138686131 %
#
# Training loss after  20000  sgd steps is :  0.4817696138549568  | validation loss is :  0.46253663697740527
# Training accuracy after  20000  sgd steps is :  87.17413972888426 %  | validation accuracy is :  87.59124087591242 %
#
# Training loss after  40000  sgd steps is :  0.3962722092830655  | validation loss is :  0.37141686144444475
# Training accuracy after  40000  sgd steps is :  89.25964546402503 %  | validation accuracy is :  89.78102189781022 %
#
# Training loss after  60000  sgd steps is :  0.34519738153678375  | validation loss is :  0.3179900836598686
# Training accuracy after  60000  sgd steps is :  90.92805005213765 %  | validation accuracy is :  93.43065693430657 %
#
# Training loss after  80000  sgd steps is :  0.30955066694618  | validation loss is :  0.28165906039414884
# Training accuracy after  80000  sgd steps is :  91.65797705943692 %  | validation accuracy is :  92.7007299270073 %
#
# Training loss after  100000  sgd steps is :  0.28228354930824756  | validation loss is :  0.2543980515184512
# Training accuracy after  100000  sgd steps is :  92.17935349322211 %  | validation accuracy is :  94.16058394160584 %
#
# Training loss after  120000  sgd steps is :  0.260292922417954  | validation loss is :  0.23301812856587445
# Training accuracy after  120000  sgd steps is :  92.80500521376433 %  | validation accuracy is :  95.62043795620438 %
#
# Training loss after  140000  sgd steps is :  0.2419111576227167  | validation loss is :  0.21534818860543287
# Training accuracy after  140000  sgd steps is :  93.32638164754952 %  | validation accuracy is :  95.62043795620438 %
#
# Training loss after  160000  sgd steps is :  0.22641554384522694  | validation loss is :  0.20072503272816217
# Training accuracy after  160000  sgd steps is :  94.16058394160584 %  | validation accuracy is :  96.35036496350365 %
#
# Training loss after  180000  sgd steps is :  0.2132399138161711  | validation loss is :  0.18848186980348872
# Training accuracy after  180000  sgd steps is :  94.68196037539103 %  | validation accuracy is :  96.35036496350365 %
#
# Training loss after  200000  sgd steps is :  0.20177011810200862  | validation loss is :  0.17784136568529493
# Training accuracy after  200000  sgd steps is :  95.20333680917624 %  | validation accuracy is :  96.35036496350365 %
#
# Training loss after  220000  sgd steps is :  0.1916970829080036  | validation loss is :  0.16857655769943436
# Training accuracy after  220000  sgd steps is :  95.51616266944734 %  | validation accuracy is :  97.08029197080292 %
#
# Training loss after  240000  sgd steps is :  0.1828229545463182  | validation loss is :  0.16042655357266192
# Training accuracy after  240000  sgd steps is :  95.62043795620438 %  | validation accuracy is :  97.8102189781022 %
#
# Training loss after  260000  sgd steps is :  0.17488305627572084  | validation loss is :  0.1532769904624664
# Training accuracy after  260000  sgd steps is :  95.82898852971846 %  | validation accuracy is :  97.8102189781022 %
#
# Training loss after  280000  sgd steps is :  0.1677601614942699  | validation loss is :  0.14695144769869292
# Training accuracy after  280000  sgd steps is :  95.9332638164755 %  | validation accuracy is :  97.8102189781022 %
#
# Training loss after  300000  sgd steps is :  0.1613610168314946  | validation loss is :  0.14121009670214202
# Training accuracy after  300000  sgd steps is :  96.24608967674662 %  | validation accuracy is :  97.8102189781022 %
#
# Training loss after  320000  sgd steps is :  0.15558290387377738  | validation loss is :  0.13611642584776806
# Training accuracy after  320000  sgd steps is :  96.4546402502607 %  | validation accuracy is :  97.8102189781022 %
#
# Training loss after  340000  sgd steps is :  0.15031466342290506  | validation loss is :  0.13141517796658966
# Training accuracy after  340000  sgd steps is :  96.76746611053181 %  | validation accuracy is :  97.8102189781022 %
#
# Training loss after  360000  sgd steps is :  0.14559205385370463  | validation loss is :  0.12713772213969327
# Training accuracy after  360000  sgd steps is :  96.76746611053181 %  | validation accuracy is :  97.8102189781022 %
#
# Training loss after  380000  sgd steps is :  0.14118376252273215  | validation loss is :  0.12321811230648837
# Training accuracy after  380000  sgd steps is :  96.76746611053181 %  | validation accuracy is :  97.8102189781022 %
# [[-2.6167    ]
#  [-1.95553526]
#  [-1.68103424]
#  [ 0.1699641 ]]
# [[-0.4832426]]
# C:\Users\Asus\Anaconda3\lib\site-packages\IPython\core\pylabtools.py:128: UserWarning: Creating legend with loc="best" can be slow with large amounts of data.
#   fig.canvas.print_figure(bytes_io, **kw)
#  -------------------------------------------------------------------------------------------
#
#  For learning rate  0.01 ------------------------------------------------------------
#
# Training loss after  0  sgd steps is :  0.6931469805599655  | validation loss is :  0.6931469805599654
# Training accuracy after  0  sgd steps is :  45.04692387904067 %  | validation accuracy is :  38.68613138686131 %
#
# Training loss after  500  sgd steps is :  0.3679256664946382  | validation loss is :  0.33348805444667634
# Training accuracy after  500  sgd steps is :  87.59124087591242 %  | validation accuracy is :  91.97080291970804 %
#
# Training loss after  1000  sgd steps is :  0.2816802341062252  | validation loss is :  0.2531279880695296
# Training accuracy after  1000  sgd steps is :  91.55370177267987 %  | validation accuracy is :  94.16058394160584 %
#
# Training loss after  1500  sgd steps is :  0.23491763007516098  | validation loss is :  0.20699026030818182
# Training accuracy after  1500  sgd steps is :  93.32638164754952 %  | validation accuracy is :  95.62043795620438 %
#
# Training loss after  2000  sgd steps is :  0.20525905424502602  | validation loss is :  0.179674077334453
# Training accuracy after  2000  sgd steps is :  93.84775808133472 %  | validation accuracy is :  96.35036496350365 %
#
# Training loss after  2500  sgd steps is :  0.18054178825910566  | validation loss is :  0.15708248517857268
# Training accuracy after  2500  sgd steps is :  95.41188738269031 %  | validation accuracy is :  96.35036496350365 %
#
# Training loss after  3000  sgd steps is :  0.16247652791436493  | validation loss is :  0.14179527425406174
# Training accuracy after  3000  sgd steps is :  95.82898852971846 %  | validation accuracy is :  97.8102189781022 %
#
# Training loss after  3500  sgd steps is :  0.14823589560693773  | validation loss is :  0.12943506567278062
# Training accuracy after  3500  sgd steps is :  96.35036496350365 %  | validation accuracy is :  97.8102189781022 %
#
# Training loss after  4000  sgd steps is :  0.13717415337322475  | validation loss is :  0.11963059234972138
# Training accuracy after  4000  sgd steps is :  96.76746611053181 %  | validation accuracy is :  97.8102189781022 %
#
# Training loss after  4500  sgd steps is :  0.12869947475914897  | validation loss is :  0.11212304748289058
# Training accuracy after  4500  sgd steps is :  97.08029197080292 %  | validation accuracy is :  97.8102189781022 %
#
# Training loss after  5000  sgd steps is :  0.12139282116748654  | validation loss is :  0.10551994735882073
# Training accuracy after  5000  sgd steps is :  97.288842544317 %  | validation accuracy is :  97.8102189781022 %
#
# Training loss after  5500  sgd steps is :  0.11518720391850905  | validation loss is :  0.09967515921387035
# Training accuracy after  5500  sgd steps is :  97.39311783107404 %  | validation accuracy is :  97.8102189781022 %
#
# Training loss after  6000  sgd steps is :  0.11019083594629096  | validation loss is :  0.0946846108537247
# Training accuracy after  6000  sgd steps is :  97.288842544317 %  | validation accuracy is :  97.8102189781022 %
#
# Training loss after  6500  sgd steps is :  0.105736297800011  | validation loss is :  0.0904364551889605
# Training accuracy after  6500  sgd steps is :  97.39311783107404 %  | validation accuracy is :  97.8102189781022 %
#
# Training loss after  7000  sgd steps is :  0.10166770308871921  | validation loss is :  0.08754805405142534
# Training accuracy after  7000  sgd steps is :  97.49739311783108 %  | validation accuracy is :  97.8102189781022 %
#
# Training loss after  7500  sgd steps is :  0.09807095360953583  | validation loss is :  0.08446529780919894
# Training accuracy after  7500  sgd steps is :  97.60166840458811 %  | validation accuracy is :  97.8102189781022 %
#
# Training loss after  8000  sgd steps is :  0.09468868617684727  | validation loss is :  0.08116804407138788
# Training accuracy after  8000  sgd steps is :  97.60166840458811 %  | validation accuracy is :  97.8102189781022 %
#
# Training loss after  8500  sgd steps is :  0.09162895417801671  | validation loss is :  0.07836681574527482
# Training accuracy after  8500  sgd steps is :  97.70594369134515 %  | validation accuracy is :  97.8102189781022 %
#
# Training loss after  9000  sgd steps is :  0.08922703081896954  | validation loss is :  0.07586082716610484
# Training accuracy after  9000  sgd steps is :  97.60166840458811 %  | validation accuracy is :  97.8102189781022 %
#
# Training loss after  9500  sgd steps is :  0.08680050263742053  | validation loss is :  0.07386607737128432
# Training accuracy after  9500  sgd steps is :  97.70594369134515 %  | validation accuracy is :  97.8102189781022 %
# [[-3.45008799]
#  [-2.98140808]
#  [-2.75552349]
#  [ 0.27576274]]
# [[-0.72665436]]
#  -------------------------------------------------------------------------------------------
#
#  For learning rate  10 ------------------------------------------------------------
#
# Training loss after  0  sgd steps is :  0.6931469805599655  | validation loss is :  0.6931469805599654
# Training accuracy after  0  sgd steps is :  45.04692387904067 %  | validation accuracy is :  38.68613138686131 %
#
# Training loss after  500  sgd steps is :  0.2648115519832726  | validation loss is :  0.2667722197093801
# Training accuracy after  500  sgd steps is :  96.87174139728884 %  | validation accuracy is :  97.8102189781022 %
#
# Training loss after  1000  sgd steps is :  0.25735741361922293  | validation loss is :  0.14003102423356337
# Training accuracy after  1000  sgd steps is :  97.49739311783108 %  | validation accuracy is :  98.54014598540147 %
#
# Training loss after  1500  sgd steps is :  0.20743016839145678  | validation loss is :  0.2150297569534962
# Training accuracy after  1500  sgd steps is :  97.60166840458811 %  | validation accuracy is :  97.8102189781022 %
#
# Training loss after  2000  sgd steps is :  0.38904300558822774  | validation loss is :  0.41425331269808585
# Training accuracy after  2000  sgd steps is :  97.18456725755996 %  | validation accuracy is :  97.08029197080292 %
#
# Training loss after  2500  sgd steps is :  0.6652662328918583  | validation loss is :  0.9678922435301732
# Training accuracy after  2500  sgd steps is :  94.57768508863398 %  | validation accuracy is :  91.97080291970804 %
#
# Training loss after  3000  sgd steps is :  0.6124194661667204  | validation loss is :  0.3518370581855184
# Training accuracy after  3000  sgd steps is :  95.30761209593325 %  | validation accuracy is :  96.35036496350365 %
#
# Training loss after  3500  sgd steps is :  0.4278288338193364  | validation loss is :  0.4211332168671796
# Training accuracy after  3500  sgd steps is :  96.4546402502607 %  | validation accuracy is :  95.62043795620438 %
#
# Training loss after  4000  sgd steps is :  0.12193856816183286  | validation loss is :  0.1132613229732437
# Training accuracy after  4000  sgd steps is :  98.85297184567257 %  | validation accuracy is :  99.27007299270073 %
#
# Training loss after  4500  sgd steps is :  0.12866029691628628  | validation loss is :  0.10886013306221834
# Training accuracy after  4500  sgd steps is :  98.1230448383733 %  | validation accuracy is :  98.54014598540147 %
#
# Training loss after  5000  sgd steps is :  0.28891016822267773  | validation loss is :  0.4083533645603989
# Training accuracy after  5000  sgd steps is :  97.288842544317 %  | validation accuracy is :  96.35036496350365 %
#
# Training loss after  5500  sgd steps is :  0.3074616167640859  | validation loss is :  0.3861921057578359
# Training accuracy after  5500  sgd steps is :  97.08029197080292 %  | validation accuracy is :  97.08029197080292 %
#
# Training loss after  6000  sgd steps is :  0.34671853310260115  | validation loss is :  0.20178888686646881
# Training accuracy after  6000  sgd steps is :  96.97601668404589 %  | validation accuracy is :  98.54014598540147 %
#
# Training loss after  6500  sgd steps is :  0.21807244703308168  | validation loss is :  0.13039741072755137
# Training accuracy after  6500  sgd steps is :  98.22732012513035 %  | validation accuracy is :  98.54014598540147 %
#
# Training loss after  7000  sgd steps is :  0.26749417260031005  | validation loss is :  0.11767040970881494
# Training accuracy after  7000  sgd steps is :  97.91449426485923 %  | validation accuracy is :  99.27007299270073 %
#
# Training loss after  7500  sgd steps is :  0.12356692447439672  | validation loss is :  0.22257924678912
# Training accuracy after  7500  sgd steps is :  98.1230448383733 %  | validation accuracy is :  97.8102189781022 %
#
# Training loss after  8000  sgd steps is :  0.0875574000145561  | validation loss is :  0.11765038194847457
# Training accuracy after  8000  sgd steps is :  98.22732012513035 %  | validation accuracy is :  99.27007299270073 %
#
# Training loss after  8500  sgd steps is :  0.36767549816311174  | validation loss is :  0.11765793508396706
# Training accuracy after  8500  sgd steps is :  97.39311783107404 %  | validation accuracy is :  99.27007299270073 %
#
# Training loss after  9000  sgd steps is :  0.16163652397404019  | validation loss is :  0.1010983084256144
# Training accuracy after  9000  sgd steps is :  98.85297184567257 %  | validation accuracy is :  99.27007299270073 %
#
# Training loss after  9500  sgd steps is :  0.059215721052834534  | validation loss is :  0.10056632201514765
# Training accuracy after  9500  sgd steps is :  98.95724713242961 %  | validation accuracy is :  99.27007299270073 %
# [[-115.22724018]
#  [-155.36999449]
#  [-133.74254307]
#  [ -13.23662981]]
# [[-51.42944251]]
#  -------------------------------------------------------------------------------------------

# %%
"""Running BGD on Banknote dataset and with LR = 0.0001, 0.01, 10"""
L = [0.0001, 0.0001,0.01,10]
Epochs = [10000,400000, 10000, 10000]

# %%
for i in range(4):
    print("\n For learning rate ", L[i], "------------------------------------------------------------ ")
    log_regressor_bgd = MyLogisticRegression()
    log_regressor_bgd.fit(X_train, y_train, X_val, y_val, epochs = Epochs[i] ,learning_rate = L[i], grad_type = "bgd")
    print(log_regressor_bgd.W)
    print(log_regressor_bgd.b)
    loss_history_bgd = log_regressor_bgd.loss_history
    val_loss_history_bgd = log_regressor_bgd.val_loss_history
    train_acc_history_bgd = log_regressor_bgd.train_acc_history
    val_acc_history_bgd = log_regressor_bgd.val_acc_history
    plt.plot([x for x in range(len(loss_history_bgd))], loss_history_bgd, label = "Training  Loss " )
    plt.plot([x for x in range(len(val_loss_history_bgd))], val_loss_history_bgd, label = "Validation  Loss")
    plt.xlabel('epochs')
    plt.ylabel('loss')
    plt.legend()
    plt.show()
    plt.plot([x for x in range(len(train_acc_history_bgd))], train_acc_history_bgd, label = "Training  accuracy " )
    plt.plot([x for x in range(len(val_acc_history_bgd))], val_acc_history_bgd, label = "Validation  accuracy")
    plt.xlabel('epochs')
    plt.ylabel('Accuracy')
    plt.legend()
    plt.show()
    print("\n -------------------------------------------------------------------------------------------")
# Out:
#  For learning rate  0.0001 ------------------------------------------------------------
#
# Training loss after  0  bgd steps is :  0.6931469805599655  | validation loss is :  0.6931469805599654
# Training accuracy after  0  bgd steps is :  45.04692387904067 %  | validation accuracy is :  38.68613138686131 %
#
# Training loss after  500  bgd steps is :  0.6838394632568269  | validation loss is :  0.6828450032321047
# Training accuracy after  500  bgd steps is :  85.19290928050052 %  | validation accuracy is :  84.67153284671532 %
#
# Training loss after  1000  bgd steps is :  0.6748750018010289  | validation loss is :  0.6729329076420374
# Training accuracy after  1000  bgd steps is :  85.19290928050052 %  | validation accuracy is :  85.40145985401459 %
#
# Training loss after  1500  bgd steps is :  0.6662379814832751  | validation loss is :  0.6633925946878373
# Training accuracy after  1500  bgd steps is :  85.29718456725757 %  | validation accuracy is :  85.40145985401459 %
#
# Training loss after  2000  bgd steps is :  0.6579133263116121  | validation loss is :  0.6542066026721183
# Training accuracy after  2000  bgd steps is :  85.29718456725757 %  | validation accuracy is :  86.13138686131387 %
#
# Training loss after  2500  bgd steps is :  0.6498865232055717  | validation loss is :  0.6453581353319349
# Training accuracy after  2500  bgd steps is :  85.40145985401459 %  | validation accuracy is :  86.13138686131387 %
#
# Training loss after  3000  bgd steps is :  0.6421436373848323  | validation loss is :  0.6368310794053205
# Training accuracy after  3000  bgd steps is :  85.40145985401459 %  | validation accuracy is :  86.13138686131387 %
#
# Training loss after  3500  bgd steps is :  0.6346713201005846  | validation loss is :  0.6286100131183803
# Training accuracy after  3500  bgd steps is :  85.50573514077165 %  | validation accuracy is :  85.40145985401459 %
#
# Training loss after  4000  bgd steps is :  0.6274568098216464  | validation loss is :  0.6206802069295478
# Training accuracy after  4000  bgd steps is :  85.50573514077165 %  | validation accuracy is :  85.40145985401459 %
#
# Training loss after  4500  bgd steps is :  0.6204879279243012  | validation loss is :  0.6130276177886966
# Training accuracy after  4500  bgd steps is :  85.9228362877998 %  | validation accuracy is :  85.40145985401459 %
#
# Training loss after  5000  bgd steps is :  0.6137530698537376  | validation loss is :  0.6056388780689358
# Training accuracy after  5000  bgd steps is :  85.9228362877998 %  | validation accuracy is :  85.40145985401459 %
#
# Training loss after  5500  bgd steps is :  0.6072411926333129  | validation loss is :  0.5985012802170584
# Training accuracy after  5500  bgd steps is :  86.02711157455683 %  | validation accuracy is :  85.40145985401459 %
#
# Training loss after  6000  bgd steps is :  0.6009417995016448  | validation loss is :  0.5916027580518444
# Training accuracy after  6000  bgd steps is :  86.13138686131387 %  | validation accuracy is :  86.13138686131387 %
#
# Training loss after  6500  bgd steps is :  0.5948449223613737  | validation loss is :  0.5849318655232006
# Training accuracy after  6500  bgd steps is :  86.44421272158498 %  | validation accuracy is :  86.13138686131387 %
#
# Training loss after  7000  bgd steps is :  0.5889411026306319  | validation loss is :  0.5784777536333534
# Training accuracy after  7000  bgd steps is :  86.54848800834203 %  | validation accuracy is :  86.13138686131387 %
#
# Training loss after  7500  bgd steps is :  0.5832213710011743  | validation loss is :  0.572230146116688
# Training accuracy after  7500  bgd steps is :  86.54848800834203 %  | validation accuracy is :  86.13138686131387 %
#
# Training loss after  8000  bgd steps is :  0.5776772265271061  | validation loss is :  0.5661793143789796
# Training accuracy after  8000  bgd steps is :  86.54848800834203 %  | validation accuracy is :  86.13138686131387 %
#
# Training loss after  8500  bgd steps is :  0.5723006153960275  | validation loss is :  0.5603160521105007
# Training accuracy after  8500  bgd steps is :  86.54848800834203 %  | validation accuracy is :  86.13138686131387 %
#
# Training loss after  9000  bgd steps is :  0.5670839096703553  | validation loss is :  0.5546316499110752
# Training accuracy after  9000  bgd steps is :  86.54848800834203 %  | validation accuracy is :  86.13138686131387 %
#
# Training loss after  9500  bgd steps is :  0.5620198862304883  | validation loss is :  0.549117870198338
# Training accuracy after  9500  bgd steps is :  86.54848800834203 %  | validation accuracy is :  86.13138686131387 %
# [[-0.31011003]
#  [-0.18542621]
#  [ 0.04238303]
#  [-0.00847349]]
# -0.04511542717147311
#  -------------------------------------------------------------------------------------------
#
#  For learning rate  0.0001 ------------------------------------------------------------
#
# Training loss after  0  bgd steps is :  0.6931469805599655  | validation loss is :  0.6931469805599654
# Training accuracy after  0  bgd steps is :  45.04692387904067 %  | validation accuracy is :  38.68613138686131 %
#
# Training loss after  20000  bgd steps is :  0.4814771832815339  | validation loss is :  0.46200880516377785
# Training accuracy after  20000  bgd steps is :  86.96558915537018 %  | validation accuracy is :  87.59124087591242 %
#
# Training loss after  40000  bgd steps is :  0.39617923386646947  | validation loss is :  0.37120077936551177
# Training accuracy after  40000  bgd steps is :  89.25964546402503 %  | validation accuracy is :  89.05109489051095 %
#
# Training loss after  60000  bgd steps is :  0.3453800294349291  | validation loss is :  0.31828188802358515
# Training accuracy after  60000  bgd steps is :  90.71949947862356 %  | validation accuracy is :  93.43065693430657 %
#
# Training loss after  80000  bgd steps is :  0.309544720254969  | validation loss is :  0.28180061780745713
# Training accuracy after  80000  bgd steps is :  91.65797705943692 %  | validation accuracy is :  92.7007299270073 %
#
# Training loss after  100000  bgd steps is :  0.2820527192439767  | validation loss is :  0.2544235039758489
# Training accuracy after  100000  bgd steps is :  92.17935349322211 %  | validation accuracy is :  94.16058394160584 %
#
# Training loss after  120000  bgd steps is :  0.2599462677195176  | validation loss is :  0.23283997367337847
# Training accuracy after  120000  bgd steps is :  92.7007299270073 %  | validation accuracy is :  95.62043795620438 %
#
# Training loss after  140000  bgd steps is :  0.2416420533761144  | validation loss is :  0.21527177379742032
# Training accuracy after  140000  bgd steps is :  93.11783107403545 %  | validation accuracy is :  95.62043795620438 %
#
# Training loss after  160000  bgd steps is :  0.22617967255016844  | validation loss is :  0.2006453915617662
# Training accuracy after  160000  bgd steps is :  94.16058394160584 %  | validation accuracy is :  96.35036496350365 %
#
# Training loss after  180000  bgd steps is :  0.2129233404257864  | validation loss is :  0.18825809206201166
# Training accuracy after  180000  bgd steps is :  94.8905109489051 %  | validation accuracy is :  96.35036496350365 %
#
# Training loss after  200000  bgd steps is :  0.20142551337928577  | validation loss is :  0.1776227164135
# Training accuracy after  200000  bgd steps is :  95.30761209593325 %  | validation accuracy is :  96.35036496350365 %
#
# Training loss after  220000  bgd steps is :  0.19135710686099275  | validation loss is :  0.16838723275978176
# Training accuracy after  220000  bgd steps is :  95.51616266944734 %  | validation accuracy is :  97.8102189781022 %
#
# Training loss after  240000  bgd steps is :  0.18246835234534675  | validation loss is :  0.16028925769854344
# Training accuracy after  240000  bgd steps is :  95.62043795620438 %  | validation accuracy is :  97.8102189781022 %
#
# Training loss after  260000  bgd steps is :  0.17456513269307902  | validation loss is :  0.15312850522318935
# Training accuracy after  260000  bgd steps is :  95.82898852971846 %  | validation accuracy is :  97.8102189781022 %
#
# Training loss after  280000  bgd steps is :  0.16749378612389262  | validation loss is :  0.14674915318290718
# Training accuracy after  280000  bgd steps is :  95.9332638164755 %  | validation accuracy is :  97.8102189781022 %
#
# Training loss after  300000  bgd steps is :  0.1611308695389372  | validation loss is :  0.14102805539402072
# Training accuracy after  300000  bgd steps is :  96.24608967674662 %  | validation accuracy is :  97.8102189781022 %
#
# Training loss after  320000  bgd steps is :  0.15537599725474951  | validation loss is :  0.13586658494068352
# Training accuracy after  320000  bgd steps is :  96.4546402502607 %  | validation accuracy is :  97.8102189781022 %
#
# Training loss after  340000  bgd steps is :  0.15014667959601494  | validation loss is :  0.13118483227684138
# Training accuracy after  340000  bgd steps is :  96.76746611053181 %  | validation accuracy is :  97.8102189781022 %
#
# Training loss after  360000  bgd steps is :  0.14537451348130162  | validation loss is :  0.12691738498580946
# Training accuracy after  360000  bgd steps is :  96.76746611053181 %  | validation accuracy is :  97.8102189781022 %
#
# Training loss after  380000  bgd steps is :  0.14100231636530658  | validation loss is :  0.12301020080724517
# Training accuracy after  380000  bgd steps is :  96.76746611053181 %  | validation accuracy is :  97.8102189781022 %
# [[-2.62101423]
#  [-1.95617434]
#  [-1.6814302 ]
#  [ 0.17263707]]
# -0.48509782158592324
#  -------------------------------------------------------------------------------------------
#
#  For learning rate  0.01 ------------------------------------------------------------
#
# Training loss after  0  bgd steps is :  0.6931469805599655  | validation loss is :  0.6931469805599654
# Training accuracy after  0  bgd steps is :  45.04692387904067 %  | validation accuracy is :  38.68613138686131 %
#
# Training loss after  500  bgd steps is :  0.3681238920005301  | validation loss is :  0.34181908778781633
# Training accuracy after  500  bgd steps is :  90.30239833159541 %  | validation accuracy is :  92.7007299270073 %
#
# Training loss after  1000  bgd steps is :  0.28200533584933835  | validation loss is :  0.25436903300583424
# Training accuracy after  1000  bgd steps is :  92.17935349322211 %  | validation accuracy is :  94.16058394160584 %
#
# Training loss after  1500  bgd steps is :  0.23356629981339455  | validation loss is :  0.2076030994246338
# Training accuracy after  1500  bgd steps is :  93.84775808133472 %  | validation accuracy is :  96.35036496350365 %
#
# Training loss after  2000  bgd steps is :  0.20139780669067897  | validation loss is :  0.17759381723003795
# Training accuracy after  2000  bgd steps is :  95.30761209593325 %  | validation accuracy is :  96.35036496350365 %
#
# Training loss after  2500  bgd steps is :  0.17838099822676934  | validation loss is :  0.15657939533623338
# Training accuracy after  2500  bgd steps is :  95.82898852971846 %  | validation accuracy is :  97.8102189781022 %
#
# Training loss after  3000  bgd steps is :  0.16111146983449084  | validation loss is :  0.1410092699114766
# Training accuracy after  3000  bgd steps is :  96.24608967674662 %  | validation accuracy is :  97.8102189781022 %
#
# Training loss after  3500  bgd steps is :  0.1476906466785779  | validation loss is :  0.128987200363523
# Training accuracy after  3500  bgd steps is :  96.76746611053181 %  | validation accuracy is :  97.8102189781022 %
#
# Training loss after  4000  bgd steps is :  0.13696754047117726  | validation loss is :  0.11940482593231837
# Training accuracy after  4000  bgd steps is :  96.76746611053181 %  | validation accuracy is :  97.8102189781022 %
#
# Training loss after  4500  bgd steps is :  0.12820421014503816  | validation loss is :  0.11157192023382478
# Training accuracy after  4500  bgd steps is :  96.97601668404589 %  | validation accuracy is :  97.8102189781022 %
#
# Training loss after  5000  bgd steps is :  0.12090691815667517  | validation loss is :  0.10503690401112055
# Training accuracy after  5000  bgd steps is :  97.288842544317 %  | validation accuracy is :  97.8102189781022 %
#
# Training loss after  5500  bgd steps is :  0.11473364343761593  | validation loss is :  0.0994921617536291
# Training accuracy after  5500  bgd steps is :  97.39311783107404 %  | validation accuracy is :  97.8102189781022 %
#
# Training loss after  6000  bgd steps is :  0.10944043079293359  | validation loss is :  0.0947209405642474
# Training accuracy after  6000  bgd steps is :  97.49739311783108 %  | validation accuracy is :  97.8102189781022 %
#
# Training loss after  6500  bgd steps is :  0.10484885171414939  | validation loss is :  0.09056606663951972
# Training accuracy after  6500  bgd steps is :  97.60166840458811 %  | validation accuracy is :  97.8102189781022 %
#
# Training loss after  7000  bgd steps is :  0.10082552900666757  | validation loss is :  0.08691073342581104
# Training accuracy after  7000  bgd steps is :  97.60166840458811 %  | validation accuracy is :  97.8102189781022 %
#
# Training loss after  7500  bgd steps is :  0.09726883979549729  | validation loss is :  0.08366627197938463
# Training accuracy after  7500  bgd steps is :  97.60166840458811 %  | validation accuracy is :  97.8102189781022 %
#
# Training loss after  8000  bgd steps is :  0.09410003911885016  | validation loss is :  0.0807641177021821
# Training accuracy after  8000  bgd steps is :  97.70594369134515 %  | validation accuracy is :  97.8102189781022 %
#
# Training loss after  8500  bgd steps is :  0.09125718847506406  | validation loss is :  0.07815038569326123
# Training accuracy after  8500  bgd steps is :  97.70594369134515 %  | validation accuracy is :  97.8102189781022 %
#
# Training loss after  9000  bgd steps is :  0.0886909119063216  | validation loss is :  0.0757821169987022
# Training accuracy after  9000  bgd steps is :  97.8102189781022 %  | validation accuracy is :  97.8102189781022 %
#
# Training loss after  9500  bgd steps is :  0.08636137128425853  | validation loss is :  0.07362462408609635
# Training accuracy after  9500  bgd steps is :  97.8102189781022 %  | validation accuracy is :  97.8102189781022 %
# [[-3.46110703]
#  [-2.97906923]
#  [-2.76745165]
#  [ 0.27724663]]
# -0.7400142734275418
#  -------------------------------------------------------------------------------------------
#
#  For learning rate  10 ------------------------------------------------------------
#
# Training loss after  0  bgd steps is :  0.6931469805599655  | validation loss is :  0.6931469805599654
# Training accuracy after  0  bgd steps is :  45.04692387904067 %  | validation accuracy is :  38.68613138686131 %
#
# Training loss after  500  bgd steps is :  0.027269288011354642  | validation loss is :  0.019365163473915384
# Training accuracy after  500  bgd steps is :  98.74869655891554 %  | validation accuracy is :  99.27007299270073 %
#
# Training loss after  1000  bgd steps is :  0.02467275112734853  | validation loss is :  0.01848125481002189
# Training accuracy after  1000  bgd steps is :  98.74869655891554 %  | validation accuracy is :  99.27007299270073 %
#
# Training loss after  1500  bgd steps is :  0.023506487927469535  | validation loss is :  0.018439166897432923
# Training accuracy after  1500  bgd steps is :  98.74869655891554 %  | validation accuracy is :  99.27007299270073 %
#
# Training loss after  2000  bgd steps is :  0.0228199268471107  | validation loss is :  0.018579715843118638
# Training accuracy after  2000  bgd steps is :  98.74869655891554 %  | validation accuracy is :  99.27007299270073 %
#
# Training loss after  2500  bgd steps is :  0.022363193969343678  | validation loss is :  0.0187717622131383
# Training accuracy after  2500  bgd steps is :  98.54014598540147 %  | validation accuracy is :  99.27007299270073 %
#
# Training loss after  3000  bgd steps is :  0.022037140353069227  | validation loss is :  0.018975716593727966
# Training accuracy after  3000  bgd steps is :  98.54014598540147 %  | validation accuracy is :  99.27007299270073 %
#
# Training loss after  3500  bgd steps is :  0.021793392402844225  | validation loss is :  0.019177197327400943
# Training accuracy after  3500  bgd steps is :  98.54014598540147 %  | validation accuracy is :  99.27007299270073 %
#
# Training loss after  4000  bgd steps is :  0.02160514350782729  | validation loss is :  0.019370605631087646
# Training accuracy after  4000  bgd steps is :  98.54014598540147 %  | validation accuracy is :  99.27007299270073 %
#
# Training loss after  4500  bgd steps is :  0.021456188866705955  | validation loss is :  0.019553861284007025
# Training accuracy after  4500  bgd steps is :  98.54014598540147 %  | validation accuracy is :  99.27007299270073 %
#
# Training loss after  5000  bgd steps is :  0.021336092558270608  | validation loss is :  0.019726416001943286
# Training accuracy after  5000  bgd steps is :  98.54014598540147 %  | validation accuracy is :  99.27007299270073 %
#
# Training loss after  5500  bgd steps is :  0.0212378023778208  | validation loss is :  0.01988841565864688
# Training accuracy after  5500  bgd steps is :  98.54014598540147 %  | validation accuracy is :  99.27007299270073 %
#
# Training loss after  6000  bgd steps is :  0.021156368913325695  | validation loss is :  0.020040318677254577
# Training accuracy after  6000  bgd steps is :  98.54014598540147 %  | validation accuracy is :  99.27007299270073 %
#
# Training loss after  6500  bgd steps is :  0.021088210910157217  | validation loss is :  0.020182712980928483
# Training accuracy after  6500  bgd steps is :  98.54014598540147 %  | validation accuracy is :  99.27007299270073 %
#
# Training loss after  7000  bgd steps is :  0.02103067116429217  | validation loss is :  0.020316225543804755
# Training accuracy after  7000  bgd steps is :  99.06152241918666 %  | validation accuracy is :  99.27007299270073 %
#
# Training loss after  7500  bgd steps is :  0.020981736207239702  | validation loss is :  0.02044147741646399
# Training accuracy after  7500  bgd steps is :  99.06152241918666 %  | validation accuracy is :  99.27007299270073 %
#
# Training loss after  8000  bgd steps is :  0.02093985288356669  | validation loss is :  0.02055906193333234
# Training accuracy after  8000  bgd steps is :  99.06152241918666 %  | validation accuracy is :  99.27007299270073 %
#
# Training loss after  8500  bgd steps is :  0.020903804608373936  | validation loss is :  0.02066953502828161
# Training accuracy after  8500  bgd steps is :  99.06152241918666 %  | validation accuracy is :  99.27007299270073 %
#
# Training loss after  9000  bgd steps is :  0.02087262567024995  | validation loss is :  0.02077341194206686
# Training accuracy after  9000  bgd steps is :  99.06152241918666 %  | validation accuracy is :  99.27007299270073 %
#
# Training loss after  9500  bgd steps is :  0.02084554051772798  | validation loss is :  0.02087116728288216
# Training accuracy after  9500  bgd steps is :  99.06152241918666 %  | validation accuracy is :  99.27007299270073 %
# [[-19.56686861]
#  [-21.31568767]
#  [-19.69439122]
#  [ -0.88427537]]
# -9.373837249345602
#  -------------------------------------------------------------------------------------------

# %%
"Custom learning rate chosen by hit and trial"
# Out:
# 'Custom learning rate chosen by hit and trial'

# %%
""" SGD on 0.005 learning rate"""
log_regressor_sgd = MyLogisticRegression()
log_regressor_sgd.fit(X_train, y_train, X_val, y_val, epochs = 10000 ,learning_rate = 0.05, grad_type = "sgd")
print(log_regressor_sgd.W)
print(log_regressor_sgd.b)
loss_history_sgd = log_regressor_sgd.loss_history
val_loss_history_sgd = log_regressor_sgd.val_loss_history
train_acc_history_sgd = log_regressor_sgd.train_acc_history
val_acc_history_sgd = log_regressor_sgd.val_acc_history
plt.plot([x for x in range(len(loss_history_sgd))], loss_history_sgd, label = "Training  loss " )
plt.plot([x for x in range(len(val_loss_history_sgd))], val_loss_history_sgd, label = "Validation  loss")
plt.xlabel('epochs')
plt.ylabel('loss')
plt.legend()
plt.show()
plt.plot([x for x in range(len(train_acc_history_sgd))], train_acc_history_sgd, label = "Training  accuracy " )
plt.plot([x for x in range(len(val_acc_history_sgd))], val_acc_history_sgd, label = "Validation  accuracy")
plt.xlabel('epochs')
plt.ylabel('accuracy')
plt.legend()
plt.show()
# Out:
# Training loss after  0  sgd steps is :  0.6931469805599655  | validation loss is :  0.6931469805599654
# Training accuracy after  0  sgd steps is :  45.04692387904067 %  | validation accuracy is :  38.68613138686131 %
#
# Training loss after  500  sgd steps is :  0.1844886929816898  | validation loss is :  0.15874926735178285
# Training accuracy after  500  sgd steps is :  95.51616266944734 %  | validation accuracy is :  96.35036496350365 %
#
# Training loss after  1000  sgd steps is :  0.11970400130281375  | validation loss is :  0.10520771017863197
# Training accuracy after  1000  sgd steps is :  97.70594369134515 %  | validation accuracy is :  97.8102189781022 %
#
# Training loss after  1500  sgd steps is :  0.09698018632261686  | validation loss is :  0.08334718369619731
# Training accuracy after  1500  sgd steps is :  97.70594369134515 %  | validation accuracy is :  97.8102189781022 %
#
# Training loss after  2000  sgd steps is :  0.0840557162718331  | validation loss is :  0.07123291278061519
# Training accuracy after  2000  sgd steps is :  97.8102189781022 %  | validation accuracy is :  97.8102189781022 %
#
# Training loss after  2500  sgd steps is :  0.07556803622277908  | validation loss is :  0.06298973871592066
# Training accuracy after  2500  sgd steps is :  98.01876955161627 %  | validation accuracy is :  98.54014598540147 %
#
# Training loss after  3000  sgd steps is :  0.07106963064146918  | validation loss is :  0.061155495468403695
# Training accuracy after  3000  sgd steps is :  98.22732012513035 %  | validation accuracy is :  98.54014598540147 %
#
# Training loss after  3500  sgd steps is :  0.06566925593334441  | validation loss is :  0.05389329664805658
# Training accuracy after  3500  sgd steps is :  98.1230448383733 %  | validation accuracy is :  98.54014598540147 %
#
# Training loss after  4000  sgd steps is :  0.06255770701068039  | validation loss is :  0.05167631160958843
# Training accuracy after  4000  sgd steps is :  98.1230448383733 %  | validation accuracy is :  98.54014598540147 %
#
# Training loss after  4500  sgd steps is :  0.05976247287719988  | validation loss is :  0.04821033973063543
# Training accuracy after  4500  sgd steps is :  98.01876955161627 %  | validation accuracy is :  98.54014598540147 %
#
# Training loss after  5000  sgd steps is :  0.05775598840804364  | validation loss is :  0.047702934617492074
# Training accuracy after  5000  sgd steps is :  98.1230448383733 %  | validation accuracy is :  98.54014598540147 %
#
# Training loss after  5500  sgd steps is :  0.05554129251221235  | validation loss is :  0.04468026738010201
# Training accuracy after  5500  sgd steps is :  98.01876955161627 %  | validation accuracy is :  98.54014598540147 %
#
# Training loss after  6000  sgd steps is :  0.05424231517560654  | validation loss is :  0.04377075935378387
# Training accuracy after  6000  sgd steps is :  98.1230448383733 %  | validation accuracy is :  98.54014598540147 %
#
# Training loss after  6500  sgd steps is :  0.052984905960471416  | validation loss is :  0.04243852667570478
# Training accuracy after  6500  sgd steps is :  98.1230448383733 %  | validation accuracy is :  98.54014598540147 %
#
# Training loss after  7000  sgd steps is :  0.051082772029029694  | validation loss is :  0.03922134897960042
# Training accuracy after  7000  sgd steps is :  98.1230448383733 %  | validation accuracy is :  98.54014598540147 %
#
# Training loss after  7500  sgd steps is :  0.050185970734224296  | validation loss is :  0.03824022389651106
# Training accuracy after  7500  sgd steps is :  98.1230448383733 %  | validation accuracy is :  98.54014598540147 %
#
# Training loss after  8000  sgd steps is :  0.04901253301732315  | validation loss is :  0.03821621317603835
# Training accuracy after  8000  sgd steps is :  98.1230448383733 %  | validation accuracy is :  98.54014598540147 %
#
# Training loss after  8500  sgd steps is :  0.04832278144241798  | validation loss is :  0.037294327158886635
# Training accuracy after  8500  sgd steps is :  98.1230448383733 %  | validation accuracy is :  98.54014598540147 %
#
# Training loss after  9000  sgd steps is :  0.04747448062937194  | validation loss is :  0.03651798542557226
# Training accuracy after  9000  sgd steps is :  98.1230448383733 %  | validation accuracy is :  98.54014598540147 %
#
# Training loss after  9500  sgd steps is :  0.046893793198063305  | validation loss is :  0.03646555561191206
# Training accuracy after  9500  sgd steps is :  98.33159541188738 %  | validation accuracy is :  98.54014598540147 %
# [[-5.32903056]
#  [-5.19327666]
#  [-4.78382637]
#  [ 0.39876234]]
# [[-1.76568504]]

# %%
log_regressor_bgd = MyLogisticRegression()
log_regressor_bgd.fit(X_train, y_train, X_val, y_val, epochs = 10000 ,learning_rate = 0.05, grad_type = "bgd")
print(log_regressor_bgd.W)
print(log_regressor_bgd.b)
loss_history_bgd = log_regressor_bgd.loss_history
val_loss_history_bgd = log_regressor_bgd.val_loss_history
train_acc_history_bgd = log_regressor_bgd.train_acc_history
val_acc_history_bgd = log_regressor_bgd.val_acc_history
plt.plot([x for x in range(10000)], loss_history_bgd, label = "Training  Loss " )
plt.plot([x for x in range(10000)], val_loss_history_bgd, label = "Validation  Loss")
plt.xlabel('epochs')
plt.ylabel('loss')
plt.legend()
plt.show()
plt.plot([x for x in range(10000)], train_acc_history_bgd, label = "Training  accuracy " )
plt.plot([x for x in range(10000)], val_acc_history_bgd, label = "Validation  accuracy")
plt.xlabel('epochs')
plt.ylabel('accuracy')
plt.legend()
plt.show()
# Out:
# Training loss after  0  bgd steps is :  0.6931469805599655  | validation loss is :  0.6931469805599654
# Training accuracy after  0  bgd steps is :  45.04692387904067 %  | validation accuracy is :  38.68613138686131 %
#
# Training loss after  500  bgd steps is :  0.17828816388012325  | validation loss is :  0.15648662176416053
# Training accuracy after  500  bgd steps is :  95.82898852971846 %  | validation accuracy is :  97.8102189781022 %
#
# Training loss after  1000  bgd steps is :  0.1208619263831176  | validation loss is :  0.10499557699599384
# Training accuracy after  1000  bgd steps is :  97.288842544317 %  | validation accuracy is :  97.8102189781022 %
#
# Training loss after  1500  bgd steps is :  0.09724187204762053  | validation loss is :  0.08364151355241761
# Training accuracy after  1500  bgd steps is :  97.60166840458811 %  | validation accuracy is :  97.8102189781022 %
#
# Training loss after  2000  bgd steps is :  0.08421776100379441  | validation loss is :  0.07163255571364448
# Training accuracy after  2000  bgd steps is :  97.8102189781022 %  | validation accuracy is :  97.8102189781022 %
#
# Training loss after  2500  bgd steps is :  0.07586327727372062  | validation loss is :  0.06380159057993647
# Training accuracy after  2500  bgd steps is :  98.01876955161627 %  | validation accuracy is :  98.54014598540147 %
#
# Training loss after  3000  bgd steps is :  0.0699889274094095  | validation loss is :  0.058227391149657
# Training accuracy after  3000  bgd steps is :  98.01876955161627 %  | validation accuracy is :  98.54014598540147 %
#
# Training loss after  3500  bgd steps is :  0.06559703329426257  | validation loss is :  0.0540230201347015
# Training accuracy after  3500  bgd steps is :  98.01876955161627 %  | validation accuracy is :  98.54014598540147 %
#
# Training loss after  4000  bgd steps is :  0.06216652962292867  | validation loss is :  0.05071876771301942
# Training accuracy after  4000  bgd steps is :  98.1230448383733 %  | validation accuracy is :  98.54014598540147 %
#
# Training loss after  4500  bgd steps is :  0.05939780413773468  | validation loss is :  0.0480409747632614
# Training accuracy after  4500  bgd steps is :  98.22732012513035 %  | validation accuracy is :  98.54014598540147 %
#
# Training loss after  5000  bgd steps is :  0.057105808214804245  | validation loss is :  0.04581859510130645
# Training accuracy after  5000  bgd steps is :  98.22732012513035 %  | validation accuracy is :  98.54014598540147 %
#
# Training loss after  5500  bgd steps is :  0.055169754414144484  | validation loss is :  0.04393879430179432
# Training accuracy after  5500  bgd steps is :  98.22732012513035 %  | validation accuracy is :  98.54014598540147 %
#
# Training loss after  6000  bgd steps is :  0.05350725267408458  | validation loss is :  0.04232389050138251
# Training accuracy after  6000  bgd steps is :  98.22732012513035 %  | validation accuracy is :  98.54014598540147 %
#
# Training loss after  6500  bgd steps is :  0.05206005119693854  | validation loss is :  0.04091851599028148
# Training accuracy after  6500  bgd steps is :  98.22732012513035 %  | validation accuracy is :  98.54014598540147 %
#
# Training loss after  7000  bgd steps is :  0.050785718651509194  | validation loss is :  0.03968205751224781
# Training accuracy after  7000  bgd steps is :  98.22732012513035 %  | validation accuracy is :  98.54014598540147 %
#
# Training loss after  7500  bgd steps is :  0.0496525604414308  | validation loss is :  0.03858399492760034
# Training accuracy after  7500  bgd steps is :  98.22732012513035 %  | validation accuracy is :  98.54014598540147 %
#
# Training loss after  8000  bgd steps is :  0.04863638734120549  | validation loss is :  0.037600913944658546
# Training accuracy after  8000  bgd steps is :  98.22732012513035 %  | validation accuracy is :  98.54014598540147 %
#
# Training loss after  8500  bgd steps is :  0.04771839172289147  | validation loss is :  0.036714527876741676
# Training accuracy after  8500  bgd steps is :  98.22732012513035 %  | validation accuracy is :  98.54014598540147 %
#
# Training loss after  9000  bgd steps is :  0.0468837108798259  | validation loss is :  0.035910330103664054
# Training accuracy after  9000  bgd steps is :  98.22732012513035 %  | validation accuracy is :  98.54014598540147 %
#
# Training loss after  9500  bgd steps is :  0.04612043040052663  | validation loss is :  0.03517665334231373
# Training accuracy after  9500  bgd steps is :  98.22732012513035 %  | validation accuracy is :  98.54014598540147 %
# [[-5.15475132]
#  [-5.27657974]
#  [-4.8764618 ]
#  [ 0.3211782 ]]
# -1.5917725499664215

# %%
"""Exploratory Data Analysis for the BankNote dataset """
# Out:
# 'Exploratory Data Analysis for the BankNote dataset '

# %%
df = pd.read_csv("LoR_dataset/data_banknote_authentication.txt",sep="," , names = ["col1", "col2", "col3", "col4" , "val"])

# %%
df.head()
# Out:
#       col1    col2    col3     col4  val
# 0  3.62160  8.6661 -2.8073 -0.44699    0
# 1  4.54590  8.1674 -2.4586 -1.46210    0
# 2  3.86600 -2.6383  1.9242  0.10645    0
# 3  3.45660  9.5228 -4.0112 -3.59440    0
# 4  0.32924 -4.4552  4.5718 -0.98880    0

# %%
import seaborn as sns
print(df.corr())
sns.heatmap(df.corr(), annot = True)
# Out:
#           col1      col2      col3      col4       val
# col1  1.000000  0.264026 -0.380850  0.276817 -0.724843
# col2  0.264026  1.000000 -0.786895 -0.526321 -0.444688
# col3 -0.380850 -0.786895  1.000000  0.318841  0.155883
# col4  0.276817 -0.526321  0.318841  1.000000 -0.023424
# val  -0.724843 -0.444688  0.155883 -0.023424  1.000000

# %%
df.hist(figsize=(16, 20), bins=50, xlabelsize=8, ylabelsize=8); # ; avoid having the matplotlib verbose informations

# %%
sns.pairplot(df,hue='val',diag_kind="hist")

# %%
print(df)
# Out:
#          col1      col2     col3     col4  val
# 0     3.62160   8.66610  -2.8073 -0.44699    0
# 1     4.54590   8.16740  -2.4586 -1.46210    0
# 2     3.86600  -2.63830   1.9242  0.10645    0
# 3     3.45660   9.52280  -4.0112 -3.59440    0
# 4     0.32924  -4.45520   4.5718 -0.98880    0
# ...       ...       ...      ...      ...  ...
# 1367  0.40614   1.34920  -1.4501 -0.55949    1
# 1368 -1.38870  -4.87730   6.4774  0.34179    1
# 1369 -3.75030 -13.45860  17.5932 -2.77710    1
# 1370 -3.56370  -8.38270  12.3930 -1.28230    1
# 1371 -2.54190  -0.65804   2.6842  1.19520    1
#
# [1372 rows x 5 columns]

# %%
from sklearn.linear_model import LogisticRegression
from sklearn import metrics

# %%
logistic_regression = LogisticRegression(max_iter=10000)
logistic_regression.fit(X_train,y_train)
y_pred = logistic_regression.predict(X_test)
accuracy = metrics.accuracy_score(y_test, y_pred)
print("Accuracy on the test set :",accuracy*100, " %")
y_pred_train = logistic_regression.predict(X_train)
accuracy = metrics.accuracy_score(y_pred_train, y_train)
print("Accuracy Train:",accuracy*100, " %")
# Out:
# Accuracy on the test set : 97.82608695652173  %
# Accuracy Train: 98.22732012513035  %
# C:\Users\Asus\Anaconda3\lib\site-packages\sklearn\linear_model\logistic.py:432: FutureWarning: Default solver will be changed to 'lbfgs' in 0.22. Specify a solver to silence this warning.
#   FutureWarning)
# C:\Users\Asus\Anaconda3\lib\site-packages\sklearn\utils\validation.py:724: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)

# %%
df=pd.read_csv('Q4_Dataset.txt',delim_whitespace=True,header=None)
X=df[[1,2]].to_numpy()
y=df[[0]].to_numpy()
mean = X.mean(axis = 0)
std = X.std(axis = 0)
X = (X - X.mean(axis = 0))/X.std(axis = 0)
df.head()
# Out:
#      0     1    2
# 0  0.0  32.0  3.0
# 1  0.0  45.0  2.0
# 2  1.0  60.0  2.0
# 3  0.0  53.0  1.0
# 4  0.0  25.0  4.0

# %%
log_regressor = MyLogisticRegression()
log_regressor.fit(X,y, epochs = 10000 ,learning_rate = 0.005)
# Out:
# Training loss after  0  iterations is  0.6931469805599654
# Training accuracy after  0  iterations is :  42.42424242424242 %
#
# Training loss after  500  iterations is  0.6242270384157194
# Training accuracy after  500  iterations is :  66.66666666666667 %
#
# Training loss after  1000  iterations is  0.5962478502142385
# Training accuracy after  1000  iterations is :  72.72727272727273 %
#
# Training loss after  1500  iterations is  0.5815673633285742
# Training accuracy after  1500  iterations is :  72.72727272727273 %
#
# Training loss after  2000  iterations is  0.5728559708604984
# Training accuracy after  2000  iterations is :  75.75757575757575 %
#
# Training loss after  2500  iterations is  0.567363693193068
# Training accuracy after  2500  iterations is :  78.78787878787878 %
#
# Training loss after  3000  iterations is  0.5637777397184307
# Training accuracy after  3000  iterations is :  78.78787878787878 %
#
# Training loss after  3500  iterations is  0.561380793899521
# Training accuracy after  3500  iterations is :  75.75757575757575 %
#
# Training loss after  4000  iterations is  0.559750515820084
# Training accuracy after  4000  iterations is :  75.75757575757575 %
#
# Training loss after  4500  iterations is  0.558626555841508
# Training accuracy after  4500  iterations is :  75.75757575757575 %
#
# Training loss after  5000  iterations is  0.5578432064583466
# Training accuracy after  5000  iterations is :  75.75757575757575 %
#
# Training loss after  5500  iterations is  0.5572924018041114
# Training accuracy after  5500  iterations is :  75.75757575757575 %
#
# Training loss after  6000  iterations is  0.5569022853853098
# Training accuracy after  6000  iterations is :  75.75757575757575 %
#
# Training loss after  6500  iterations is  0.5566243121840918
# Training accuracy after  6500  iterations is :  75.75757575757575 %
#
# Training loss after  7000  iterations is  0.5564252509189604
# Training accuracy after  7000  iterations is :  75.75757575757575 %
#
# Training loss after  7500  iterations is  0.556282101308868
# Training accuracy after  7500  iterations is :  75.75757575757575 %
#
# Training loss after  8000  iterations is  0.5561787962708594
# Training accuracy after  8000  iterations is :  75.75757575757575 %
#
# Training loss after  8500  iterations is  0.5561040241089631
# Training accuracy after  8500  iterations is :  75.75757575757575 %
#
# Training loss after  9000  iterations is  0.556049768388717
# Training accuracy after  9000  iterations is :  75.75757575757575 %
#
# Training loss after  9500  iterations is  0.5560103161634421
# Training accuracy after  9500  iterations is :  75.75757575757575 %

# %%
print(log_regressor.W)
print(log_regressor.b)
# Out:
# [[1.38835658]
#  [0.73511168]]
# -0.3497166832331577

# %%
print(np.exp(log_regressor.W))
print(np.exp(log_regressor.b))
# Out:
# [[4.00825738]
#  [2.08571492]]
# 0.7048877679546853

# %%
# Out:
# 0.8981808926762442

# %%
X_test = np.array([[75,2]])
print(X_test.shape)
print(mean.shape)
X_test = (X_test-mean)/std
print(X_test)
# Out:
# (1, 2)
# (2,)
# [[ 1.74336321 -0.78173596]]

# %%
y_test = 1/(1 + np.exp(-(np.dot(X_test,log_regressor.W) + log_regressor.b)))
print(y_test)
# Out:
# [[0.8169816]]

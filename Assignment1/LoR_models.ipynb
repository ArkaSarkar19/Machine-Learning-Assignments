# %%
import numpy as np
import pandas as pd
from scratch import *
# Out:
# Linear Regression
# Training loss after  0  iterations is  1.5811388300841898
# Training loss after  500  iterations is  0.11522308082978301
# Training loss after  1000  iterations is  0.11531590760055782
# Training loss after  1500  iterations is  0.11540873459346981
# Training loss after  2000  iterations is  0.11550156192142631
# Training loss after  2500  iterations is  0.11559438970508162
# Training loss after  3000  iterations is  0.11568721806509605
# Training loss after  3500  iterations is  0.11578004712213608
# Training loss after  4000  iterations is  0.11587287699688441
# Training loss after  4500  iterations is  0.11596570781002223
# Predicted Values: [[2.76277438]
#  [2.76277438]]
# True Values: [3]

# %%
preprocess = MyPreProcessor()
X,Y=preprocess.pre_process(2)
print(X)
print(Y)
# Out:
# [[-0.3045281   0.43511636 -0.85057826 -0.39569855]
#  [-0.60684187  2.62093955  0.4518636  -0.92911949]
#  [-0.61187079  0.22062834 -0.14103162 -0.41809146]
#  ...
#  [-0.16889989  0.73552294 -1.22924142 -1.16071057]
#  [ 0.25742008 -1.21220952  1.79840337 -0.58065355]
#  [-0.48239991  0.21963205  1.63622082  0.03404369]]
# [[1]
#  [0]
#  [1]
#  ...
#  [1]
#  [0]
#  [0]]

# %%
ratio = X.shape[0]//10
X_train = X[0:7*ratio, :]
y_train = Y[0:7*ratio, :]
X_val = X[7*ratio : 8*ratio, :]
y_val = Y[7*ratio : 8*ratio, :]
X_test = X[8*ratio:, :]
y_test = Y[8*ratio:,:]
print(X_train.shape,y_train.shape )
print(X_test.shape,y_test.shape )
print(X_val.shape, y_val.shape)
# Out:
# (959, 4) (959, 1)
# (276, 4) (276, 1)
# (137, 4) (137, 1)

# %%
pp = MyPreProcessor()
W = pp.get_analytical_sol()
print(W)
X,y = pp.pre_process(0)
bias = np.zeros((X.shape[0],1))
bias.fill(1)
X = np.append(X,bias, axis = 1)
y_pred = np.dot(X,W)
error = (np.sum((y-y_pred)**2)/y_pred.shape[0])**0.5
mae = np.sum(abs(y-y_pred))/y_pred.shape[0]
print(error)
print(mae)
# Out:
# [[ 0.63253946  0.14382949 -0.05917311 ... -0.45314852 -0.10127735
#    1.        ]
#  [ 0.63253946  0.00849443 -0.17947094 ... -0.55089051 -0.44262246
#    1.        ]
#  [ 2.13626242  0.01601304 -0.17195233 ... -0.51179372 -0.49299718
#    1.        ]
#  ...
#  [ 2.13626242 -0.09676618 -0.24713848 ... -0.5764538  -0.49525276
#    1.        ]
#  [ 3.63998538 -0.38999216 -0.51780861 ... -0.83734974 -0.79599736
#    1.        ]
#  [ 0.63253946  0.17390395 -0.07421034 ... -0.21556029 -0.18698956
#    1.        ]]
# [[ -0.25628631]
#  [ -0.51655077]
#  [  7.900679  ]
#  [  7.50021818]
#  [  6.02815842]
#  [-13.36837538]
#  [ -6.73825106]
#  [  5.79235855]
#  [  9.66007587]]
# 2.1959658591369107
# 1.583133232202801

# %%
"""Running SGD on Banknote dataset and with LR = 0.0001, 0.01, 10"""
L = [0.0001,0.01,10]

# %%
for i in range(3):
    print("\n For learning rate ", L[i], "------------------------------------------------------------ ")
    log_regressor_sgd = MyLogisticRegression()
    log_regressor_sgd.fit(X_train, y_train, X_test, y_test, epochs = 10 ,learning_rate = L[i], grad_type = "sgd")
    print(log_regressor_sgd.W)
    print(log_regressor_sgd.b)
    loss_history_sgd = log_regressor_sgd.loss_history
    val_loss_history_sgd = log_regressor_sgd.val_loss_history
    train_acc_history_sgd = log_regressor_sgd.train_acc_history
    val_acc_history_sgd = log_regressor_sgd.val_acc_history
    plt.plot([x for x in range(len(loss_history_sgd))], loss_history_sgd, label = "Training  loss " )
    plt.plot([x for x in range(len(val_loss_history_sgd))], val_loss_history_sgd, label = "Validation  loss")
    plt.xlabel('iterations')
    plt.ylabel('loss')
    plt.legend()
    plt.show()
    plt.plot([x for x in range(len(train_acc_history_sgd))], train_acc_history_sgd, label = "Training  accuracy " )
    plt.plot([x for x in range(len(val_acc_history_sgd))], val_acc_history_sgd, label = "Validation  accuracy")
    plt.xlabel('iterations')
    plt.ylabel('loss')
    plt.legend()
    plt.show()
    
    print("\n -------------------------------------------------------------------------------------------")
# Out:
#  For learning rate  0.0001 ------------------------------------------------------------
#
# Training loss after  0  sgd steps is :  0.6931471805599453  | validation loss is :  0.6931558885203337
# Training accuracy after  0  sgd steps is :  39.62460896767466 %  | validation accuracy is :  42.391304347826086 %
#
# Training loss after  2000  sgd steps is :  0.6392414850413062  | validation loss is :  0.6622183344149098
# Training accuracy after  2000  sgd steps is :  70.17726798748696 %  | validation accuracy is :  65.21739130434783 %
#
# Training loss after  4000  sgd steps is :  0.5569766474587001  | validation loss is :  0.6367495470056591
# Training accuracy after  4000  sgd steps is :  71.42857142857143 %  | validation accuracy is :  65.57971014492753 %
#
# Training loss after  6000  sgd steps is :  0.7118418731736879  | validation loss is :  0.6154189447909445
# Training accuracy after  6000  sgd steps is :  71.74139728884255 %  | validation accuracy is :  65.57971014492753 %
#
# Training loss after  8000  sgd steps is :  0.35294359349347604  | validation loss is :  0.597355783545879
# Training accuracy after  8000  sgd steps is :  72.1584984358707 %  | validation accuracy is :  66.66666666666667 %
#
# Training loss after  10000  sgd steps is :  0.3423987807479563  | validation loss is :  0.5815651571634332
# Training accuracy after  10000  sgd steps is :  72.78415015641293 %  | validation accuracy is :  67.7536231884058 %
# [[-0.22190835]
#  [-0.26190669]
#  [ 0.01995354]
#  [ 0.00374157]]
# [-0.04944057]
#  -------------------------------------------------------------------------------------------
#
#  For learning rate  0.01 ------------------------------------------------------------
#
# Training loss after  0  sgd steps is :  0.6931471805599453  | validation loss is :  0.694029005636045
# Training accuracy after  0  sgd steps is :  39.62460896767466 %  | validation accuracy is :  42.391304347826086 %
#
# Training loss after  2000  sgd steps is :  0.10925533681524875  | validation loss is :  0.2113483532010344
# Training accuracy after  2000  sgd steps is :  96.97601668404589 %  | validation accuracy is :  98.18840579710145 %
#
# Training loss after  4000  sgd steps is :  0.01682990244246688  | validation loss is :  0.13513895312872876
# Training accuracy after  4000  sgd steps is :  97.91449426485923 %  | validation accuracy is :  98.91304347826086 %
#
# Training loss after  6000  sgd steps is :  0.3548465070304608  | validation loss is :  0.10384136493887616
# Training accuracy after  6000  sgd steps is :  98.01876955161627 %  | validation accuracy is :  98.55072463768117 %
#
# Training loss after  8000  sgd steps is :  0.05659657517971312  | validation loss is :  0.08658708191256678
# Training accuracy after  8000  sgd steps is :  98.33159541188738 %  | validation accuracy is :  98.91304347826086 %
#
# Training loss after  10000  sgd steps is :  0.0008737461305250256  | validation loss is :  0.07547810303771192
# Training accuracy after  10000  sgd steps is :  98.22732012513035 %  | validation accuracy is :  98.55072463768117 %
# [[-4.42532105]
#  [-2.57458251]
#  [-2.78174471]
#  [-0.32799809]]
# [0.05896522]
#  -------------------------------------------------------------------------------------------
#
#  For learning rate  10 ------------------------------------------------------------
#
# Training loss after  0  sgd steps is :  0.6931471805599453  | validation loss is :  4.979835000777211
# Training accuracy after  0  sgd steps is :  39.62460896767466 %  | validation accuracy is :  42.391304347826086 %
# E:\sem5\MachineLearning\Machine-Learning-Assignments\Assignment1\scratch.py:414: RuntimeWarning: divide by zero encountered in log
#   loss = (-1/m)*(np.sum(y*np.log(A) + (1-y)*np.log(1-A)))
# E:\sem5\MachineLearning\Machine-Learning-Assignments\Assignment1\scratch.py:414: RuntimeWarning: invalid value encountered in multiply
#   loss = (-1/m)*(np.sum(y*np.log(A) + (1-y)*np.log(1-A)))
# E:\sem5\MachineLearning\Machine-Learning-Assignments\Assignment1\scratch.py:427: RuntimeWarning: divide by zero encountered in log
#   loss = -(y_i*np.log(a_i) + (1-y_i)*np.log(1-a_i))
# E:\sem5\MachineLearning\Machine-Learning-Assignments\Assignment1\scratch.py:427: RuntimeWarning: invalid value encountered in multiply
#   loss = -(y_i*np.log(a_i) + (1-y_i)*np.log(1-a_i))
# Training loss after  2000  sgd steps is :  -0.0  | validation loss is :  nan
# Training accuracy after  2000  sgd steps is :  97.08029197080292 %  | validation accuracy is :  98.18840579710145 %
#
# Training loss after  4000  sgd steps is :  -0.0  | validation loss is :  nan
# Training accuracy after  4000  sgd steps is :  93.0135557872784 %  | validation accuracy is :  94.92753623188406 %
#
# Training loss after  6000  sgd steps is :  -0.0  | validation loss is :  nan
# Training accuracy after  6000  sgd steps is :  97.288842544317 %  | validation accuracy is :  98.55072463768117 %
#
# Training loss after  8000  sgd steps is :  3.7303493627405954e-14  | validation loss is :  nan
# Training accuracy after  8000  sgd steps is :  97.91449426485923 %  | validation accuracy is :  98.55072463768117 %
#
# Training loss after  10000  sgd steps is :  -0.0  | validation loss is :  nan
# Training accuracy after  10000  sgd steps is :  98.1230448383733 %  | validation accuracy is :  98.55072463768117 %
# [[-185.00066453]
#  [-128.47257424]
#  [-109.79785671]
#  [ -19.3623808 ]]
# [-7.21263208]
#  -------------------------------------------------------------------------------------------

# %%
"""Running BGD on Banknote dataset and with LR = 0.0001, 0.01, 10"""
L = [0.0001,0.01,10]

# %%
for i in range(3):
    print("\n For learning rate ", L[i], "------------------------------------------------------------ ")
    log_regressor_bgd = MyLogisticRegression()
    log_regressor_bgd.fit(X_train, y_train, X_test, y_test, epochs = 10000 ,learning_rate = L[i], grad_type = "bgd")
    print(log_regressor_bgd.W)
    print(log_regressor_bgd.b)
    loss_history_bgd = log_regressor_bgd.loss_history
    val_loss_history_bgd = log_regressor_bgd.val_loss_history
    train_acc_history_bgd = log_regressor_bgd.train_acc_history
    val_acc_history_bgd = log_regressor_bgd.val_acc_history
    plt.plot([x for x in range(10000)], loss_history_bgd, label = "Training  accuracy " )
    plt.plot([x for x in range(10000)], val_loss_history_bgd, label = "Validation  accuracy")
    plt.xlabel('epochs')
    plt.ylabel('loss')
    plt.legend()
    plt.show()
    plt.plot([x for x in range(10000)], train_acc_history_bgd, label = "Training  accuracy " )
    plt.plot([x for x in range(10000)], val_acc_history_bgd, label = "Validation  accuracy")
    plt.xlabel('epochs')
    plt.ylabel('loss')
    plt.legend()
    plt.show()
    print("\n -------------------------------------------------------------------------------------------")
# Out:
#  For learning rate  0.0001 ------------------------------------------------------------
#
# Training loss after  0  iterations is :  0.6931471805599454  | validation loss is :  0.6931471805599453
# Training accuracy after  0  iterations is :  43.691345151199165 %  | validation accuracy is :  45.289855072463766 %
#
# Training loss after  500  iterations is :  0.6847464492885017  | validation loss is :  0.6847899302150018
# Training accuracy after  500  iterations is :  69.34306569343065 %  | validation accuracy is :  64.13043478260869 %
#
# Training loss after  1000  iterations is :  0.6767657579743309  | validation loss is :  0.6768598503652477
# Training accuracy after  1000  iterations is :  69.4473409801877 %  | validation accuracy is :  64.4927536231884 %
#
# Training loss after  1500  iterations is :  0.6691769701455261  | validation loss is :  0.6693277005687376
# Training accuracy after  1500  iterations is :  69.96871741397288 %  | validation accuracy is :  64.85507246376811 %
#
# Training loss after  2000  iterations is :  0.6619536220127353  | validation loss is :  0.6621660036245188
# Training accuracy after  2000  iterations is :  70.281543274244 %  | validation accuracy is :  65.21739130434783 %
#
# Training loss after  2500  iterations is :  0.6550708967733543  | validation loss is :  0.6553490168154795
# Training accuracy after  2500  iterations is :  70.49009384775809 %  | validation accuracy is :  65.57971014492753 %
#
# Training loss after  3000  iterations is :  0.6485055816481909  | validation loss is :  0.6488526851506184
# Training accuracy after  3000  iterations is :  70.8029197080292 %  | validation accuracy is :  65.57971014492753 %
#
# Training loss after  3500  iterations is :  0.6422360118172634  | validation loss is :  0.6426545809982567
# Training accuracy after  3500  iterations is :  71.11574556830031 %  | validation accuracy is :  65.57971014492753 %
#
# Training loss after  4000  iterations is :  0.6362420048720737  | validation loss is :  0.6367338339136017
# Training accuracy after  4000  iterations is :  71.42857142857143 %  | validation accuracy is :  65.57971014492753 %
#
# Training loss after  4500  iterations is :  0.6305047888527128  | validation loss is :  0.6310710538801252
# Training accuracy after  4500  iterations is :  71.42857142857143 %  | validation accuracy is :  65.57971014492753 %
#
# Training loss after  5000  iterations is :  0.6250069264160568  | validation loss is :  0.6256482506313995
# Training accuracy after  5000  iterations is :  71.42857142857143 %  | validation accuracy is :  65.57971014492753 %
#
# Training loss after  5500  iterations is :  0.6197322372028548  | validation loss is :  0.6204487512150915
# Training accuracy after  5500  iterations is :  71.53284671532847 %  | validation accuracy is :  65.57971014492753 %
#
# Training loss after  6000  iterations is :  0.6146657200457851  | validation loss is :  0.6154571175126237
# Training accuracy after  6000  iterations is :  71.74139728884255 %  | validation accuracy is :  65.57971014492753 %
#
# Training loss after  6500  iterations is :  0.609793476290847  | validation loss is :  0.6106590650395582
# Training accuracy after  6500  iterations is :  71.84567257559958 %  | validation accuracy is :  65.94202898550725 %
#
# Training loss after  7000  iterations is :  0.6051026351900943  | validation loss is :  0.6060413840219558
# Training accuracy after  7000  iterations is :  71.84567257559958 %  | validation accuracy is :  65.94202898550725 %
#
# Training loss after  7500  iterations is :  0.6005812820613818  | validation loss is :  0.6015918634690921
# Training accuracy after  7500  iterations is :  71.84567257559958 %  | validation accuracy is :  66.30434782608697 %
#
# Training loss after  8000  iterations is :  0.5962183896956619  | validation loss is :  0.5972992187377545
# Training accuracy after  8000  iterations is :  72.05422314911367 %  | validation accuracy is :  66.66666666666667 %
#
# Training loss after  8500  iterations is :  0.5920037533189166  | validation loss is :  0.5931530229019816
# Training accuracy after  8500  iterations is :  72.26277372262774 %  | validation accuracy is :  66.66666666666667 %
#
# Training loss after  9000  iterations is :  0.5879279292783148  | validation loss is :  0.5891436420984983
# Training accuracy after  9000  iterations is :  72.36704900938477 %  | validation accuracy is :  66.66666666666667 %
#
# Training loss after  9500  iterations is :  0.5839821775151702  | validation loss is :  0.5852621749064538
# Training accuracy after  9500  iterations is :  72.47132429614182 %  | validation accuracy is :  67.02898550724638 %
# [[-0.21120931]
#  [-0.25144774]
#  [ 0.02064346]
#  [ 0.00425557]]
# -0.047597239599265574
#  -------------------------------------------------------------------------------------------
#
#  For learning rate  0.01 ------------------------------------------------------------
#
# Training loss after  0  iterations is :  0.6931471805599454  | validation loss is :  0.6931471805599453
# Training accuracy after  0  iterations is :  43.691345151199165 %  | validation accuracy is :  45.289855072463766 %
#
# Training loss after  500  iterations is :  0.41642945587505836  | validation loss is :  0.416684061659141
# Training accuracy after  500  iterations is :  87.48696558915536 %  | validation accuracy is :  87.68115942028986 %
#
# Training loss after  1000  iterations is :  0.3173515931087361  | validation loss is :  0.31329746364502314
# Training accuracy after  1000  iterations is :  93.95203336809176 %  | validation accuracy is :  97.10144927536231 %
#
# Training loss after  1500  iterations is :  0.2588311996359841  | validation loss is :  0.2521717535826436
# Training accuracy after  1500  iterations is :  96.35036496350365 %  | validation accuracy is :  97.82608695652173 %
#
# Training loss after  2000  iterations is :  0.22050382802610233  | validation loss is :  0.21233483749251286
# Training accuracy after  2000  iterations is :  96.97601668404589 %  | validation accuracy is :  98.18840579710145 %
#
# Training loss after  2500  iterations is :  0.19356033717722773  | validation loss is :  0.1844627171796883
# Training accuracy after  2500  iterations is :  97.49739311783108 %  | validation accuracy is :  98.55072463768117 %
#
# Training loss after  3000  iterations is :  0.1736173724779095  | validation loss is :  0.16391470467605795
# Training accuracy after  3000  iterations is :  97.49739311783108 %  | validation accuracy is :  98.55072463768117 %
#
# Training loss after  3500  iterations is :  0.15826770228362547  | validation loss is :  0.14815227638401807
# Training accuracy after  3500  iterations is :  97.70594369134515 %  | validation accuracy is :  98.55072463768117 %
#
# Training loss after  4000  iterations is :  0.14608644109682203  | validation loss is :  0.13567907484976682
# Training accuracy after  4000  iterations is :  97.91449426485923 %  | validation accuracy is :  98.91304347826086 %
#
# Training loss after  4500  iterations is :  0.1361793407350214  | validation loss is :  0.12555947750997976
# Training accuracy after  4500  iterations is :  97.91449426485923 %  | validation accuracy is :  98.91304347826086 %
#
# Training loss after  5000  iterations is :  0.12795820203012184  | validation loss is :  0.11718005277388298
# Training accuracy after  5000  iterations is :  98.22732012513035 %  | validation accuracy is :  98.91304347826086 %
#
# Training loss after  5500  iterations is :  0.12102093904404661  | validation loss is :  0.1101226441248465
# Training accuracy after  5500  iterations is :  98.22732012513035 %  | validation accuracy is :  98.91304347826086 %
#
# Training loss after  6000  iterations is :  0.11508369988129687  | validation loss is :  0.10409278647127305
# Training accuracy after  6000  iterations is :  98.22732012513035 %  | validation accuracy is :  98.91304347826086 %
#
# Training loss after  6500  iterations is :  0.10994055349279  | validation loss is :  0.09887732230522324
# Training accuracy after  6500  iterations is :  98.33159541188738 %  | validation accuracy is :  98.91304347826086 %
#
# Training loss after  7000  iterations is :  0.1054385545406623  | validation loss is :  0.09431825627034487
# Training accuracy after  7000  iterations is :  98.33159541188738 %  | validation accuracy is :  98.91304347826086 %
#
# Training loss after  7500  iterations is :  0.10146177410756109  | validation loss is :  0.09029605066855716
# Training accuracy after  7500  iterations is :  98.33159541188738 %  | validation accuracy is :  98.91304347826086 %
#
# Training loss after  8000  iterations is :  0.09792075957477055  | validation loss is :  0.08671862357927684
# Training accuracy after  8000  iterations is :  98.43587069864442 %  | validation accuracy is :  98.91304347826086 %
#
# Training loss after  8500  iterations is :  0.09474539206525733  | validation loss is :  0.08351390772343709
# Training accuracy after  8500  iterations is :  98.22732012513035 %  | validation accuracy is :  98.55072463768117 %
#
# Training loss after  9000  iterations is :  0.09187993235822926  | validation loss is :  0.08062469832017774
# Training accuracy after  9000  iterations is :  98.22732012513035 %  | validation accuracy is :  98.55072463768117 %
#
# Training loss after  9500  iterations is :  0.08927951293456253  | validation loss is :  0.07800501075745636
# Training accuracy after  9500  iterations is :  98.22732012513035 %  | validation accuracy is :  98.55072463768117 %
# [[-4.33538521]
#  [-2.4984044 ]
#  [-2.74079621]
#  [-0.33253979]]
# 0.03788775861801608
#  -------------------------------------------------------------------------------------------
#
#  For learning rate  10 ------------------------------------------------------------
#
# Training loss after  0  iterations is :  0.6931471805599454  | validation loss is :  0.6931471805599453
# Training accuracy after  0  iterations is :  43.691345151199165 %  | validation accuracy is :  45.289855072463766 %
#
# Training loss after  500  iterations is :  0.024944460240822315  | validation loss is :  0.015634429894183295
# Training accuracy after  500  iterations is :  99.16579770594369 %  | validation accuracy is :  99.63768115942028 %
#
# Training loss after  1000  iterations is :  0.02243437981961378  | validation loss is :  0.013783757639280943
# Training accuracy after  1000  iterations is :  99.16579770594369 %  | validation accuracy is :  99.63768115942028 %
#
# Training loss after  1500  iterations is :  0.021342051790393543  | validation loss is :  0.013070509823435375
# Training accuracy after  1500  iterations is :  99.16579770594369 %  | validation accuracy is :  99.63768115942028 %
#
# Training loss after  2000  iterations is :  0.020713359266308955  | validation loss is :  0.012698238529348158
# Training accuracy after  2000  iterations is :  99.06152241918666 %  | validation accuracy is :  99.27536231884058 %
#
# Training loss after  2500  iterations is :  0.02030307954970922  | validation loss is :  0.012475763183448792
# Training accuracy after  2500  iterations is :  98.95724713242961 %  | validation accuracy is :  99.27536231884058 %
#
# Training loss after  3000  iterations is :  0.020015268439550246  | validation loss is :  0.012332415519513676
# Training accuracy after  3000  iterations is :  98.95724713242961 %  | validation accuracy is :  99.27536231884058 %
#
# Training loss after  3500  iterations is :  0.019803615975322975  | validation loss is :  0.01223570644895653
# Training accuracy after  3500  iterations is :  98.95724713242961 %  | validation accuracy is :  99.27536231884058 %
#
# Training loss after  4000  iterations is :  0.019642698385980154  | validation loss is :  0.012168549519423677
# Training accuracy after  4000  iterations is :  98.95724713242961 %  | validation accuracy is :  99.27536231884058 %
#
# Training loss after  4500  iterations is :  0.01951728114091599  | validation loss is :  0.012121096444357929
# Training accuracy after  4500  iterations is :  98.95724713242961 %  | validation accuracy is :  99.27536231884058 %
#
# Training loss after  5000  iterations is :  0.019417636453042345  | validation loss is :  0.012087280934996577
# Training accuracy after  5000  iterations is :  98.95724713242961 %  | validation accuracy is :  99.27536231884058 %
#
# Training loss after  5500  iterations is :  0.019337245739183676  | validation loss is :  0.01206317367937452
# Training accuracy after  5500  iterations is :  98.95724713242961 %  | validation accuracy is :  99.27536231884058 %
#
# Training loss after  6000  iterations is :  0.019271572242373032  | validation loss is :  0.01204612772732572
# Training accuracy after  6000  iterations is :  98.95724713242961 %  | validation accuracy is :  99.27536231884058 %
#
# Training loss after  6500  iterations is :  0.01921736062602163  | validation loss is :  0.012034303240052419
# Training accuracy after  6500  iterations is :  98.95724713242961 %  | validation accuracy is :  99.27536231884058 %
#
# Training loss after  7000  iterations is :  0.01917221562961628  | validation loss is :  0.01202638840941829
# Training accuracy after  7000  iterations is :  98.95724713242961 %  | validation accuracy is :  99.27536231884058 %
#
# Training loss after  7500  iterations is :  0.019134337412433658  | validation loss is :  0.012021428099332883
# Training accuracy after  7500  iterations is :  98.95724713242961 %  | validation accuracy is :  99.27536231884058 %
#
# Training loss after  8000  iterations is :  0.019102349219575224  | validation loss is :  0.012018714643824317
# Training accuracy after  8000  iterations is :  98.95724713242961 %  | validation accuracy is :  99.27536231884058 %
#
# Training loss after  8500  iterations is :  0.01907518168881566  | validation loss is :  0.012017716031614457
# Training accuracy after  8500  iterations is :  98.95724713242961 %  | validation accuracy is :  99.27536231884058 %
#
# Training loss after  9000  iterations is :  0.01905199312297448  | validation loss is :  0.01201802738755233
# Training accuracy after  9000  iterations is :  98.95724713242961 %  | validation accuracy is :  99.27536231884058 %
#
# Training loss after  9500  iterations is :  0.019032113286129585  | validation loss is :  0.012019337420043272
# Training accuracy after  9500  iterations is :  98.95724713242961 %  | validation accuracy is :  99.27536231884058 %
# [[-26.80213361]
#  [-14.53356699]
#  [-18.02861856]
#  [ -2.18882982]]
# -3.319133382789111
#  -------------------------------------------------------------------------------------------

# %%
"Custom learning rate chosen by hit and trial"
# Out:
# 'Custom learning rate chosen by hit and trial'

# %%
""" SGD on 0.005 learning rate"""
log_regressor_sgd = MyLogisticRegression()
log_regressor_sgd.fit(X_train, y_train, X_test, y_test, epochs = 15 ,learning_rate = 0.005, grad_type = "sgd")
print(log_regressor_sgd.W)
print(log_regressor_sgd.b)
loss_history_sgd = log_regressor_sgd.loss_history
val_loss_history_sgd = log_regressor_sgd.val_loss_history
train_acc_history_sgd = log_regressor_sgd.train_acc_history
val_acc_history_sgd = log_regressor_sgd.val_acc_history
plt.plot([x for x in range(len(loss_history_sgd))], loss_history_sgd, label = "Training  loss " )
plt.plot([x for x in range(len(val_loss_history_sgd))], val_loss_history_sgd, label = "Validation  loss")
plt.xlabel('epochs')
plt.ylabel('loss')
plt.legend()
plt.show()
plt.plot([x for x in range(len(train_acc_history_sgd))], train_acc_history_sgd, label = "Training  accuracy " )
plt.plot([x for x in range(len(val_acc_history_sgd))], val_acc_history_sgd, label = "Validation  accuracy")
plt.xlabel('epochs')
plt.ylabel('loss')
plt.legend()
plt.show()
# Out:
# Training loss after  0  sgd steps is :  0.6931471805599453  | validation loss is :  0.6935853080019112
# Training accuracy after  0  sgd steps is :  39.62460896767466 %  | validation accuracy is :  42.391304347826086 %
#
# Training loss after  2000  sgd steps is :  0.1877674465152012  | validation loss is :  0.31258273496281813
# Training accuracy after  2000  sgd steps is :  93.43065693430657 %  | validation accuracy is :  96.73913043478261 %
#
# Training loss after  4000  sgd steps is :  0.044418067407058136  | validation loss is :  0.21177294102620636
# Training accuracy after  4000  sgd steps is :  96.97601668404589 %  | validation accuracy is :  98.18840579710145 %
#
# Training loss after  6000  sgd steps is :  0.43801265264955497  | validation loss is :  0.16351688214699714
# Training accuracy after  6000  sgd steps is :  97.60166840458811 %  | validation accuracy is :  98.55072463768117 %
#
# Training loss after  8000  sgd steps is :  0.0679412848301299  | validation loss is :  0.13553630688552037
# Training accuracy after  8000  sgd steps is :  97.91449426485923 %  | validation accuracy is :  98.91304347826086 %
#
# Training loss after  10000  sgd steps is :  0.00418372955011697  | validation loss is :  0.11696810105526538
# Training accuracy after  10000  sgd steps is :  98.22732012513035 %  | validation accuracy is :  98.91304347826086 %
#
# Training loss after  12000  sgd steps is :  0.02442759029445986  | validation loss is :  0.10395070400876118
# Training accuracy after  12000  sgd steps is :  98.33159541188738 %  | validation accuracy is :  98.91304347826086 %
#
# Training loss after  14000  sgd steps is :  0.07698350664020287  | validation loss is :  0.09422817120008317
# Training accuracy after  14000  sgd steps is :  98.33159541188738 %  | validation accuracy is :  98.91304347826086 %
# [[-3.93910306]
#  [-2.28418195]
#  [-2.42258929]
#  [-0.35938269]]
# [0.02795119]

# %%
log_regressor_bgd = MyLogisticRegression()
log_regressor_bgd.fit(X_train, y_train, X_test, y_test, epochs = 10000 ,learning_rate = 0.005, grad_type = "bgd")
print(log_regressor_bgd.W)
print(log_regressor_bgd.b)
loss_history_bgd = log_regressor_bgd.loss_history
val_loss_history_bgd = log_regressor_bgd.val_loss_history
train_acc_history_bgd = log_regressor_bgd.train_acc_history
val_acc_history_bgd = log_regressor_bgd.val_acc_history
plt.plot([x for x in range(10000)], loss_history_bgd, label = "Training  accuracy " )
plt.plot([x for x in range(10000)], val_loss_history_bgd, label = "Validation  accuracy")
plt.xlabel('epochs')
plt.ylabel('loss')
plt.legend()
plt.show()
plt.plot([x for x in range(10000)], train_acc_history_bgd, label = "Training  accuracy " )
plt.plot([x for x in range(10000)], val_acc_history_bgd, label = "Validation  accuracy")
plt.xlabel('epochs')
plt.ylabel('loss')
plt.legend()
plt.show()
# Out:
# Training loss after  0  iterations is :  0.6931471805599454  | validation loss is :  0.6931471805599453
# Training accuracy after  0  iterations is :  43.691345151199165 %  | validation accuracy is :  45.289855072463766 %
#
# Training loss after  500  iterations is :  0.4985307238917381  | validation loss is :  0.5005632276029895
# Training accuracy after  500  iterations is :  77.89363920750783 %  | validation accuracy is :  74.27536231884058 %
#
# Training loss after  1000  iterations is :  0.4164575407771321  | validation loss is :  0.4167100709377534
# Training accuracy after  1000  iterations is :  87.48696558915536 %  | validation accuracy is :  87.68115942028986 %
#
# Training loss after  1500  iterations is :  0.3596731004731677  | validation loss is :  0.3575715002717987
# Training accuracy after  1500  iterations is :  91.97080291970804 %  | validation accuracy is :  93.84057971014492 %
#
# Training loss after  2000  iterations is :  0.3173759232490248  | validation loss is :  0.3133228566043607
# Training accuracy after  2000  iterations is :  93.95203336809176 %  | validation accuracy is :  97.10144927536231 %
#
# Training loss after  2500  iterations is :  0.28473459812976354  | validation loss is :  0.27919562760051836
# Training accuracy after  2500  iterations is :  95.09906152241918 %  | validation accuracy is :  97.46376811594203 %
#
# Training loss after  3000  iterations is :  0.25885132660660565  | validation loss is :  0.25219302009897737
# Training accuracy after  3000  iterations is :  96.35036496350365 %  | validation accuracy is :  97.82608695652173 %
#
# Training loss after  3500  iterations is :  0.23786238209155292  | validation loss is :  0.2303524019192936
# Training accuracy after  3500  iterations is :  96.66319082377477 %  | validation accuracy is :  98.18840579710145 %
#
# Training loss after  4000  iterations is :  0.22052031297009564  | validation loss is :  0.21235218092306238
# Training accuracy after  4000  iterations is :  96.97601668404589 %  | validation accuracy is :  98.18840579710145 %
#
# Training loss after  4500  iterations is :  0.20596222489932803  | validation loss is :  0.19727724610554473
# Training accuracy after  4500  iterations is :  97.08029197080292 %  | validation accuracy is :  98.55072463768117 %
#
# Training loss after  5000  iterations is :  0.19357397677681965  | validation loss is :  0.18447697453758422
# Training accuracy after  5000  iterations is :  97.49739311783108 %  | validation accuracy is :  98.55072463768117 %
#
# Training loss after  5500  iterations is :  0.18290751320881707  | validation loss is :  0.17347757551926477
# Training accuracy after  5500  iterations is :  97.49739311783108 %  | validation accuracy is :  98.55072463768117 %
#
# Training loss after  6000  iterations is :  0.1736288184981867  | validation loss is :  0.16392659544517055
# Training accuracy after  6000  iterations is :  97.49739311783108 %  | validation accuracy is :  98.55072463768117 %
#
# Training loss after  6500  iterations is :  0.1654841368804213  | validation loss is :  0.15555684333241013
# Training accuracy after  6500  iterations is :  97.70594369134515 %  | validation accuracy is :  98.55072463768117 %
#
# Training loss after  7000  iterations is :  0.1582774427966713  | validation loss is :  0.14816233977264195
# Training accuracy after  7000  iterations is :  97.70594369134515 %  | validation accuracy is :  98.55072463768117 %
#
# Training loss after  7500  iterations is :  0.15185504523089532  | validation loss is :  0.1415819030401925
# Training accuracy after  7500  iterations is :  97.70594369134515 %  | validation accuracy is :  98.55072463768117 %
#
# Training loss after  8000  iterations is :  0.14609483684779248  | validation loss is :  0.13568770679069056
# Training accuracy after  8000  iterations is :  97.91449426485923 %  | validation accuracy is :  98.91304347826086 %
#
# Training loss after  8500  iterations is :  0.14089863975913552  | validation loss is :  0.13037714869906028
# Training accuracy after  8500  iterations is :  97.91449426485923 %  | validation accuracy is :  98.91304347826086 %
#
# Training loss after  9000  iterations is :  0.13618666024928963  | validation loss is :  0.12556697058250174
# Training accuracy after  9000  iterations is :  97.91449426485923 %  | validation accuracy is :  98.91304347826086 %
#
# Training loss after  9500  iterations is :  0.1318934076880721  | validation loss is :  0.12118893897835614
# Training accuracy after  9500  iterations is :  97.91449426485923 %  | validation accuracy is :  98.91304347826086 %
# [[-3.31956882]
#  [-1.91546634]
#  [-1.95634493]
#  [-0.37432445]]
# -0.018683898492827623

# %%
import numpy as np
import pandas as pd
from scratch import *
import random
# Out:
# Linear Regression
# Training loss after  0  iterations is  1.5811388300841898
# Training loss after  500  iterations is  0.11515089871796896
# Training loss after  1000  iterations is  0.11515089872154656
# Training loss after  1500  iterations is  0.11515089872154524
# Training loss after  2000  iterations is  0.11515089872154423
# Training loss after  2500  iterations is  0.11515089872154423
# Training loss after  3000  iterations is  0.11515089872154423
# Training loss after  3500  iterations is  0.11515089872154423
# Training loss after  4000  iterations is  0.11515089872154423
# Training loss after  4500  iterations is  0.11515089872154423
# Predicted Values: [[2.76462962]
#  [2.76462962]]
# True Values: [3]

# %%
preprocess = MyPreProcessor()
X,Y=preprocess.pre_process(2)
print(X)
print(Y)
# Out:
# [[-0.29911252 -0.01940752 -0.24347183 -0.30950245]
#  [ 0.98585385  1.50520806 -0.6255817  -0.23496538]
#  [ 0.80692407 -1.19354086  0.97401692  0.11777277]
#  ...
#  [-0.61580852 -0.10285432  0.14393737 -0.23987331]
#  [-0.4566623   0.62410398 -0.57111759 -0.92544269]
#  [-0.71354029 -0.25551277  0.249426   -0.25398274]]
# [[1.]
#  [0.]
#  [0.]
#  ...
#  [1.]
#  [1.]
#  [1.]]

# %%
ratio = X.shape[0]//10
X_train = X[0:7*ratio, :]
y_train = Y[0:7*ratio, :]
X_val = X[7*ratio : 8*ratio, :]
y_val = Y[7*ratio : 8*ratio, :]
X_test = X[8*ratio:, :]
y_test = Y[8*ratio:,:]
print(X_train.shape,y_train.shape )
print(X_test.shape,y_test.shape )
print(X_val.shape, y_val.shape)
# Out:
# (959, 4) (959, 1)
# (276, 4) (276, 1)
# (137, 4) (137, 1)

# %%
pp = MyPreProcessor()
W = pp.get_analytical_sol()
print(W)
X,y = pp.pre_process(0)
bias = np.zeros((X.shape[0],1))
bias.fill(1)
X = np.append(X,bias, axis = 1)
y_pred = np.dot(X,W)
error = (np.sum((y-y_pred)**2)/y_pred.shape[0])**0.5
mae = np.sum(abs(y-y_pred))/y_pred.shape[0]
print(error)
print(mae)
# Out:
# [[ 2.13626242  0.00849443 -0.19450817 ... -0.55916099 -0.53284584
#    1.        ]
#  [ 3.63998538 -0.09676618 -0.28473155 ... -0.70051095 -0.53510142
#    1.        ]
#  [ 3.63998538 -0.11180341 -0.28473155 ... -0.65765484 -0.61254316
#    1.        ]
#  ...
#  [ 0.63253946  0.0460875  -0.1569151  ... -0.52833467 -0.4711932
#    1.        ]
#  [ 2.13626242 -0.14939648 -0.31480601 ... -0.6448732  -0.63133969
#    1.        ]
#  [ 0.63253946  0.06864335 -0.1569151  ... -0.51705675 -0.40427753
#    1.        ]]
# [[ -0.25628631]
#  [ -0.51655077]
#  [  7.900679  ]
#  [  7.50021818]
#  [  6.02815842]
#  [-13.36837538]
#  [ -6.73825106]
#  [  5.79235855]
#  [  9.66007587]]
# 2.1959658591369107
# 1.583133232202937

# %%
"""Running SGD on Banknote dataset and with LR = 0.0001, 0.01, 10"""
L = [0.0001,0.01,10]

# %%
for i in range(3):
    print("\n For learning rate ", L[i], "------------------------------------------------------------ ")
    log_regressor_sgd = MyLogisticRegression()
    log_regressor_sgd.fit(X_train, y_train, X_val, y_val, epochs = 10000 ,learning_rate = L[i], grad_type = "sgd")
    print(log_regressor_sgd.W)
    print(log_regressor_sgd.b)
    loss_history_sgd = log_regressor_sgd.loss_history
    val_loss_history_sgd = log_regressor_sgd.val_loss_history
    train_acc_history_sgd = log_regressor_sgd.train_acc_history
    val_acc_history_sgd = log_regressor_sgd.val_acc_history
    plt.plot([x for x in range(len(loss_history_sgd))], loss_history_sgd, label = "Training  loss " )
    plt.plot([x for x in range(len(val_loss_history_sgd))], val_loss_history_sgd, label = "Validation  loss")
    plt.xlabel('iterations')
    plt.ylabel('loss')
    plt.legend()
    plt.show()
    plt.plot([x for x in range(len(train_acc_history_sgd))], train_acc_history_sgd, label = "Training  accuracy " )
    plt.plot([x for x in range(len(val_acc_history_sgd))], val_acc_history_sgd, label = "Validation  accuracy")
    plt.xlabel('iterations')
    plt.ylabel('accuracy')
    plt.legend()
    plt.show()
    
    print("\n -------------------------------------------------------------------------------------------")
# Out:
#  For learning rate  0.0001 ------------------------------------------------------------
#
# Training loss after  0  sgd steps is :  0.6931469805599655  | validation loss is :  0.6931469805599654
# Training accuracy after  0  sgd steps is :  45.04692387904067 %  | validation accuracy is :  38.68613138686131 %
#
# Training loss after  500  sgd steps is :  0.683988064172614  | validation loss is :  0.6832099873873957
# Training accuracy after  500  sgd steps is :  67.15328467153286 %  | validation accuracy is :  70.07299270072993 %
#
# Training loss after  1000  sgd steps is :  0.6762534626999323  | validation loss is :  0.6748656722567583
# Training accuracy after  1000  sgd steps is :  68.30031282586026 %  | validation accuracy is :  71.53284671532847 %
#
# Training loss after  1500  sgd steps is :  0.6682388527261482  | validation loss is :  0.6662278016549729
# Training accuracy after  1500  sgd steps is :  68.82168925964547 %  | validation accuracy is :  71.53284671532847 %
#
# Training loss after  2000  sgd steps is :  0.6605793987551172  | validation loss is :  0.6579945529147616
# Training accuracy after  2000  sgd steps is :  68.71741397288842 %  | validation accuracy is :  71.53284671532847 %
#
# Training loss after  2500  sgd steps is :  0.6540883501594744  | validation loss is :  0.6511176089768074
# Training accuracy after  2500  sgd steps is :  69.13451511991657 %  | validation accuracy is :  71.53284671532847 %
#
# Training loss after  3000  sgd steps is :  0.648128104644995  | validation loss is :  0.644660383097484
# Training accuracy after  3000  sgd steps is :  69.65589155370178 %  | validation accuracy is :  72.26277372262774 %
#
# Training loss after  3500  sgd steps is :  0.6416265230462617  | validation loss is :  0.6375687953558458
# Training accuracy after  3500  sgd steps is :  69.65589155370178 %  | validation accuracy is :  72.26277372262774 %
#
# Training loss after  4000  sgd steps is :  0.6357764457533759  | validation loss is :  0.6312574877532908
# Training accuracy after  4000  sgd steps is :  69.96871741397288 %  | validation accuracy is :  72.99270072992701 %
#
# Training loss after  4500  sgd steps is :  0.6295196613152738  | validation loss is :  0.624606851496367
# Training accuracy after  4500  sgd steps is :  69.86444212721585 %  | validation accuracy is :  72.26277372262774 %
#
# Training loss after  5000  sgd steps is :  0.6235688861554469  | validation loss is :  0.6183279137637874
# Training accuracy after  5000  sgd steps is :  69.65589155370178 %  | validation accuracy is :  72.26277372262774 %
#
# Training loss after  5500  sgd steps is :  0.6182816425541958  | validation loss is :  0.6127272365574356
# Training accuracy after  5500  sgd steps is :  69.76016684045881 %  | validation accuracy is :  72.26277372262774 %
#
# Training loss after  6000  sgd steps is :  0.6136164229713945  | validation loss is :  0.6076334493339696
# Training accuracy after  6000  sgd steps is :  70.07299270072993 %  | validation accuracy is :  72.99270072992701 %
#
# Training loss after  6500  sgd steps is :  0.6088775498937606  | validation loss is :  0.6025641215109759
# Training accuracy after  6500  sgd steps is :  70.281543274244 %  | validation accuracy is :  72.99270072992701 %
#
# Training loss after  7000  sgd steps is :  0.6041331090127623  | validation loss is :  0.5974690546934905
# Training accuracy after  7000  sgd steps is :  70.38581856100103 %  | validation accuracy is :  72.99270072992701 %
#
# Training loss after  7500  sgd steps is :  0.5992790877935269  | validation loss is :  0.5922994286367098
# Training accuracy after  7500  sgd steps is :  70.38581856100103 %  | validation accuracy is :  73.72262773722628 %
#
# Training loss after  8000  sgd steps is :  0.5947548111169582  | validation loss is :  0.5875468501019522
# Training accuracy after  8000  sgd steps is :  70.69864442127216 %  | validation accuracy is :  73.72262773722628 %
#
# Training loss after  8500  sgd steps is :  0.590342168289516  | validation loss is :  0.5828683194462863
# Training accuracy after  8500  sgd steps is :  70.69864442127216 %  | validation accuracy is :  74.45255474452554 %
#
# Training loss after  9000  sgd steps is :  0.5865614519134364  | validation loss is :  0.5787990588117138
# Training accuracy after  9000  sgd steps is :  71.01147028154328 %  | validation accuracy is :  75.91240875912408 %
#
# Training loss after  9500  sgd steps is :  0.5830027128509775  | validation loss is :  0.5750173354176717
# Training accuracy after  9500  sgd steps is :  71.32429614181439 %  | validation accuracy is :  76.64233576642336 %
# [[-0.21955218]
#  [-0.249516  ]
#  [ 0.03147262]
#  [ 0.00356837]]
# [[-0.0425763]]
#  -------------------------------------------------------------------------------------------
#
#  For learning rate  0.01 ------------------------------------------------------------
#
# Training loss after  0  sgd steps is :  0.6931469805599655  | validation loss is :  0.6931469805599654
# Training accuracy after  0  sgd steps is :  45.04692387904067 %  | validation accuracy is :  38.68613138686131 %
#
# Training loss after  500  sgd steps is :  0.41301334266583606  | validation loss is :  0.40226907151527047
# Training accuracy after  500  sgd steps is :  91.03232533889468 %  | validation accuracy is :  89.05109489051095 %
#
# Training loss after  1000  sgd steps is :  0.31342584061591117  | validation loss is :  0.2978984217340159
# Training accuracy after  1000  sgd steps is :  95.30761209593325 %  | validation accuracy is :  96.35036496350365 %
#
# Training loss after  1500  sgd steps is :  0.2589538370916775  | validation loss is :  0.24474028029651515
# Training accuracy after  1500  sgd steps is :  95.62043795620438 %  | validation accuracy is :  95.62043795620438 %
#
# Training loss after  2000  sgd steps is :  0.22260766990390962  | validation loss is :  0.20664987667808693
# Training accuracy after  2000  sgd steps is :  96.55891553701773 %  | validation accuracy is :  97.08029197080292 %
#
# Training loss after  2500  sgd steps is :  0.19662022674617674  | validation loss is :  0.1824295145848732
# Training accuracy after  2500  sgd steps is :  96.76746611053181 %  | validation accuracy is :  97.08029197080292 %
#
# Training loss after  3000  sgd steps is :  0.17684467946704777  | validation loss is :  0.16053228788857413
# Training accuracy after  3000  sgd steps is :  96.87174139728884 %  | validation accuracy is :  98.54014598540147 %
#
# Training loss after  3500  sgd steps is :  0.1607350273153408  | validation loss is :  0.14498259434609098
# Training accuracy after  3500  sgd steps is :  97.39311783107404 %  | validation accuracy is :  98.54014598540147 %
#
# Training loss after  4000  sgd steps is :  0.1483559971378876  | validation loss is :  0.13319481992956275
# Training accuracy after  4000  sgd steps is :  97.91449426485923 %  | validation accuracy is :  98.54014598540147 %
#
# Training loss after  4500  sgd steps is :  0.13841821930173348  | validation loss is :  0.12472347133150745
# Training accuracy after  4500  sgd steps is :  97.91449426485923 %  | validation accuracy is :  98.54014598540147 %
#
# Training loss after  5000  sgd steps is :  0.13001150067089884  | validation loss is :  0.11660681100619097
# Training accuracy after  5000  sgd steps is :  98.01876955161627 %  | validation accuracy is :  98.54014598540147 %
#
# Training loss after  5500  sgd steps is :  0.12282311315048564  | validation loss is :  0.10952068416642446
# Training accuracy after  5500  sgd steps is :  98.01876955161627 %  | validation accuracy is :  98.54014598540147 %
#
# Training loss after  6000  sgd steps is :  0.11697259702814096  | validation loss is :  0.10361762243530409
# Training accuracy after  6000  sgd steps is :  98.01876955161627 %  | validation accuracy is :  98.54014598540147 %
#
# Training loss after  6500  sgd steps is :  0.11189603229495285  | validation loss is :  0.09980068079966853
# Training accuracy after  6500  sgd steps is :  98.22732012513035 %  | validation accuracy is :  98.54014598540147 %
#
# Training loss after  7000  sgd steps is :  0.1072863733951785  | validation loss is :  0.09543476149122275
# Training accuracy after  7000  sgd steps is :  98.22732012513035 %  | validation accuracy is :  98.54014598540147 %
#
# Training loss after  7500  sgd steps is :  0.10346543871751449  | validation loss is :  0.09059903963335666
# Training accuracy after  7500  sgd steps is :  98.1230448383733 %  | validation accuracy is :  98.54014598540147 %
#
# Training loss after  8000  sgd steps is :  0.09971674419521571  | validation loss is :  0.0867398513849635
# Training accuracy after  8000  sgd steps is :  98.43587069864442 %  | validation accuracy is :  98.54014598540147 %
#
# Training loss after  8500  sgd steps is :  0.09658494466035591  | validation loss is :  0.08404572148130211
# Training accuracy after  8500  sgd steps is :  98.22732012513035 %  | validation accuracy is :  98.54014598540147 %
#
# Training loss after  9000  sgd steps is :  0.09378099870088276  | validation loss is :  0.08118076068432839
# Training accuracy after  9000  sgd steps is :  98.22732012513035 %  | validation accuracy is :  98.54014598540147 %
#
# Training loss after  9500  sgd steps is :  0.09105537066525887  | validation loss is :  0.07881886242704544
# Training accuracy after  9500  sgd steps is :  98.22732012513035 %  | validation accuracy is :  98.54014598540147 %
# [[-4.35119802]
#  [-2.45981648]
#  [-2.73273977]
#  [-0.2708569 ]]
# [[0.10958122]]
#  -------------------------------------------------------------------------------------------
#
#  For learning rate  10 ------------------------------------------------------------
#
# Training loss after  0  sgd steps is :  0.6931469805599655  | validation loss is :  0.6931469805599654
# Training accuracy after  0  sgd steps is :  45.04692387904067 %  | validation accuracy is :  38.68613138686131 %
#
# Training loss after  500  sgd steps is :  0.2802082759396471  | validation loss is :  0.23379002896776263
# Training accuracy after  500  sgd steps is :  97.288842544317 %  | validation accuracy is :  97.08029197080292 %
#
# Training loss after  1000  sgd steps is :  0.5644506068591805  | validation loss is :  0.7955195857640681
# Training accuracy after  1000  sgd steps is :  94.99478623566215 %  | validation accuracy is :  91.97080291970804 %
#
# Training loss after  1500  sgd steps is :  0.21580775109035955  | validation loss is :  0.11744270500828342
# Training accuracy after  1500  sgd steps is :  98.33159541188738 %  | validation accuracy is :  99.27007299270073 %
#
# Training loss after  2000  sgd steps is :  0.31544371935859394  | validation loss is :  0.11769520056381294
# Training accuracy after  2000  sgd steps is :  97.60166840458811 %  | validation accuracy is :  99.27007299270073 %
#
# Training loss after  2500  sgd steps is :  0.18718031769533416  | validation loss is :  0.11411040049004467
# Training accuracy after  2500  sgd steps is :  98.33159541188738 %  | validation accuracy is :  98.54014598540147 %
#
# Training loss after  3000  sgd steps is :  0.21520287886013015  | validation loss is :  0.11763460152800162
# Training accuracy after  3000  sgd steps is :  98.33159541188738 %  | validation accuracy is :  99.27007299270073 %
#
# Training loss after  3500  sgd steps is :  0.27795881407296025  | validation loss is :  0.11765424824538764
# Training accuracy after  3500  sgd steps is :  97.70594369134515 %  | validation accuracy is :  99.27007299270073 %
#
# Training loss after  4000  sgd steps is :  0.1608690504891545  | validation loss is :  0.19884277547537219
# Training accuracy after  4000  sgd steps is :  98.1230448383733 %  | validation accuracy is :  97.8102189781022 %
#
# Training loss after  4500  sgd steps is :  0.08047160151825893  | validation loss is :  0.10353291675281583
# Training accuracy after  4500  sgd steps is :  98.6444212721585 %  | validation accuracy is :  99.27007299270073 %
#
# Training loss after  5000  sgd steps is :  0.2852412583567458  | validation loss is :  0.11765038835946368
# Training accuracy after  5000  sgd steps is :  97.8102189781022 %  | validation accuracy is :  99.27007299270073 %
#
# Training loss after  5500  sgd steps is :  0.10681656379067049  | validation loss is :  0.11765399807608264
# Training accuracy after  5500  sgd steps is :  98.6444212721585 %  | validation accuracy is :  99.27007299270073 %
#
# Training loss after  6000  sgd steps is :  0.11141544766199304  | validation loss is :  0.11749858473416044
# Training accuracy after  6000  sgd steps is :  98.54014598540147 %  | validation accuracy is :  99.27007299270073 %
#
# Training loss after  6500  sgd steps is :  0.11207136810624178  | validation loss is :  0.11760946242177536
# Training accuracy after  6500  sgd steps is :  98.54014598540147 %  | validation accuracy is :  99.27007299270073 %
#
# Training loss after  7000  sgd steps is :  0.1719458503876586  | validation loss is :  0.11223195051517729
# Training accuracy after  7000  sgd steps is :  98.22732012513035 %  | validation accuracy is :  99.27007299270073 %
#
# Training loss after  7500  sgd steps is :  0.2848705608088339  | validation loss is :  0.32875847418403537
# Training accuracy after  7500  sgd steps is :  97.8102189781022 %  | validation accuracy is :  97.08029197080292 %
#
# Training loss after  8000  sgd steps is :  0.06201627032221853  | validation loss is :  0.11757356303339331
# Training accuracy after  8000  sgd steps is :  98.95724713242961 %  | validation accuracy is :  99.27007299270073 %
#
# Training loss after  8500  sgd steps is :  0.10068131278001882  | validation loss is :  0.11764517004024297
# Training accuracy after  8500  sgd steps is :  98.22732012513035 %  | validation accuracy is :  99.27007299270073 %
#
# Training loss after  9000  sgd steps is :  0.3232223107334902  | validation loss is :  0.15103317214987172
# Training accuracy after  9000  sgd steps is :  97.288842544317 %  | validation accuracy is :  98.54014598540147 %
#
# Training loss after  9500  sgd steps is :  0.10794645373601822  | validation loss is :  0.09608132493328068
# Training accuracy after  9500  sgd steps is :  98.43587069864442 %  | validation accuracy is :  99.27007299270073 %
# [[-204.48538786]
#  [ -91.58910726]
#  [-130.75499858]
#  [   3.86839285]]
# [[-23.34756475]]
#  -------------------------------------------------------------------------------------------

# %%
"""Running BGD on Banknote dataset and with LR = 0.0001, 0.01, 10"""
L = [0.0001,0.01,10]

# %%
for i in range(3):
    print("\n For learning rate ", L[i], "------------------------------------------------------------ ")
    log_regressor_bgd = MyLogisticRegression()
    log_regressor_bgd.fit(X_train, y_train, X_val, y_val, epochs = 10000 ,learning_rate = L[i], grad_type = "bgd")
    print(log_regressor_bgd.W)
    print(log_regressor_bgd.b)
    loss_history_bgd = log_regressor_bgd.loss_history
    val_loss_history_bgd = log_regressor_bgd.val_loss_history
    train_acc_history_bgd = log_regressor_bgd.train_acc_history
    val_acc_history_bgd = log_regressor_bgd.val_acc_history
    plt.plot([x for x in range(10000)], loss_history_bgd, label = "Training  accuracy " )
    plt.plot([x for x in range(10000)], val_loss_history_bgd, label = "Validation  accuracy")
    plt.xlabel('epochs')
    plt.ylabel('loss')
    plt.legend()
    plt.show()
    plt.plot([x for x in range(10000)], train_acc_history_bgd, label = "Training  accuracy " )
    plt.plot([x for x in range(10000)], val_acc_history_bgd, label = "Validation  accuracy")
    plt.xlabel('epochs')
    plt.ylabel('loss')
    plt.legend()
    plt.show()
    print("\n -------------------------------------------------------------------------------------------")
# Out:
#  For learning rate  0.0001 ------------------------------------------------------------
#
# Training loss after  0  iterations is :  0.6931469805599655  | validation loss is :  0.6931469805599654
# Training accuracy after  0  iterations is :  45.04692387904067 %  | validation accuracy is :  38.68613138686131 %
#
# Training loss after  500  iterations is :  0.6846722097947422  | validation loss is :  0.6840016968229867
# Training accuracy after  500  iterations is :  68.82168925964547 %  | validation accuracy is :  71.53284671532847 %
#
# Training loss after  1000  iterations is :  0.676630168067112  | validation loss is :  0.6753319540196963
# Training accuracy after  1000  iterations is :  69.03023983315954 %  | validation accuracy is :  71.53284671532847 %
#
# Training loss after  1500  iterations is :  0.6689910871728904  | validation loss is :  0.6671050401891278
# Training accuracy after  1500  iterations is :  69.23879040667362 %  | validation accuracy is :  71.53284671532847 %
#
# Training loss after  2000  iterations is :  0.6617270242963703  | validation loss is :  0.6592902334517617
# Training accuracy after  2000  iterations is :  69.34306569343065 %  | validation accuracy is :  71.53284671532847 %
#
# Training loss after  2500  iterations is :  0.6548118306452143  | validation loss is :  0.6518587727601561
# Training accuracy after  2500  iterations is :  69.4473409801877 %  | validation accuracy is :  71.53284671532847 %
#
# Training loss after  3000  iterations is :  0.6482211009719822  | validation loss is :  0.6447838064102761
# Training accuracy after  3000  iterations is :  69.4473409801877 %  | validation accuracy is :  71.53284671532847 %
#
# Training loss after  3500  iterations is :  0.6419321087571653  | validation loss is :  0.6380403237845524
# Training accuracy after  3500  iterations is :  69.65589155370178 %  | validation accuracy is :  72.26277372262774 %
#
# Training loss after  4000  iterations is :  0.635923731178443  | validation loss is :  0.6316050750584046
# Training accuracy after  4000  iterations is :  69.76016684045881 %  | validation accuracy is :  72.26277372262774 %
#
# Training loss after  4500  iterations is :  0.6301763673434901  | validation loss is :  0.6254564828634306
# Training accuracy after  4500  iterations is :  69.86444212721585 %  | validation accuracy is :  72.26277372262774 %
#
# Training loss after  5000  iterations is :  0.6246718526509536  | validation loss is :  0.6195745492001374
# Training accuracy after  5000  iterations is :  70.17726798748696 %  | validation accuracy is :  72.99270072992701 %
#
# Training loss after  5500  iterations is :  0.619393371585895  | validation loss is :  0.613940760254251
# Training accuracy after  5500  iterations is :  70.281543274244 %  | validation accuracy is :  72.99270072992701 %
#
# Training loss after  6000  iterations is :  0.6143253707623784  | validation loss is :  0.6085379912054484
# Training accuracy after  6000  iterations is :  70.49009384775809 %  | validation accuracy is :  73.72262773722628 %
#
# Training loss after  6500  iterations is :  0.60945347360025  | validation loss is :  0.6033504126298412
# Training accuracy after  6500  iterations is :  70.59436913451512 %  | validation accuracy is :  73.72262773722628 %
#
# Training loss after  7000  iterations is :  0.6047643976640386  | validation loss is :  0.598363399686111
# Training accuracy after  7000  iterations is :  70.69864442127216 %  | validation accuracy is :  74.45255474452554 %
#
# Training loss after  7500  iterations is :  0.6002458753947428  | validation loss is :  0.5935634449347194
# Training accuracy after  7500  iterations is :  70.8029197080292 %  | validation accuracy is :  74.45255474452554 %
#
# Training loss after  8000  iterations is :  0.5958865787238571  | validation loss is :  0.5889380753629688
# Training accuracy after  8000  iterations is :  71.01147028154328 %  | validation accuracy is :  75.18248175182481 %
#
# Training loss after  8500  iterations is :  0.591676047866319  | validation loss is :  0.5844757739678722
# Training accuracy after  8500  iterations is :  71.11574556830031 %  | validation accuracy is :  75.91240875912408 %
#
# Training loss after  9000  iterations is :  0.5876046244381208  | validation loss is :  0.5801659060757538
# Training accuracy after  9000  iterations is :  71.22002085505736 %  | validation accuracy is :  76.64233576642336 %
#
# Training loss after  9500  iterations is :  0.5836633889284062  | validation loss is :  0.5759986504445361
# Training accuracy after  9500  iterations is :  71.6371220020855 %  | validation accuracy is :  77.37226277372262 %
# [[-0.21925326]
#  [-0.24602219]
#  [ 0.02838119]
#  [ 0.00192891]]
# -0.03681746356243362
#  -------------------------------------------------------------------------------------------
#
#  For learning rate  0.01 ------------------------------------------------------------
#
# Training loss after  0  iterations is :  0.6931469805599655  | validation loss is :  0.6931469805599654
# Training accuracy after  0  iterations is :  45.04692387904067 %  | validation accuracy is :  38.68613138686131 %
#
# Training loss after  500  iterations is :  0.4159555881543855  | validation loss is :  0.40265325386554435
# Training accuracy after  500  iterations is :  88.52971845672576 %  | validation accuracy is :  86.86131386861314 %
#
# Training loss after  1000  iterations is :  0.31760232347513523  | validation loss is :  0.3025048157314157
# Training accuracy after  1000  iterations is :  94.05630865484879 %  | validation accuracy is :  94.16058394160584 %
#
# Training loss after  1500  iterations is :  0.2597828458984282  | validation loss is :  0.24415730024842894
# Training accuracy after  1500  iterations is :  96.14181438998958 %  | validation accuracy is :  96.35036496350365 %
#
# Training loss after  2000  iterations is :  0.22187550205616582  | validation loss is :  0.20636197153850022
# Training accuracy after  2000  iterations is :  96.87174139728884 %  | validation accuracy is :  97.08029197080292 %
#
# Training loss after  2500  iterations is :  0.1951700111955153  | validation loss is :  0.18000551027309636
# Training accuracy after  2500  iterations is :  97.288842544317 %  | validation accuracy is :  98.54014598540147 %
#
# Training loss after  3000  iterations is :  0.17536291216312183  | validation loss is :  0.1606007173858709
# Training accuracy after  3000  iterations is :  97.39311783107404 %  | validation accuracy is :  98.54014598540147 %
#
# Training loss after  3500  iterations is :  0.16009214483978573  | validation loss is :  0.1457132177014468
# Training accuracy after  3500  iterations is :  97.60166840458811 %  | validation accuracy is :  98.54014598540147 %
#
# Training loss after  4000  iterations is :  0.14795728108184528  | validation loss is :  0.13391841618734793
# Training accuracy after  4000  iterations is :  97.91449426485923 %  | validation accuracy is :  98.54014598540147 %
#
# Training loss after  4500  iterations is :  0.13807748492467448  | validation loss is :  0.12433096993350785
# Training accuracy after  4500  iterations is :  97.91449426485923 %  | validation accuracy is :  98.54014598540147 %
#
# Training loss after  5000  iterations is :  0.12987211863406503  | validation loss is :  0.11637325571772021
# Training accuracy after  5000  iterations is :  98.22732012513035 %  | validation accuracy is :  98.54014598540147 %
#
# Training loss after  5500  iterations is :  0.12294349480733037  | validation loss is :  0.10965303304862645
# Training accuracy after  5500  iterations is :  98.01876955161627 %  | validation accuracy is :  98.54014598540147 %
#
# Training loss after  6000  iterations is :  0.11701040107221973  | validation loss is :  0.10389488571579392
# Training accuracy after  6000  iterations is :  98.01876955161627 %  | validation accuracy is :  98.54014598540147 %
#
# Training loss after  6500  iterations is :  0.11186853758461736  | validation loss is :  0.0988998620051829
# Training accuracy after  6500  iterations is :  98.1230448383733 %  | validation accuracy is :  98.54014598540147 %
#
# Training loss after  7000  iterations is :  0.10736599464455311  | validation loss is :  0.0945207029995693
# Training accuracy after  7000  iterations is :  98.1230448383733 %  | validation accuracy is :  98.54014598540147 %
#
# Training loss after  7500  iterations is :  0.10338751693557463  | validation loss is :  0.09064608474750929
# Training accuracy after  7500  iterations is :  98.1230448383733 %  | validation accuracy is :  98.54014598540147 %
#
# Training loss after  8000  iterations is :  0.0998440992862106  | validation loss is :  0.08719027884600902
# Training accuracy after  8000  iterations is :  98.22732012513035 %  | validation accuracy is :  98.54014598540147 %
#
# Training loss after  8500  iterations is :  0.09666592533639085  | validation loss is :  0.08408618187954664
# Training accuracy after  8500  iterations is :  98.22732012513035 %  | validation accuracy is :  98.54014598540147 %
#
# Training loss after  9000  iterations is :  0.09379746326544146  | validation loss is :  0.08128050234439134
# Training accuracy after  9000  iterations is :  98.22732012513035 %  | validation accuracy is :  98.54014598540147 %
#
# Training loss after  9500  iterations is :  0.09119398914279395  | validation loss is :  0.07873036592325892
# Training accuracy after  9500  iterations is :  98.22732012513035 %  | validation accuracy is :  98.54014598540147 %
# [[-4.32738335]
#  [-2.46430225]
#  [-2.75009478]
#  [-0.21773359]]
# 0.09472497102526312
#  -------------------------------------------------------------------------------------------
#
#  For learning rate  10 ------------------------------------------------------------
#
# Training loss after  0  iterations is :  0.6931469805599655  | validation loss is :  0.6931469805599654
# Training accuracy after  0  iterations is :  45.04692387904067 %  | validation accuracy is :  38.68613138686131 %
#
# Training loss after  500  iterations is :  0.02756118869988163  | validation loss is :  0.01886025964663917
# Training accuracy after  500  iterations is :  98.85297184567257 %  | validation accuracy is :  99.27007299270073 %
#
# Training loss after  1000  iterations is :  0.024961453861280736  | validation loss is :  0.018056054205253823
# Training accuracy after  1000  iterations is :  98.74869655891554 %  | validation accuracy is :  99.27007299270073 %
#
# Training loss after  1500  iterations is :  0.023769470923946236  | validation loss is :  0.018043002755231533
# Training accuracy after  1500  iterations is :  98.74869655891554 %  | validation accuracy is :  99.27007299270073 %
#
# Training loss after  2000  iterations is :  0.023056904435479846  | validation loss is :  0.01819776095557825
# Training accuracy after  2000  iterations is :  98.74869655891554 %  | validation accuracy is :  99.27007299270073 %
#
# Training loss after  2500  iterations is :  0.02257680631761796  | validation loss is :  0.01839823583948335
# Training accuracy after  2500  iterations is :  98.6444212721585 %  | validation accuracy is :  99.27007299270073 %
#
# Training loss after  3000  iterations is :  0.022230198149549747  | validation loss is :  0.01860813134092609
# Training accuracy after  3000  iterations is :  98.54014598540147 %  | validation accuracy is :  99.27007299270073 %
#
# Training loss after  3500  iterations is :  0.02196839194596263  | validation loss is :  0.018814487002032386
# Training accuracy after  3500  iterations is :  98.54014598540147 %  | validation accuracy is :  99.27007299270073 %
#
# Training loss after  4000  iterations is :  0.02176421854320825  | validation loss is :  0.019012373739718445
# Training accuracy after  4000  iterations is :  98.54014598540147 %  | validation accuracy is :  99.27007299270073 %
#
# Training loss after  4500  iterations is :  0.021601152377495332  | validation loss is :  0.01920003863946886
# Training accuracy after  4500  iterations is :  98.54014598540147 %  | validation accuracy is :  99.27007299270073 %
#
# Training loss after  5000  iterations is :  0.021468490460173097  | validation loss is :  0.0193770918992655
# Training accuracy after  5000  iterations is :  98.54014598540147 %  | validation accuracy is :  99.27007299270073 %
#
# Training loss after  5500  iterations is :  0.021358961303008198  | validation loss is :  0.01954375050499622
# Training accuracy after  5500  iterations is :  98.54014598540147 %  | validation accuracy is :  99.27007299270073 %
#
# Training loss after  6000  iterations is :  0.021267435249057748  | validation loss is :  0.01970049760761046
# Training accuracy after  6000  iterations is :  98.54014598540147 %  | validation accuracy is :  99.27007299270073 %
#
# Training loss after  6500  iterations is :  0.021190181941360037  | validation loss is :  0.01984792113037147
# Training accuracy after  6500  iterations is :  98.54014598540147 %  | validation accuracy is :  99.27007299270073 %
#
# Training loss after  7000  iterations is :  0.021124419836983606  | validation loss is :  0.01998663515570503
# Training accuracy after  7000  iterations is :  98.54014598540147 %  | validation accuracy is :  99.27007299270073 %
#
# Training loss after  7500  iterations is :  0.021068030912323246  | validation loss is :  0.0201172415591449
# Training accuracy after  7500  iterations is :  98.54014598540147 %  | validation accuracy is :  99.27007299270073 %
#
# Training loss after  8000  iterations is :  0.021019373386096222  | validation loss is :  0.020240311942768527
# Training accuracy after  8000  iterations is :  99.06152241918666 %  | validation accuracy is :  99.27007299270073 %
#
# Training loss after  8500  iterations is :  0.02097715498703789  | validation loss is :  0.0203563800449012
# Training accuracy after  8500  iterations is :  99.06152241918666 %  | validation accuracy is :  99.27007299270073 %
#
# Training loss after  9000  iterations is :  0.02094034492255275  | validation loss is :  0.02046593960018023
# Training accuracy after  9000  iterations is :  99.06152241918666 %  | validation accuracy is :  99.27007299270073 %
#
# Training loss after  9500  iterations is :  0.02090811132721569  | validation loss is :  0.020569445003227653
# Training accuracy after  9500  iterations is :  99.06152241918666 %  | validation accuracy is :  99.27007299270073 %
# [[-28.35673936]
#  [-14.99561312]
#  [-18.8477103 ]
#  [ -1.7048779 ]]
# -3.351112968791918
#  -------------------------------------------------------------------------------------------

# %%
"Custom learning rate chosen by hit and trial"
# Out:
# 'Custom learning rate chosen by hit and trial'

# %%
""" SGD on 0.005 learning rate"""
log_regressor_sgd = MyLogisticRegression()
log_regressor_sgd.fit(X_train, y_train, X_val, y_val, epochs = 10000 ,learning_rate = 0.005, grad_type = "sgd")
print(log_regressor_sgd.W)
print(log_regressor_sgd.b)
loss_history_sgd = log_regressor_sgd.loss_history
val_loss_history_sgd = log_regressor_sgd.val_loss_history
train_acc_history_sgd = log_regressor_sgd.train_acc_history
val_acc_history_sgd = log_regressor_sgd.val_acc_history
plt.plot([x for x in range(len(loss_history_sgd))], loss_history_sgd, label = "Training  loss " )
plt.plot([x for x in range(len(val_loss_history_sgd))], val_loss_history_sgd, label = "Validation  loss")
plt.xlabel('epochs')
plt.ylabel('loss')
plt.legend()
plt.show()
plt.plot([x for x in range(len(train_acc_history_sgd))], train_acc_history_sgd, label = "Training  accuracy " )
plt.plot([x for x in range(len(val_acc_history_sgd))], val_acc_history_sgd, label = "Validation  accuracy")
plt.xlabel('epochs')
plt.ylabel('accuracy')
plt.legend()
plt.show()
# Out:
# Training loss after  0  sgd steps is :  0.6931469805599655  | validation loss is :  0.6931469805599654
# Training accuracy after  0  sgd steps is :  45.04692387904067 %  | validation accuracy is :  38.68613138686131 %
#
# Training loss after  500  sgd steps is :  0.498209095282329  | validation loss is :  0.4868887872788629
# Training accuracy after  500  sgd steps is :  82.1689259645464 %  | validation accuracy is :  86.13138686131387 %
#
# Training loss after  1000  sgd steps is :  0.4150166584444571  | validation loss is :  0.40181952282432265
# Training accuracy after  1000  sgd steps is :  89.4681960375391 %  | validation accuracy is :  87.59124087591242 %
#
# Training loss after  1500  sgd steps is :  0.357246780981293  | validation loss is :  0.3418592227350585
# Training accuracy after  1500  sgd steps is :  92.59645464025026 %  | validation accuracy is :  91.97080291970804 %
#
# Training loss after  2000  sgd steps is :  0.31607445202241846  | validation loss is :  0.30025831000480785
# Training accuracy after  2000  sgd steps is :  94.57768508863398 %  | validation accuracy is :  94.8905109489051 %
#
# Training loss after  2500  sgd steps is :  0.284733407252241  | validation loss is :  0.2697382947984298
# Training accuracy after  2500  sgd steps is :  95.72471324296141 %  | validation accuracy is :  95.62043795620438 %
#
# Training loss after  3000  sgd steps is :  0.26009504950213275  | validation loss is :  0.24360041208811356
# Training accuracy after  3000  sgd steps is :  96.14181438998958 %  | validation accuracy is :  96.35036496350365 %
#
# Training loss after  3500  sgd steps is :  0.23868611369050508  | validation loss is :  0.22283217454287138
# Training accuracy after  3500  sgd steps is :  96.76746611053181 %  | validation accuracy is :  96.35036496350365 %
#
# Training loss after  4000  sgd steps is :  0.22168507118906805  | validation loss is :  0.20551567158162648
# Training accuracy after  4000  sgd steps is :  96.87174139728884 %  | validation accuracy is :  97.8102189781022 %
#
# Training loss after  4500  sgd steps is :  0.20667279375380784  | validation loss is :  0.1919354576994914
# Training accuracy after  4500  sgd steps is :  97.288842544317 %  | validation accuracy is :  97.8102189781022 %
#
# Training loss after  5000  sgd steps is :  0.1943430596120547  | validation loss is :  0.17991025633610097
# Training accuracy after  5000  sgd steps is :  97.288842544317 %  | validation accuracy is :  97.8102189781022 %
#
# Training loss after  5500  sgd steps is :  0.18387096303489833  | validation loss is :  0.16990289799012762
# Training accuracy after  5500  sgd steps is :  97.288842544317 %  | validation accuracy is :  97.8102189781022 %
#
# Training loss after  6000  sgd steps is :  0.17474678110512012  | validation loss is :  0.16165343615667674
# Training accuracy after  6000  sgd steps is :  97.49739311783108 %  | validation accuracy is :  97.8102189781022 %
#
# Training loss after  6500  sgd steps is :  0.1666790771740999  | validation loss is :  0.15403333214944892
# Training accuracy after  6500  sgd steps is :  97.8102189781022 %  | validation accuracy is :  97.8102189781022 %
#
# Training loss after  7000  sgd steps is :  0.15939797224080673  | validation loss is :  0.1468303907210268
# Training accuracy after  7000  sgd steps is :  97.91449426485923 %  | validation accuracy is :  98.54014598540147 %
#
# Training loss after  7500  sgd steps is :  0.15290804264340552  | validation loss is :  0.13949664002747236
# Training accuracy after  7500  sgd steps is :  97.91449426485923 %  | validation accuracy is :  98.54014598540147 %
#
# Training loss after  8000  sgd steps is :  0.14731956289629217  | validation loss is :  0.1338941539634087
# Training accuracy after  8000  sgd steps is :  97.91449426485923 %  | validation accuracy is :  98.54014598540147 %
#
# Training loss after  8500  sgd steps is :  0.1422558783153851  | validation loss is :  0.128582407403153
# Training accuracy after  8500  sgd steps is :  98.22732012513035 %  | validation accuracy is :  98.54014598540147 %
#
# Training loss after  9000  sgd steps is :  0.13749124260386733  | validation loss is :  0.1244150136043481
# Training accuracy after  9000  sgd steps is :  98.43587069864442 %  | validation accuracy is :  98.54014598540147 %
#
# Training loss after  9500  sgd steps is :  0.13294538060189276  | validation loss is :  0.12038379825502407
# Training accuracy after  9500  sgd steps is :  98.01876955161627 %  | validation accuracy is :  98.54014598540147 %
# [[-3.29867782]
#  [-1.89212143]
#  [-2.02224223]
#  [-0.31723758]]
# [[0.03650149]]

# %%
log_regressor_bgd = MyLogisticRegression()
log_regressor_bgd.fit(X_train, y_train, X_val, y_val, epochs = 10000 ,learning_rate = 0.005, grad_type = "bgd")
print(log_regressor_bgd.W)
print(log_regressor_bgd.b)
loss_history_bgd = log_regressor_bgd.loss_history
val_loss_history_bgd = log_regressor_bgd.val_loss_history
train_acc_history_bgd = log_regressor_bgd.train_acc_history
val_acc_history_bgd = log_regressor_bgd.val_acc_history
plt.plot([x for x in range(10000)], loss_history_bgd, label = "Training  accuracy " )
plt.plot([x for x in range(10000)], val_loss_history_bgd, label = "Validation  accuracy")
plt.xlabel('epochs')
plt.ylabel('loss')
plt.legend()
plt.show()
plt.plot([x for x in range(10000)], train_acc_history_bgd, label = "Training  accuracy " )
plt.plot([x for x in range(10000)], val_acc_history_bgd, label = "Validation  accuracy")
plt.xlabel('epochs')
plt.ylabel('accuracy')
plt.legend()
plt.show()
# Out:
# Training loss after  0  iterations is :  0.6931469805599655  | validation loss is :  0.6931469805599654
# Training accuracy after  0  iterations is :  45.04692387904067 %  | validation accuracy is :  38.68613138686131 %
#
# Training loss after  500  iterations is :  0.4981719886975598  | validation loss is :  0.48683373318632184
# Training accuracy after  500  iterations is :  78.41501564129302 %  | validation accuracy is :  83.21167883211679 %
#
# Training loss after  1000  iterations is :  0.41598419141878284  | validation loss is :  0.4026821770939867
# Training accuracy after  1000  iterations is :  88.52971845672576 %  | validation accuracy is :  86.86131386861314 %
#
# Training loss after  1500  iterations is :  0.35949804945252745  | validation loss is :  0.3450986038400131
# Training accuracy after  1500  iterations is :  91.97080291970804 %  | validation accuracy is :  91.24087591240875 %
#
# Training loss after  2000  iterations is :  0.3176265877197924  | validation loss is :  0.3025300409998018
# Training accuracy after  2000  iterations is :  94.05630865484879 %  | validation accuracy is :  94.16058394160584 %
#
# Training loss after  2500  iterations is :  0.2853738954192926  | validation loss is :  0.2698970351094557
# Training accuracy after  2500  iterations is :  95.30761209593325 %  | validation accuracy is :  95.62043795620438 %
#
# Training loss after  3000  iterations is :  0.2598026912284114  | validation loss is :  0.24417806993667462
# Training accuracy after  3000  iterations is :  96.14181438998958 %  | validation accuracy is :  96.35036496350365 %
#
# Training loss after  3500  iterations is :  0.23905311540741395  | validation loss is :  0.22343607510063243
# Training accuracy after  3500  iterations is :  96.76746611053181 %  | validation accuracy is :  97.08029197080292 %
#
# Training loss after  4000  iterations is :  0.22189169971066747  | validation loss is :  0.20637879322396405
# Training accuracy after  4000  iterations is :  96.87174139728884 %  | validation accuracy is :  97.08029197080292 %
#
# Training loss after  4500  iterations is :  0.2074694152087495  | validation loss is :  0.19211643938172582
# Training accuracy after  4500  iterations is :  96.97601668404589 %  | validation accuracy is :  98.54014598540147 %
#
# Training loss after  5000  iterations is :  0.1951834053591373  | validation loss is :  0.18001926837176985
# Training accuracy after  5000  iterations is :  97.288842544317 %  | validation accuracy is :  98.54014598540147 %
#
# Training loss after  5500  iterations is :  0.18459420240202473  | validation loss is :  0.1696306209585587
# Training accuracy after  5500  iterations is :  97.288842544317 %  | validation accuracy is :  98.54014598540147 %
#
# Training loss after  6000  iterations is :  0.17537415782472152  | validation loss is :  0.16061214920572417
# Training accuracy after  6000  iterations is :  97.39311783107404 %  | validation accuracy is :  98.54014598540147 %
#
# Training loss after  6500  iterations is :  0.16727419469572904  | validation loss is :  0.15270832844281285
# Training accuracy after  6500  iterations is :  97.60166840458811 %  | validation accuracy is :  98.54014598540147 %
#
# Training loss after  7000  iterations is :  0.1601017230541288  | validation loss is :  0.14572286982852783
# Training accuracy after  7000  iterations is :  97.60166840458811 %  | validation accuracy is :  98.54014598540147 %
#
# Training loss after  7500  iterations is :  0.15370558341254248  | validation loss is :  0.1395026745141711
# Training accuracy after  7500  iterations is :  97.70594369134515 %  | validation accuracy is :  98.54014598540147 %
#
# Training loss after  8000  iterations is :  0.14796554458374225  | validation loss is :  0.13392668565409507
# Training accuracy after  8000  iterations is :  97.91449426485923 %  | validation accuracy is :  98.54014598540147 %
#
# Training loss after  8500  iterations is :  0.14278482886270497  | validation loss is :  0.12889799361460266
# Training accuracy after  8500  iterations is :  97.91449426485923 %  | validation accuracy is :  98.54014598540147 %
#
# Training loss after  9000  iterations is :  0.13808469547813657  | validation loss is :  0.12433814692421004
# Training accuracy after  9000  iterations is :  97.91449426485923 %  | validation accuracy is :  98.54014598540147 %
#
# Training loss after  9500  iterations is :  0.13380045187501713  | validation loss is :  0.12018298720590581
# Training accuracy after  9500  iterations is :  98.22732012513035 %  | validation accuracy is :  98.54014598540147 %
# [[-3.32960468]
#  [-1.88046379]
#  [-1.94789769]
#  [-0.29734622]]
# 0.01684531046444804

# %%
"""Exploratory Data Analysis for the BankNote dataset """
# Out:
# 'Exploratory Data Analysis for the BankNote dataset '

# %%
df = pd.read_csv("LoR_dataset/data_banknote_authentication.txt",sep="," , names = ["col1", "col2", "col3", "col4" , "val"])

# %%
df.head()
# Out:
#       col1    col2    col3     col4  val
# 0  3.62160  8.6661 -2.8073 -0.44699    0
# 1  4.54590  8.1674 -2.4586 -1.46210    0
# 2  3.86600 -2.6383  1.9242  0.10645    0
# 3  3.45660  9.5228 -4.0112 -3.59440    0
# 4  0.32924 -4.4552  4.5718 -0.98880    0

# %%
import seaborn as sns
print(df.corr())
sns.heatmap(df.corr(), annot = True)
# Out:
#           col1      col2      col3      col4       val
# col1  1.000000  0.264026 -0.380850  0.276817 -0.724843
# col2  0.264026  1.000000 -0.786895 -0.526321 -0.444688
# col3 -0.380850 -0.786895  1.000000  0.318841  0.155883
# col4  0.276817 -0.526321  0.318841  1.000000 -0.023424
# val  -0.724843 -0.444688  0.155883 -0.023424  1.000000

# %%
df.hist(figsize=(16, 20), bins=50, xlabelsize=8, ylabelsize=8); # ; avoid having the matplotlib verbose informations

# %%
print(df)
# Out:
#          col1      col2     col3     col4  val
# 0     3.62160   8.66610  -2.8073 -0.44699    0
# 1     4.54590   8.16740  -2.4586 -1.46210    0
# 2     3.86600  -2.63830   1.9242  0.10645    0
# 3     3.45660   9.52280  -4.0112 -3.59440    0
# 4     0.32924  -4.45520   4.5718 -0.98880    0
# ...       ...       ...      ...      ...  ...
# 1367  0.40614   1.34920  -1.4501 -0.55949    1
# 1368 -1.38870  -4.87730   6.4774  0.34179    1
# 1369 -3.75030 -13.45860  17.5932 -2.77710    1
# 1370 -3.56370  -8.38270  12.3930 -1.28230    1
# 1371 -2.54190  -0.65804   2.6842  1.19520    1
#
# [1372 rows x 5 columns]
